# %% [markdown]
# # Unit 2 Assesment - Monte-Carlo Models
#
# For this assessment, you will work in the following groups
#
# | Group | Names |
# | :---: | :---: |
# | 1 | Hajrah and Maddie L. |
# | 2 | Drake and Cherian |
# | 3 | Diamond and AJ |
# | 4 | Viggo and Ross |
# | 5 | Xavier and Ben |
# | 6 | Victoria and Ash |
# | 7 | Juliana and Kyllie |
# | 8 | Kirsten and Quinn |
# | 9 | Katie and Maddie D. |
# | 10| Dean and Kaiya |
#
# This assessment is due at 8 am on Wednesday 9/16/26.
#
# ### Working Together
# - You should both be present when working on this notebook. Nobody should work on it alone. This is a group effort.
# - **One** person will save the notebook in their Google Drive folder shared with me. They should then share *the notebook* with the other person's gmail account so that both individuals will have access to (and can edit) the same notebook.  Notebooks don't work the same as Google Docs, so if you are both trying to edit a notebook at the same time you will have to manually merge the changes. **After it is completely finished**, the other person should save a copy of the notebook to their Google Drive.
# - I will randomly select one person's Google Drive folder and notebook to grade the group's effort.
# - The quality of your writing important. Your responses should be detailed, logical, and followable. I would strongly recommend coming back to edit your answers a day or so after initially answering the questions.
#
# ### **Using resources**
#
# You may use your Colab notebooks from class, any other notebook or reading I have given you, and any links to web sites I have provided. Basically, if it is linked on Blackboard then you can use it.
#
# You may not use any other person, website, book, or resource. This includes the AI features in Google Colab or any other generative AI tool (ChatGPT, etc.) You are responsible for using only approved resources. If you're unsure whether something is allowed, please ask me before using it.
#
# You can disable the Gemini AI assistance by going to settings, then: uncheck `Consented to use generative AI features`/`Show AI-powered inline completions` and check `Hide generative AI features.` as seen below.
#
# ### **Citing Sources**
#
# Citing sources isn't just about copying and pasting code. It's about giving credit whenever you use ideas, inspiration, or guidance from another source, even if you don't copy directly. Here's how to handle it:
#
# - **When to Cite**:
#   - If you refer to a **specific code example** from class materials, notebooks, or a reading.
#     - Example: "I used the loop structure from the `02-01-random` notebook, exercise 1."
#   - When you use an **idea** or approach that you didn't come up with on your own, even if you modify it.
#     - Example: "The way I calculated the probability of finding the area of a circle was based on the pre-class notebook for Day 3."
#   - **Even if you don't copy-paste** code, if something influenced your thinking or the way you structured your solution, it should be cited.
#
# - **What doesn't need citation**:
#   - Basic ideas that come entirely from your own brain.
#   - Simple language constructs like loops, if-statements, or variables, unless they come directly from an example you're referencing.
#
# - **Key points**
#   - It's always better to cite than to leave something out. You won't lose points for over-citing and I will give you feedback on what citations are required or not.
#   - Don't just cite when you copy code—cite when ideas or problem-solving approaches come from an outside source.
#
# - **Examples of Correct Citations**:
#   - **Copied/Modified Code**: "We used the code from the `randomwalk1D` function in the `02-03-random-walk` notebook to help structure our loop."
#   - **Concept or Inspiration**: "We based our approach for determining the circle a dart landed in on the example we did in class estimating $\pi$. "

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Modeling the Monty Hall Problem
#
# In this assessment, you build a Monte Carlo simulation to model a brainteaser/probability puzzle called the [Monty Hall Problem](https://en.wikipedia.org/wiki/Monty_Hall_problem). Loosely based on the game show *Let's Make a Deal*, a contestant is presented with **three** doors. Behind one door is a prize, and behind the other two are goats. After the contestant picks a door, the host, who knows what is behind every door, opens one of the other two doors to reveal a goat. The contestant can then stick with their original door or switch to the remaining unopened door.
#
# Your task will be to build a Monte-Carlo model to determine what is the better strategy: stick with your initial selection or switch to the other door.

# %% [markdown]
# Before continuing, make sure you run the cell below to load in the required python packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
import random as rand

# %% [markdown]
# # Exercise 1
#
# **Before beginning**: Make a prediction. Do you think the contestant should switch doors or stick with their original choice? Give a rough estimate for the probability of winning under each strategy, not just which one is better. Explain your prediction.

# %% [markdown]
# # Exercise 2
#
# Let's start with the simpler strategy: the contestant does not switch doors. When the contestant doesn't switch, the host opening a door doesn't affect anything, so we don't need to model the host at all.
#
# **Write a function `game()` that picks a random door for the prize and a random door for the contestant, and returns `1` if they match and `0` if they don't.**

# %%
def game():
  ####
  # Pick a random door for the prize and contestant (i.e. 1, 2, or 3)
  # Return True if they match, False if they don't
  ####

  return 1

# %% [markdown]
# Run the code cell below a few times to check that your function is working.

# %%
won = game()
if won == 1:
    print("The contestant won")
else:
    print("The contestant lost")

# %% [markdown]
# # Exercise 3
#
# Let's calculate the probability that the contestant wins the prize with this first strategy.
#
# In the code cell below, use your functions from exercise 2, `game()` in a loop to simulate runs of the game. Record how many times the contestant wins. **What is the (expected) probability the contestant wins without switching?** (Hint: How many games should you simulate to get an answer close to the true probability?)

# %% [markdown]
# # Exercise 4
#
# Compare this result to your prediction from Exercise 1. Were you close?
#
# Now make an updated prediction: given this result, what do you think the probability of winning **while switching** will be? Explain your reasoning.

# %% [markdown]
# # Exercise 5
#
# To simulate switching, we need to model the host opening a door. The host's door has to be random, but it can't be the prize door or the contestant's door. This means we need a way to generate a random number that avoids a known value.
#
# One way to do this is to keep generating a random number in a loop until it's not the value we want to avoid. The code cell below generates two random numbers between 1 and 3 that are guaranteed to be different from each other. Run it a few times to see how it behaves. This is the same code we used in our economic model to ensure we always selected two different agents.

# %%
num1 = rand.randint(1,3)
num2 = rand.randint(1,3)
while num2 == num1:
  num2 = rand.randint(1,3)

print(num1, num2)

# %% [markdown]
# **Write a function `pickDoorAvoiding(door1, door2)` that returns a random door that isn't `door1` and isn't `door2`.** Verify it using the print statements below.
#
# If `door1` and `door2` are different, there's only one valid door left, so you know exactly what the function should return every time. If `door1` and `door2` are the same, there are two valid doors left, so you should see both of them come up if you run it a few times.

# %%
def pickDoorAvoiding(door1, door2):
  ####
  # Return a random door that isn't door1 and isn't door2.
  ####

  return 1

door3 = pickDoorAvoiding(1, 2)
print(f"This should always print 3: {door3}")

randomDoor = pickDoorAvoiding(1, 1)
print(f"This should print 2 or 3: {randomDoor}")

# %% [markdown]
# # Exercise 6
#
# Now that our host can open a door and not accidentally reveal the prize, we can model the switching strategy. This is an english only exercise where we will write out a detailed plan of how to model this. It is, after all, more complicated than our non-switching case!
#
# Our task is to plan a single game. With our new strategy we need to track the prize door, the contestant's door, the host's door, the door the contestant switches to. Write a plan in words (I would suggested a list of steps) for how the function will work from start to finish. When planning, think about which steps can be accomplished with calls to the function we just wrote, o `pickDoorAvoiding()`. By my count, this function is likely to be useful two places. Add a markdown (text) cell below with your plan.

# %% [markdown]
# # Exercise 7
#
# Let's call the version of the game where the contestant switches doors `game_switch()`. I have added some scaffolding to the function below that you could use in addition to your plan. Feel free to copy your code from `game()` into the function below and then implement your plan from the previous exercise if you'd like to replace the provided scaffolding and rely just on your plan from Ex 6.
#
# This function should still pick a prize door and a contestant door the same way `game()` did and return whether the contestant won. The new parts will be picking the host door and the door the contestant chooses to switch to.

# %%
def game_switch():
  ####
  # Pick a prize door and a contestant door.
  # switch the contestant door to the one not opened by the host
  # Return 1 if the contestant won, 0 if they didn't.
  ####

  prizeDoor = 1         # Randomly select the door with the prize behind it
  contestantDoor = 1    # Randomly select the door the contestant chooses
  print(f"Prize door: {prizeDoor}, Contestant door: {contestantDoor}")

  hostOpens = 1         # Randomly select the door the host will open (not contestantDoor and not prizeDoor)
  switchDoor = 1        # Select the door the contestant will switch to (not contestantDoor and not hostOpens)
  print(f"Host opened {hostOpens} and the contestant switched to: {switchDoor}")

  # Return 1 if the contestant won, 0 if they didn't.
  return 1

# %% [markdown]
# Run the code cell below a few times to check that your function is working.

# %%
won = game_switch()
if won == 1:
    print("The contestant won")
else:
    print("The contestant lost")

# %% [markdown]
# # Exercise 8
#
# Use your `game_switch()` function in a loop the same way you did in Exercise 3. **What is the (expected) probability the contestant wins while switching?**
#
# You probably want to delete or comment out the print statements from `game_switch()` before running the loop to avoid spamming text out while running many games.

# %% [markdown]
# # Exercise 9
#
# Compare both probabilities to each other, to your original prediction from Exercise 1, and to your updated prediction from Exercise 4. What is the optimal strategy? How confident are you in this answer? Write a paragraph that summarizes the problem, the model you built, and your results.

# %% [markdown]
# # Exercise 10
#
# Comment on the strengths of the members of your group. What strengths did each person bring to the team? Detail the *specific* contributions (e.g., coding, debugging, explaining concepts, documenting results) made by each member of the group.

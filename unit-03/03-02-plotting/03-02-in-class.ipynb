# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ## Schedule for Unit 3
# - 9/21 Plotting
# - 9/23 Fitting
# - 9/28 Review and Applications. Group assessment released at end of class
# - 9/30 Individual assessment
# - 10/2 Group assessment due (no 1:1 meetings for Unit 3)

# %% [markdown]
# ## Empirical Models
#
# A mathematical expression that follows real world data. Can be used to make predictions where the model is valid (interpolation). Does **not** explain the data or describe why the data has the trend that it does.

# %% [markdown]
# # Review (Functions)
#
# ## Mathematical functions
#
# $$f(x) = a\sqrt{x}+bx+cx^2$$
#
# What are the parts of a function?
#
#
#
# ## Programming functions
# How would we implement the above function in python?

# %% [markdown]
# # Monte-Carlo Models vs. Emperical Models
#
# How do these two modeling methods differ? How are they similar?
#
# ## Monte-Carlo
#
#
#
# ## Emperical

# %% [markdown]
# # Plotting in python

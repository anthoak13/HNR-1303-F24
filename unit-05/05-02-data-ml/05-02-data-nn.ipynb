# %% [markdown]
# # Breaking a simple neural network
#
# In this notebook we will take the neural net we constructed last class and try to break it. How? By messing with the data we use to train it.
#
# My goal for this notebook is for you to understand the importance of data in training a neural network. If our data is incomplete or incorrect in some manner, then our model will be garbage (even if our cost function might look alright)
#
# **Before running any code**: One person in your group should go to `Runtime->Change runtime type` and select `T4 GPU`. The other group member should keep this option on `CPU`. The person who is using a GPU will train the model using the GPU rather than the CPU. This is often faster for large models. The question is: is our model large enough for that to make a difference?
#
# Run the cell below to import all of the python packages we will require in this notebook. You should see the device is CUDA and the GPU is available if you changed the run type otherwise is should say the device is CPU.

# %%
from pathlib import Path # internal python library for managing file paths
import requests # used to doqload files using web requests
import pickle
import gzip # used to unzip files
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

import torch
import torch.nn.functional as F
from torch import nn

import copy
from google.colab import files
import random

gpu_avail = torch.cuda.is_available()
print(f"Is the GPU available? {gpu_avail}")
device = torch.device("cuda") if gpu_avail else torch.device("cpu")
print("Device", device)
# Out:
# Is the GPU available? True
# Device cuda

# %% [markdown]
# # Getting the MINST dataset
#
# Run the cell below to download and unpack the MINST dataset (this is the same as last notebook).

# %%
data_path = Path("data")
path = data_path/"mnist" # this defines the file path as data/mnist
path.mkdir(parents=True, exist_ok=True) # this creates the folders "data" and "data/mnist"

data_url = "https://github.com/pytorch/tutorials/raw/main/_static/"
data_filename = "mnist.pkl.gz"

if not (data_path / data_filename).exists():
  content = requests.get(data_url + data_filename).content
  (data_path/data_filename).open("wb").write(content)

with gzip.open((data_path / data_filename).as_posix(), "rb") as unpacked_data:
  ((image_train, label_train), (image_valid, label_valid), _) = pickle.load(unpacked_data, encoding="latin-1")

# %% [markdown]
# ---
# # (Re-)Building a neural network

# %% [markdown]
# Run the code cells in this section to re-build the different parts of the neural network. These cells will define the cost function, the activation function, and the structure of the neural net (number of hidden layers, etc.)

# %%
# Define the cost function that takes in the model prediction (input) and the expected output by the model (target)
def cost_func(input, target):
   cost = torch.nn.MSELoss(reduction='sum')
   return cost(input, target)

# Define a function that takes in a digit (0-9) and creates the corresponding model target
def get_target(digits):
  target = F.one_hot(torch.tensor(digits, device = device), 10)
  return target

# Define the activation function
activation_func = F.sigmoid

# Define the structure of the neural net
class NN_Model(nn.Module):
  def __init__(self):
    super().__init__()
    self.hidden1 = nn.Linear(784,16) # Our input layer has 784 neurons and our first hidden layer has 16 elements
    self.hidden2 = nn.Linear(16,16) # Our second hidden layer has 16 inputs and 16 outputs
    self.output = nn.Linear(16,10) # Our output layer has 16 inputs and 10 outputs

  def forward(self, xb):
    # xb is the value of all the neurons at the current layer.
    # At the start it is a tensor with 784 elements

    # Do the matrix multiplication and then take the sigmoid of each element in the first hidden layer.
    xb = activation_func(self.hidden1(xb))
    # xb is now a tensor with 16 elements

    # Do the matrix multiplication and then take the sigmoid of each element in the second hidden layer.
    xb = activation_func(self.hidden2(xb))
    # xb is now a tensor with 16 elements

    # Do the matrix multiplication and then take the sigmoid of each element in the output layer.
    xb = activation_func(self.output(xb))
    # xb is now a tensor with 10 elements

    return xb

# %% [markdown]
# ---
# # Training the model

# %% [markdown]
# Run the cell below to define the training function. This is a slightly more sophisticated version of the training function we have used in the past. It takes in both the training data and the validation data. It also uses the abstract `Dataset` class and the helper class `DataLoader` from PyTorch to simplify the management of the data and creating batches to train on.
#
# **Optional for those interested in the details**: This information is not necessary for understanding anything in our class, but is here for those who are interested in digging into the details of how python handles data structures. The `Dataset` class wraps any object that implements the [`__len__()`](https://docs.python.org/3/reference/datamodel.html#object.__len__) and [`__getitem__()`](https://docs.python.org/3/reference/datamodel.html#object.__getitem__) functions in Python. These are both examples of so-called ["magic functions"](https://rszalski.github.io/magicmethods/) in Python. They are what underlay a lot of the power of Python, which I would argue is the ability to basically ignore the specific type of an object. Instead we can treat an object logically. Is it an array like object? Then `a[0]` should do something reasonable. Personally, I've never really liked the name "magic functions". What they really are is an [Interface](https://en.wikipedia.org/wiki/Interface_(object-oriented_programming) which defines a set of *behaviors*. Any class can then agree to follow and implement the interface. All of these classes can be used interchangeably (in certain contexts). The two functions we need implemented are part of [the group of magic functions](https://docs.python.org/3/reference/datamodel.html#emulating-container-types) that allow for us to iterate through a container. `__len__(self)` is what is called whenever you run `len(obj)`. `__getitem__(self, key)` is called whenever you run something like `self[key]`. Both are fundamental to the design of a data structure and are part of the interface that allows you to mostly treat all data structures the same way in Python. Isn't object oriented programming fun?

# %%
# We will define a function for training out model:
# epochs is the number of times we pass over the complete training set.
# batch_size is how many training examples to combine before updating the model parameters
# learning_rate controls how large of a step we take each time we update the model parameters
# data_train is the list of images we are training on (the entirety of this dataset corresponds to a single epoch)
# label_train is the list of labels corresponding to the images in data_train
# model is the model we are training
# We can optionally pass two additional parameters data_valid and label_valid.

# The function will return a list containing the average cost function after each epoch
def train_model(epochs, batch_size, learning_rate, data_train, label_train, model, data_valid = None, label_valid = None):

  # Create lists to return
  cost_valid = []
  cost_train = []
  models = []

  # Create the optimizer to perform the gradient descent
  opt = torch.optim.SGD(model.parameters(), lr=learning_rate)

  # Wrap the training data in a dataset
  train_ds = torch.utils.data.TensorDataset(torch.tensor(data_train, device = device), get_target(label_train))
  train_dl = torch.utils.data.DataLoader(train_ds, batch_size=batch_size)

  # Send the model to the GPU if available
  model.to(device)

  # We will repeat the training process multiple times, printing the current average of the cost function after each epoch
  for epoch in range (epochs):
    runningLoss = 0.0
    model.train()
    # Each iteration of this loop will evaluate the model
    # on a subset of the data containing batch_size images
    for xb, yb in train_dl:
      xb = xb.to(device)
      yb = yb.to(device)

      opt.zero_grad()
      pred = model(xb)
      cost = cost_func(pred, yb.float())

      # Update the model parameters (i.e. train the model)
      # for this batch of data
      cost.backward()
      opt.step()

      runningLoss += cost.item()


    # End of batch_size loop

    # calculate the average cost function
    cost = runningLoss / len(train_dl.dataset)

    xb = torch.tensor(data_valid, device=device)
    yb = get_target(label_valid)
    pred = model(xb)

    # calculate the average cost function
    cost_v = cost_func(pred, yb) / len(pred)

    print(f"After epoch {epoch} the cost function is {cost}")
    cost_valid.append(cost_v.item())
    cost_train.append(cost)
    models.append(copy.deepcopy(model))

  return cost_valid, cost_train, models

# Return the predicted digit from the output of the model
def get_digit(pred):
  return torch.argmax(pred, dim=0)

def accuracy(pred, xy):
  num_right = 0
  for i in range(pred.shape[0]):
    if get_digit(pred[i]) == get_digit(xy[i]):
      num_right += 1

  return num_right / pred.shape[0]

# %% [markdown]
# ## Get a working model
#
# Run the following code to train the model using some default hyperparameters:

# %%
# Hyperparameters for training
learning_rate = 0.05
batch_size = 100
num_epochs = 100

# This will default to creating a model with random weights and biases.
torch.manual_seed(0) # This will fix it so we all get the same data
if torch.cuda.is_available():
  torch.cuda.manual_seed(0)
  torch.cuda.manual_seed_all(0)

model = NN_Model()
model.to(device)

# Train the data. Save the average cost function and the model after each epoch
costs_valid, costs, models = train_model(num_epochs, batch_size, learning_rate, image_train, label_train, model, data_valid = image_valid, label_valid=label_valid)

#torch.save(model, 'testModel.pth')
#files.download('testModel.pth')
epochs = [i for i in range(len(costs))]

# plot the cost function as a function of epoch
fig = plt.figure(figsize=(8,6))
plt.title("Cost function vs. training epoch")
plt.xlabel('Epoch')
plt.ylabel('Cost function (arb)')
plt.grid(which='both', axis='both')
plt.plot(epochs, costs, 'r-', label="Training set")
plt.plot(epochs, costs_valid, 'b-', label="Validation set")
plt.legend()
plt.show()
# Out:
# After epoch 0 the cost function is 0.5347940487098694
# After epoch 1 the cost function is 0.1593022083568573
# After epoch 2 the cost function is 0.1249147532081604
# After epoch 3 the cost function is 0.11035253449916839
# After epoch 4 the cost function is 0.10068771554231644
# After epoch 5 the cost function is 0.09462399106740951
# After epoch 6 the cost function is 0.08994345111370086
# After epoch 7 the cost function is 0.08547375059604645
# After epoch 8 the cost function is 0.081962352976799
# After epoch 9 the cost function is 0.0795931849527359
# After epoch 10 the cost function is 0.07648712656497955
# After epoch 11 the cost function is 0.07414100492119789
# After epoch 12 the cost function is 0.0733643131685257
# After epoch 13 the cost function is 0.07013321787357331
# After epoch 14 the cost function is 0.06920432104706764
# After epoch 15 the cost function is 0.06794717249155044
# After epoch 16 the cost function is 0.0662457338309288
# After epoch 17 the cost function is 0.06598738413453102
# After epoch 18 the cost function is 0.06483499568104743
# After epoch 19 the cost function is 0.06448209333598613
# After epoch 20 the cost function is 0.062287127131819726
# After epoch 21 the cost function is 0.06280747419655323
# After epoch 22 the cost function is 0.06208317086696625
# After epoch 23 the cost function is 0.060781100916862486
# After epoch 24 the cost function is 0.06004860337197781
# After epoch 25 the cost function is 0.059645298338532445
# After epoch 26 the cost function is 0.05936894170284271
# After epoch 27 the cost function is 0.059148926733732225
# After epoch 28 the cost function is 0.05795258965790272
# After epoch 29 the cost function is 0.05589280379295349
# After epoch 30 the cost function is 0.05604339498281479
# After epoch 31 the cost function is 0.05624994403064251
# After epoch 32 the cost function is 0.0553082113301754
# After epoch 33 the cost function is 0.05521603746175766
# After epoch 34 the cost function is 0.05542384066462517
# After epoch 35 the cost function is 0.05397702337384224
# After epoch 36 the cost function is 0.054055050623118876
# After epoch 37 the cost function is 0.0526456158810854
# After epoch 38 the cost function is 0.053056567580103874
# After epoch 39 the cost function is 0.052425593771785496
# After epoch 40 the cost function is 0.05259886915266514
# After epoch 41 the cost function is 0.05205137214243412
# After epoch 42 the cost function is 0.05143707424342632
# After epoch 43 the cost function is 0.05171848851323128
# After epoch 44 the cost function is 0.050516624369621274
# After epoch 45 the cost function is 0.04987228221178055
# After epoch 46 the cost function is 0.04963440853446722
# After epoch 47 the cost function is 0.04952038608193397
# After epoch 48 the cost function is 0.04910190595433116
# After epoch 49 the cost function is 0.048525475329458716
# After epoch 50 the cost function is 0.04873599244147539
# After epoch 51 the cost function is 0.04815965145766735
# After epoch 52 the cost function is 0.04719288974046707
# After epoch 53 the cost function is 0.04779463698774576
# After epoch 54 the cost function is 0.04766684329286218
# After epoch 55 the cost function is 0.04815984239593148
# After epoch 56 the cost function is 0.04710869782164693
# After epoch 57 the cost function is 0.046564153306484224
# After epoch 58 the cost function is 0.0470895961394161
# After epoch 59 the cost function is 0.04659136223852634
# After epoch 60 the cost function is 0.04676879407286644
# After epoch 61 the cost function is 0.04582387105613947
# After epoch 62 the cost function is 0.04681507703065872
# After epoch 63 the cost function is 0.04573585994645953
# After epoch 64 the cost function is 0.04533073833301663
# After epoch 65 the cost function is 0.04536990232557058
# After epoch 66 the cost function is 0.04441912245117128
# After epoch 67 the cost function is 0.04401169185712934
# After epoch 68 the cost function is 0.045581306693553925
# After epoch 69 the cost function is 0.04364371010310948
# After epoch 70 the cost function is 0.04411067163534462
# After epoch 71 the cost function is 0.04493419310361147
# After epoch 72 the cost function is 0.0442386517983675
# After epoch 73 the cost function is 0.04343755645386874
# After epoch 74 the cost function is 0.04382371424041689
# After epoch 75 the cost function is 0.04295867912895977
# After epoch 76 the cost function is 0.04304737182855606
# After epoch 77 the cost function is 0.04255167225182056
# After epoch 78 the cost function is 0.042753842327073216
# After epoch 79 the cost function is 0.042692728886008266
# After epoch 80 the cost function is 0.04359389774031937
# After epoch 81 the cost function is 0.042677911323159935
# After epoch 82 the cost function is 0.04188414852239192
# After epoch 83 the cost function is 0.042033738978207114
# After epoch 84 the cost function is 0.04239392219863832
# After epoch 85 the cost function is 0.04198909197688103
# After epoch 86 the cost function is 0.04154096524879337
# After epoch 87 the cost function is 0.04037046501405537
# After epoch 88 the cost function is 0.04225683388754725
# After epoch 89 the cost function is 0.042305605111420154
# After epoch 90 the cost function is 0.04227651710860431
# After epoch 91 the cost function is 0.041733173116743565
# After epoch 92 the cost function is 0.04248902355670929
# After epoch 93 the cost function is 0.042034197384417056
# After epoch 94 the cost function is 0.04187098609868437
# After epoch 95 the cost function is 0.04253362526446581
# After epoch 96 the cost function is 0.040539821963608266
# After epoch 97 the cost function is 0.040979339968189595
# After epoch 98 the cost function is 0.040649325594455006
# After epoch 99 the cost function is 0.039905549992769955

# %% [markdown]
# # When is a model done learning?
#
# **Based on the cost curves you generated above, how does the long-term behavior of the cost function differ between the validation set and the training set?**
#
# **Around what epoch does the validation curve level off?**
#
# **What do you think is happening here?**
#
#
# Run the code below to fit the long term behavior of the cost function for our two data sets.

# %%
linear_model = lambda x,a,b: x*a + b

trunc_epoch = epochs[20:]
trunc_train = costs[20:]
trunc_valid = costs_valid[20:]

params, cov = curve_fit(linear_model, trunc_epoch, trunc_train)
model_train = linear_model(np.array(trunc_epoch), *params)
print(f"The slope of the cost curve for the training data is {params[0]:.2e}.")

params, cov = curve_fit(linear_model, trunc_epoch, trunc_valid)
model_valid = linear_model(np.array(trunc_epoch), *params)
print(f"The slope of the cost curve for the validation data is {params[0]:.2e}.")

# plot the cost function as a function of epoch
fig = plt.figure(figsize=(8,6))
plt.title("Cost function vs. training epoch")
plt.xlabel('Epoch')
plt.ylabel('Cost function (arb)')
plt.grid(which='both', axis='both')
plt.plot(trunc_epoch, costs[20:], 'r-', label="Training set")
plt.plot(trunc_epoch, model_train, 'r--', label="Linear fit")
plt.plot(epochs[20:], costs_valid[20:], 'b-', label="Validation set")
plt.plot(trunc_epoch, model_valid, 'b--', label="Linear fit")
plt.legend()
plt.show()
# Out:
# The slope of the cost curve for the training data is -2.57e-04.
# The slope of the cost curve for the validation data is 4.85e-05.

# %% [markdown]
# **What does it mean for the validity of our model that the slope for the training set is negative and the slope for the validation set is positive?**

# %% [markdown]
# # Training with bad data
#
# Machine learning models are only as good as the data they are given. Suppose we where to shuffle of the labels in our training set. That is, each image in our training set is assigned to a random number as a label.
#
# **What do you think the cost curves will look like for the training and validation sets? Sketch a prediction for the curves.**
#
#
# After sketching your prediction, run the following code to find out.

# %%
# Hyperparameters for training
learning_rate = 0.05
batch_size = 100
num_epochs = 100

# This will default to creating a model with random weights and biases.
torch.manual_seed(0) # This will fix it so we all get the same starting model
model = NN_Model()
model.to(device)

label_sh = copy.deepcopy(label_train) # Make a copy of our labels
random.shuffle(label_sh) # Shuffle our labels at random

# Train the data. Save the average cost function and the model after each epoch
costs_valid_sh, costs_sh, models_sh = train_model(num_epochs, batch_size, learning_rate, image_train, label_sh, model, data_valid = image_valid, label_valid=label_valid)
epochs_sh = [i for i in range(len(costs_sh))]
# Out:
# After epoch 0 the cost function is 0.9054575497436523
# After epoch 1 the cost function is 0.9003748971557617
# After epoch 2 the cost function is 0.900325103302002
# After epoch 3 the cost function is 0.9002896978759766
# After epoch 4 the cost function is 0.9002621257019043
# After epoch 5 the cost function is 0.9002394055175781
# After epoch 6 the cost function is 0.9002198257446289
# After epoch 7 the cost function is 0.9002022529602051
# After epoch 8 the cost function is 0.9001858184814453
# After epoch 9 the cost function is 0.900169778137207
# After epoch 10 the cost function is 0.900153405456543
# After epoch 11 the cost function is 0.9001360037231445
# After epoch 12 the cost function is 0.9001169657897949
# After epoch 13 the cost function is 0.900095983581543
# After epoch 14 the cost function is 0.9000732431030274
# After epoch 15 the cost function is 0.9000493061828613
# After epoch 16 the cost function is 0.9000246427917481
# After epoch 17 the cost function is 0.8999994834899903
# After epoch 18 the cost function is 0.8999739639282227
# After epoch 19 the cost function is 0.8999481562805176
# After epoch 20 the cost function is 0.8999219416809082
# After epoch 21 the cost function is 0.8998950328063965
# After epoch 22 the cost function is 0.8998671522521973
# After epoch 23 the cost function is 0.8998380952453613
# After epoch 24 the cost function is 0.8998077719116211
# After epoch 25 the cost function is 0.8997761402893066
# After epoch 26 the cost function is 0.8997432026672363
# After epoch 27 the cost function is 0.8997089324951172
# After epoch 28 the cost function is 0.8996732981872558
# After epoch 29 the cost function is 0.8996361950683593
# After epoch 30 the cost function is 0.8995975099182129
# After epoch 31 the cost function is 0.8995570797729492
# After epoch 32 the cost function is 0.8995147450256348
# After epoch 33 the cost function is 0.8994703736877442
# After epoch 34 the cost function is 0.899423872680664
# After epoch 35 the cost function is 0.8993751710510254
# After epoch 36 the cost function is 0.8993241763305664
# After epoch 37 the cost function is 0.8992707481384278
# After epoch 38 the cost function is 0.8992147193908692
# After epoch 39 the cost function is 0.8991558810424805
# After epoch 40 the cost function is 0.8990940632629395
# After epoch 41 the cost function is 0.8990291198730469
# After epoch 42 the cost function is 0.8989609677124023
# After epoch 43 the cost function is 0.8988895510864258
# After epoch 44 the cost function is 0.8988148350524903
# After epoch 45 the cost function is 0.8987367286682129
# After epoch 46 the cost function is 0.898655126953125
# After epoch 47 the cost function is 0.8985698811340332
# After epoch 48 the cost function is 0.8984808187866211
# After epoch 49 the cost function is 0.8983877906799317
# After epoch 50 the cost function is 0.8982906309509278
# After epoch 51 the cost function is 0.898189168548584
# After epoch 52 the cost function is 0.8980831878662109
# After epoch 53 the cost function is 0.8979723844909668
# After epoch 54 the cost function is 0.8978564379882813
# After epoch 55 the cost function is 0.8977350944519042
# After epoch 56 the cost function is 0.8976082313537598
# After epoch 57 the cost function is 0.8974757888793945
# After epoch 58 the cost function is 0.8973377014160157
# After epoch 59 the cost function is 0.897193892211914
# After epoch 60 the cost function is 0.8970442150878907
# After epoch 61 the cost function is 0.8968885105895996
# After epoch 62 the cost function is 0.8967265911865234
# After epoch 63 the cost function is 0.896558279876709
# After epoch 64 the cost function is 0.8963834017944335
# After epoch 65 the cost function is 0.8962017762756348
# After epoch 66 the cost function is 0.8960132272338868
# After epoch 67 the cost function is 0.8958176148986816
# After epoch 68 the cost function is 0.8956148020935059
# After epoch 69 the cost function is 0.8954046949768066
# After epoch 70 the cost function is 0.8951872250366211
# After epoch 71 the cost function is 0.8949623881530762
# After epoch 72 the cost function is 0.894730359954834
# After epoch 73 the cost function is 0.8944915234375
# After epoch 74 the cost function is 0.894246496887207
# After epoch 75 the cost function is 0.8939960125732422
# After epoch 76 the cost function is 0.8937407196044922
# After epoch 77 the cost function is 0.8934811535644531
# After epoch 78 the cost function is 0.8932177960205078
# After epoch 79 the cost function is 0.8929508258056641
# After epoch 80 the cost function is 0.8926799633789062
# After epoch 81 the cost function is 0.892404594116211
# After epoch 82 the cost function is 0.8921246630859375
# After epoch 83 the cost function is 0.8918412493896485
# After epoch 84 the cost function is 0.8915554852294922
# After epoch 85 the cost function is 0.8912671282958985
# After epoch 86 the cost function is 0.8909750611877442
# After epoch 87 the cost function is 0.8906772242736817
# After epoch 88 the cost function is 0.8903713847351075
# After epoch 89 the cost function is 0.8900569279479981
# After epoch 90 the cost function is 0.8897322018432617
# After epoch 91 the cost function is 0.8894001515197754
# After epoch 92 the cost function is 0.889069112701416
# After epoch 93 the cost function is 0.8887455891418456
# After epoch 94 the cost function is 0.8884237843322754
# After epoch 95 the cost function is 0.8881006468200684
# After epoch 96 the cost function is 0.887800471496582
# After epoch 97 the cost function is 0.8874944813537597
# After epoch 98 the cost function is 0.8871407807922363
# After epoch 99 the cost function is 0.8867816290283204

# %%
# plot the cost function as a function of epoch
fig = plt.figure(figsize=(8,6))
plt.title("Cost function vs. training epoch")
plt.xlabel('Epoch')
plt.ylabel('Cost function (arb)')
plt.grid(which='both', axis='both')
plt.plot(epochs_sh, costs_sh, 'r-', label="Training set")
plt.plot(epochs_sh, costs_valid_sh, 'b-', label="Validation set")
plt.legend()
plt.show()

# %% [markdown]
# **What is the long term behavior for both cost curves?**
#
# **How do the cost curves differ from when we are training with good data?**

# %% [markdown]
# ---
#
#
# Let's look for a second at the accuracy as a function of epoch. It's a little easier to interpret. **If our model was just guessing, what would the expected accuracy of the model be?**
#
# After making your prediction, run the two code cells below to calculate and plot accuracy vs epoch (it'll take a bit, there is a lot of data to churn through, if you want to edit the plot just run the second cell). It took about 6 minutes for me.

# %%
target = get_target(label_sh)
target_valid = get_target(label_valid)
acc_train = []
acc_valid = []
for model, epoch in zip(models_sh, range(len(models_sh))):
  if epoch % 10 == 0:
    print("On epoch ", epoch, " of ", len(models_sh))

  model.to(device)
  pred = model(torch.tensor(image_train, device=device))
  acc_train.append(accuracy(pred, target))


  pred = model(torch.tensor(image_valid, device=device))
  acc_valid.append(accuracy(pred, target_valid))
# Out:
# On epoch  0  of  100
# On epoch  10  of  100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1893934444.py in <cell line: 0>()
#       9   model.to(device)
#      10   pred = model(torch.tensor(image_train, device=device))
# ---> 11   acc_train.append(accuracy(pred, target))
#      12
#      13
#
# /tmp/ipython-input-3664864767.py in accuracy(pred, xy)
#      74   num_right = 0
#      75   for i in range(pred.shape[0]):
# ---> 76     if get_digit(pred[i]) == get_digit(xy[i]):
#      77       num_right += 1
#      78
#
# KeyboardInterrupt:

# %%
log_model = lambda x, a, b, c, d: a/(1+np.exp(-b*(x-c))) + d

trunc_epoch = epochs_sh[0:]
trunc_train = costs_sh[0:]
trunc_valid = costs_valid_sh[0:]

params, cov = curve_fit(log_model, trunc_epoch, acc_train, p0=[.03, 1, 45, .12])
model_train = log_model(np.array(trunc_epoch), *params)
print(f"The carrying capacity of the cost curve for the training data is {(params[0]+params[3])*100:.2f}%.")


# plot the cost function as a function of epoch
fig = plt.figure(figsize=(8,6))
plt.title("Accuracy vs. training epoch")
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(which='both', axis='both')
plt.plot(epochs_sh, acc_train, 'r-', label="Training set")
plt.plot(epochs_sh, acc_valid, 'b-', label="Validation set")
plt.plot(epochs_sh, model_train, 'r--', label="Logistic fit")
plt.legend()
plt.show()
# Out:
# The carrying capacity of the cost curve for the training data is 14.93%.

# %% [markdown]
# **What do you notice about the accuracy? Is one dataset better than random? Is one dataset worse than random?**
#
# **Why do you think the accuracy for the training set is leveling off? It is fit quite well by a logisitic function.**
#
# **What do you think would happen if we were to only train on $100$ examples instead of $50,000$ (with the wrong labels)?**

# %% [markdown]
# The code below will train a series of models on only 100 events with the labels shuffled.

# %%
# Hyperparameters for training
learning_rate = 0.05
batch_size = 100
num_epochs = 1000

# This will default to creating a model with random weights and biases.
torch.manual_seed(0) # This will fix it so we all get the same data
model = NN_Model()
model.to(device)

label_100 = label_sh[:100]
data_100 = image_train[:100]

# Train the data. Save the average cost function and the model after each epoch
costs_valid_100, costs_100, models_100 = train_model(num_epochs, batch_size, learning_rate, data_100, label_100, model, data_valid = image_valid, label_valid=label_valid)
epochs_100 = [i for i in range(len(costs_100))]

# plot the cost function as a function of epoch
fig = plt.figure(figsize=(8,6))
plt.title("Cost function vs. training epoch")
plt.xlabel('Epoch')
plt.ylabel('Cost function (arb)')
plt.grid(which='both', axis='both')
plt.plot(epochs_100, costs_100, 'r-', label="Training set")
plt.plot(epochs_100, costs_valid_100, 'b-', label="Validation set")
plt.legend()
plt.show()
# Out:
# After epoch 0 the cost function is 2.4599365234375
# After epoch 1 the cost function is 0.9806608581542968
# After epoch 2 the cost function is 0.9779324340820312
# After epoch 3 the cost function is 0.9748731231689454
# After epoch 4 the cost function is 0.9716510009765625
# After epoch 5 the cost function is 0.9684779357910156
# After epoch 6 the cost function is 0.9654026794433593
# After epoch 7 the cost function is 0.9621829223632813
# After epoch 8 the cost function is 0.9584518432617187
# After epoch 9 the cost function is 0.953910140991211
# After epoch 10 the cost function is 0.9483560180664062
# After epoch 11 the cost function is 0.9417102813720704
# After epoch 12 the cost function is 0.9341371154785156
# After epoch 13 the cost function is 0.9261969757080079
# After epoch 14 the cost function is 0.9188164520263672
# After epoch 15 the cost function is 0.9128702545166015
# After epoch 16 the cost function is 0.9086454772949218
# After epoch 17 the cost function is 0.9058267211914063
# After epoch 18 the cost function is 0.9039344024658204
# After epoch 19 the cost function is 0.9026148986816406
# After epoch 20 the cost function is 0.9016593170166015
# After epoch 21 the cost function is 0.9009465789794922
# After epoch 22 the cost function is 0.9004031372070312
# After epoch 23 the cost function is 0.8999816131591797
# After epoch 24 the cost function is 0.8996501159667969
# After epoch 25 the cost function is 0.8993861389160156
# After epoch 26 the cost function is 0.8991734313964844
# After epoch 27 the cost function is 0.8990000915527344
# After epoch 28 the cost function is 0.8988571166992188
# After epoch 29 the cost function is 0.8987377166748047
# After epoch 30 the cost function is 0.8986370086669921
# After epoch 31 the cost function is 0.8985507202148437
# After epoch 32 the cost function is 0.8984759521484375
# After epoch 33 the cost function is 0.8984104919433594
# After epoch 34 the cost function is 0.898352279663086
# After epoch 35 the cost function is 0.8983000183105468
# After epoch 36 the cost function is 0.8982525634765625
# After epoch 37 the cost function is 0.8982090759277344
# After epoch 38 the cost function is 0.8981687927246094
# After epoch 39 the cost function is 0.8981309509277344
# After epoch 40 the cost function is 0.8980952453613281
# After epoch 41 the cost function is 0.8980612182617187
# After epoch 42 the cost function is 0.8980286407470703
# After epoch 43 the cost function is 0.8979971313476562
# After epoch 44 the cost function is 0.8979666137695312
# After epoch 45 the cost function is 0.8979365539550781
# After epoch 46 the cost function is 0.8979071807861329
# After epoch 47 the cost function is 0.8978780364990234
# After epoch 48 the cost function is 0.8978492736816406
# After epoch 49 the cost function is 0.8978205871582031
# After epoch 50 the cost function is 0.8977920532226562
# After epoch 51 the cost function is 0.8977633666992187
# After epoch 52 the cost function is 0.8977347564697266
# After epoch 53 the cost function is 0.8977059173583984
# After epoch 54 the cost function is 0.897677001953125
# After epoch 55 the cost function is 0.897647705078125
# After epoch 56 the cost function is 0.8976182556152343
# After epoch 57 the cost function is 0.8975884246826172
# After epoch 58 the cost function is 0.8975582885742187
# After epoch 59 the cost function is 0.8975277709960937
# After epoch 60 the cost function is 0.8974966430664062
# After epoch 61 the cost function is 0.8974653625488281
# After epoch 62 the cost function is 0.8974334716796875
# After epoch 63 the cost function is 0.897401123046875
# After epoch 64 the cost function is 0.8973680877685547
# After epoch 65 the cost function is 0.8973345947265625
# After epoch 66 the cost function is 0.8973005676269531
# After epoch 67 the cost function is 0.8972658538818359
# After epoch 68 the cost function is 0.8972304534912109
# After epoch 69 the cost function is 0.8971943664550781
# After epoch 70 the cost function is 0.8971575927734375
# After epoch 71 the cost function is 0.8971201324462891
# After epoch 72 the cost function is 0.8970819091796876
# After epoch 73 the cost function is 0.8970427703857422
# After epoch 74 the cost function is 0.8970028686523438
# After epoch 75 the cost function is 0.8969619750976563
# After epoch 76 the cost function is 0.8969203186035156
# After epoch 77 the cost function is 0.8968775939941406
# After epoch 78 the cost function is 0.8968339538574219
# After epoch 79 the cost function is 0.8967892456054688
# After epoch 80 the cost function is 0.8967433929443359
# After epoch 81 the cost function is 0.8966964721679688
# After epoch 82 the cost function is 0.8966484069824219
# After epoch 83 the cost function is 0.89659912109375
# After epoch 84 the cost function is 0.8965485382080078
# After epoch 85 the cost function is 0.8964966583251953
# After epoch 86 the cost function is 0.8964433288574218
# After epoch 87 the cost function is 0.8963887023925782
# After epoch 88 the cost function is 0.8963324737548828
# After epoch 89 the cost function is 0.8962747192382813
# After epoch 90 the cost function is 0.8962153625488282
# After epoch 91 the cost function is 0.8961542510986328
# After epoch 92 the cost function is 0.8960914611816406
# After epoch 93 the cost function is 0.8960267639160157
# After epoch 94 the cost function is 0.8959602355957031
# After epoch 95 the cost function is 0.8958915710449219
# After epoch 96 the cost function is 0.8958209228515625
# After epoch 97 the cost function is 0.8957481384277344
# After epoch 98 the cost function is 0.8956729125976562
# After epoch 99 the cost function is 0.8955953979492187
# After epoch 100 the cost function is 0.895515365600586
# After epoch 101 the cost function is 0.8954328918457031
# After epoch 102 the cost function is 0.8953475952148438
# After epoch 103 the cost function is 0.8952593994140625
# After epoch 104 the cost function is 0.8951683044433594
# After epoch 105 the cost function is 0.8950740051269531
# After epoch 106 the cost function is 0.894976577758789
# After epoch 107 the cost function is 0.8948756408691406
# After epoch 108 the cost function is 0.8947712707519532
# After epoch 109 the cost function is 0.8946629333496093
# After epoch 110 the cost function is 0.8945508575439454
# After epoch 111 the cost function is 0.8944346618652343
# After epoch 112 the cost function is 0.8943140411376953
# After epoch 113 the cost function is 0.8941889190673828
# After epoch 114 the cost function is 0.8940590667724609
# After epoch 115 the cost function is 0.8939241027832031
# After epoch 116 the cost function is 0.8937840270996094
# After epoch 117 the cost function is 0.8936383056640625
# After epoch 118 the cost function is 0.8934867858886719
# After epoch 119 the cost function is 0.8933291625976563
# After epoch 120 the cost function is 0.8931649780273437
# After epoch 121 the cost function is 0.8929940795898438
# After epoch 122 the cost function is 0.8928160095214843
# After epoch 123 the cost function is 0.8926303100585937
# After epoch 124 the cost function is 0.892436752319336
# After epoch 125 the cost function is 0.8922346496582031
# After epoch 126 the cost function is 0.8920236968994141
# After epoch 127 the cost function is 0.8918033599853515
# After epoch 128 the cost function is 0.8915731811523437
# After epoch 129 the cost function is 0.8913323974609375
# After epoch 130 the cost function is 0.8910804748535156
# After epoch 131 the cost function is 0.8908168792724609
# After epoch 132 the cost function is 0.890540771484375
# After epoch 133 the cost function is 0.8902516174316406
# After epoch 134 the cost function is 0.8899484252929688
# After epoch 135 the cost function is 0.8896305847167969
# After epoch 136 the cost function is 0.889296875
# After epoch 137 the cost function is 0.8889467620849609
# After epoch 138 the cost function is 0.888578872680664
# After epoch 139 the cost function is 0.8881922912597656
# After epoch 140 the cost function is 0.8877857971191406
# After epoch 141 the cost function is 0.8873582458496094
# After epoch 142 the cost function is 0.8869082641601562
# After epoch 143 the cost function is 0.8864344024658203
# After epoch 144 the cost function is 0.88593505859375
# After epoch 145 the cost function is 0.8854087829589844
# After epoch 146 the cost function is 0.8848538208007812
# After epoch 147 the cost function is 0.8842681884765625
# After epoch 148 the cost function is 0.8836501312255859
# After epoch 149 the cost function is 0.8829972839355469
# After epoch 150 the cost function is 0.8823075103759765
# After epoch 151 the cost function is 0.8815785217285156
# After epoch 152 the cost function is 0.8808075714111329
# After epoch 153 the cost function is 0.8799920654296876
# After epoch 154 the cost function is 0.8791294097900391
# After epoch 155 the cost function is 0.8782164001464844
# After epoch 156 the cost function is 0.8772501373291015
# After epoch 157 the cost function is 0.8762273406982422
# After epoch 158 the cost function is 0.8751448822021485
# After epoch 159 the cost function is 0.8739993286132812
# After epoch 160 the cost function is 0.8727874755859375
# After epoch 161 the cost function is 0.8715058898925782
# After epoch 162 the cost function is 0.8701516723632813
# After epoch 163 the cost function is 0.8687214660644531
# After epoch 164 the cost function is 0.8672125244140625
# After epoch 165 the cost function is 0.8656224060058594
# After epoch 166 the cost function is 0.863948974609375
# After epoch 167 the cost function is 0.8621903228759765
# After epoch 168 the cost function is 0.8603451538085938
# After epoch 169 the cost function is 0.8584130859375
# After epoch 170 the cost function is 0.8563938903808593
# After epoch 171 the cost function is 0.8542878723144531
# After epoch 172 the cost function is 0.8520964050292968
# After epoch 173 the cost function is 0.8498211669921875
# After epoch 174 the cost function is 0.8474645233154297
# After epoch 175 the cost function is 0.8450289916992187
# After epoch 176 the cost function is 0.8425181579589843
# After epoch 177 the cost function is 0.8399355316162109
# After epoch 178 the cost function is 0.8372852325439453
# After epoch 179 the cost function is 0.834571533203125
# After epoch 180 the cost function is 0.8317991638183594
# After epoch 181 the cost function is 0.8289727783203125
# After epoch 182 the cost function is 0.8260974884033203
# After epoch 183 the cost function is 0.8231781768798828
# After epoch 184 the cost function is 0.8202196502685547
# After epoch 185 the cost function is 0.8172262573242187
# After epoch 186 the cost function is 0.8142023468017578
# After epoch 187 the cost function is 0.8111510467529297
# After epoch 188 the cost function is 0.8080751037597657
# After epoch 189 the cost function is 0.8049761962890625
# After epoch 190 the cost function is 0.8018546295166016
# After epoch 191 the cost function is 0.7987100982666016
# After epoch 192 the cost function is 0.795540771484375
# After epoch 193 the cost function is 0.79234375
# After epoch 194 the cost function is 0.7891154479980469
# After epoch 195 the cost function is 0.7858512115478515
# After epoch 196 the cost function is 0.7825466918945313
# After epoch 197 the cost function is 0.7792018127441406
# After epoch 198 the cost function is 0.7758488464355469
# After epoch 199 the cost function is 0.7727818298339844
# After epoch 200 the cost function is 0.7725271606445312
# After epoch 201 the cost function is 0.794425277709961
# After epoch 202 the cost function is 0.8600570678710937
# After epoch 203 the cost function is 0.8908200073242187
# After epoch 204 the cost function is 0.8772514343261719
# After epoch 205 the cost function is 0.8717726135253906
# After epoch 206 the cost function is 0.8670733642578125
# After epoch 207 the cost function is 0.8626133728027344
# After epoch 208 the cost function is 0.857989501953125
# After epoch 209 the cost function is 0.85280517578125
# After epoch 210 the cost function is 0.8465502166748047
# After epoch 211 the cost function is 0.8383286285400391
# After epoch 212 the cost function is 0.8254637145996093
# After epoch 213 the cost function is 0.7995391845703125
# After epoch 214 the cost function is 0.7658348083496094
# After epoch 215 the cost function is 0.7554745483398437
# After epoch 216 the cost function is 0.7490675354003906
# After epoch 217 the cost function is 0.7460092163085937
# After epoch 218 the cost function is 0.7537737274169922
# After epoch 219 the cost function is 0.8002635192871094
# After epoch 220 the cost function is 0.8096682739257812
# After epoch 221 the cost function is 0.8188003540039063
# After epoch 222 the cost function is 0.7418152618408204
# After epoch 223 the cost function is 0.7376886749267578
# After epoch 224 the cost function is 0.7623359680175781
# After epoch 225 the cost function is 0.8314886474609375
# After epoch 226 the cost function is 0.7807201385498047
# After epoch 227 the cost function is 0.75305419921875
# After epoch 228 the cost function is 0.7586375427246094
# After epoch 229 the cost function is 0.7432979583740235
# After epoch 230 the cost function is 0.7538328552246094
# After epoch 231 the cost function is 0.733072509765625
# After epoch 232 the cost function is 0.7508549499511719
# After epoch 233 the cost function is 0.7238512420654297
# After epoch 234 the cost function is 0.7354689025878907
# After epoch 235 the cost function is 0.7293791198730468
# After epoch 236 the cost function is 0.7457429504394532
# After epoch 237 the cost function is 0.7302262878417969
# After epoch 238 the cost function is 0.73750244140625
# After epoch 239 the cost function is 0.7272917938232422
# After epoch 240 the cost function is 0.7556932830810547
# After epoch 241 the cost function is 0.7438431549072265
# After epoch 242 the cost function is 0.735474853515625
# After epoch 243 the cost function is 0.8000129699707031
# After epoch 244 the cost function is 0.7321551513671875
# After epoch 245 the cost function is 0.7202451324462891
# After epoch 246 the cost function is 0.7179075622558594
# After epoch 247 the cost function is 0.7067243957519531
# After epoch 248 the cost function is 0.7103117370605468
# After epoch 249 the cost function is 0.7011000061035156
# After epoch 250 the cost function is 0.7003821563720704
# After epoch 251 the cost function is 0.6991673278808593
# After epoch 252 the cost function is 0.6985617065429688
# After epoch 253 the cost function is 0.7021611022949219
# After epoch 254 the cost function is 0.7307746887207032
# After epoch 255 the cost function is 0.7073926544189453
# After epoch 256 the cost function is 0.6969284057617188
# After epoch 257 the cost function is 0.7491482543945313
# After epoch 258 the cost function is 0.7075000762939453
# After epoch 259 the cost function is 0.6794219970703125
# After epoch 260 the cost function is 0.6718278503417969
# After epoch 261 the cost function is 0.6646407318115234
# After epoch 262 the cost function is 0.678167724609375
# After epoch 263 the cost function is 0.6761499786376953
# After epoch 264 the cost function is 0.674711685180664
# After epoch 265 the cost function is 0.6562591552734375
# After epoch 266 the cost function is 0.6482948303222656
# After epoch 267 the cost function is 0.6553924560546875
# After epoch 268 the cost function is 0.6559080505371093
# After epoch 269 the cost function is 0.6661506652832031
# After epoch 270 the cost function is 0.6501914978027343
# After epoch 271 the cost function is 0.6369841766357421
# After epoch 272 the cost function is 0.6298554229736328
# After epoch 273 the cost function is 0.6350784301757812
# After epoch 274 the cost function is 0.6341925048828125
# After epoch 275 the cost function is 0.6392247009277344
# After epoch 276 the cost function is 0.6321794891357422
# After epoch 277 the cost function is 0.618799934387207
# After epoch 278 the cost function is 0.6116073608398438
# After epoch 279 the cost function is 0.6107267761230468
# After epoch 280 the cost function is 0.6137853240966797
# After epoch 281 the cost function is 0.6175597763061523
# After epoch 282 the cost function is 0.6180863952636719
# After epoch 283 the cost function is 0.6176516723632812
# After epoch 284 the cost function is 0.6542214965820312
# After epoch 285 the cost function is 0.6530024719238281
# After epoch 286 the cost function is 0.6158650207519532
# After epoch 287 the cost function is 0.612138786315918
# After epoch 288 the cost function is 0.6028982543945313
# After epoch 289 the cost function is 0.56123046875
# After epoch 290 the cost function is 0.5519960403442383
# After epoch 291 the cost function is 0.5549688720703125
# After epoch 292 the cost function is 0.5792290878295898
# After epoch 293 the cost function is 0.6421295928955079
# After epoch 294 the cost function is 0.6090573120117188
# After epoch 295 the cost function is 0.5886725234985352
# After epoch 296 the cost function is 0.5556474304199219
# After epoch 297 the cost function is 0.6141415786743164
# After epoch 298 the cost function is 0.5142490005493164
# After epoch 299 the cost function is 0.5320079803466797
# After epoch 300 the cost function is 0.5384264755249023
# After epoch 301 the cost function is 0.5730631256103516
# After epoch 302 the cost function is 0.526202735900879
# After epoch 303 the cost function is 0.5101420593261718
# After epoch 304 the cost function is 0.48907989501953125
# After epoch 305 the cost function is 0.5180007171630859
# After epoch 306 the cost function is 0.5465148162841796
# After epoch 307 the cost function is 0.6371767425537109
# After epoch 308 the cost function is 0.4803862762451172
# After epoch 309 the cost function is 0.47513877868652343
# After epoch 310 the cost function is 0.5087799835205078
# After epoch 311 the cost function is 0.5035002136230469
# After epoch 312 the cost function is 0.5298628234863281
# After epoch 313 the cost function is 0.47219440460205075
# After epoch 314 the cost function is 0.47312732696533205
# After epoch 315 the cost function is 0.45070594787597656
# After epoch 316 the cost function is 0.5017659759521484
# After epoch 317 the cost function is 0.5303350067138672
# After epoch 318 the cost function is 0.654404296875
# After epoch 319 the cost function is 0.6001240158081055
# After epoch 320 the cost function is 0.608072624206543
# After epoch 321 the cost function is 0.49794807434082033
# After epoch 322 the cost function is 0.4557740020751953
# After epoch 323 the cost function is 0.4608649444580078
# After epoch 324 the cost function is 0.4972503662109375
# After epoch 325 the cost function is 0.44441123962402346
# After epoch 326 the cost function is 0.46101280212402346
# After epoch 327 the cost function is 0.4249324417114258
# After epoch 328 the cost function is 0.47613330841064455
# After epoch 329 the cost function is 0.4264354705810547
# After epoch 330 the cost function is 0.4308659744262695
# After epoch 331 the cost function is 0.4479865264892578
# After epoch 332 the cost function is 0.47351295471191407
# After epoch 333 the cost function is 0.4287019348144531
# After epoch 334 the cost function is 0.4351880645751953
# After epoch 335 the cost function is 0.416402587890625
# After epoch 336 the cost function is 0.43344146728515626
# After epoch 337 the cost function is 0.42629199981689453
# After epoch 338 the cost function is 0.44793609619140623
# After epoch 339 the cost function is 0.40318855285644534
# After epoch 340 the cost function is 0.4032669448852539
# After epoch 341 the cost function is 0.4067151641845703
# After epoch 342 the cost function is 0.4445909881591797
# After epoch 343 the cost function is 0.4392870330810547
# After epoch 344 the cost function is 0.4556072235107422
# After epoch 345 the cost function is 0.37192535400390625
# After epoch 346 the cost function is 0.3459006881713867
# After epoch 347 the cost function is 0.33930885314941406
# After epoch 348 the cost function is 0.3621372222900391
# After epoch 349 the cost function is 0.3807659912109375
# After epoch 350 the cost function is 0.47455291748046874
# After epoch 351 the cost function is 0.37330318450927735
# After epoch 352 the cost function is 0.3401577377319336
# After epoch 353 the cost function is 0.31831506729125975
# After epoch 354 the cost function is 0.31291013717651367
# After epoch 355 the cost function is 0.3118754386901855
# After epoch 356 the cost function is 0.31655742645263674
# After epoch 357 the cost function is 0.3219382095336914
# After epoch 358 the cost function is 0.3294602203369141
# After epoch 359 the cost function is 0.33360076904296876
# After epoch 360 the cost function is 0.3351020050048828
# After epoch 361 the cost function is 0.3240652084350586
# After epoch 362 the cost function is 0.31759572982788087
# After epoch 363 the cost function is 0.3076510047912598
# After epoch 364 the cost function is 0.30786420822143556
# After epoch 365 the cost function is 0.3017293930053711
# After epoch 366 the cost function is 0.3015389251708984
# After epoch 367 the cost function is 0.28898651123046876
# After epoch 368 the cost function is 0.2854353904724121
# After epoch 369 the cost function is 0.2694088935852051
# After epoch 370 the cost function is 0.2691292190551758
# After epoch 371 the cost function is 0.2582301712036133
# After epoch 372 the cost function is 0.26414289474487307
# After epoch 373 the cost function is 0.25639900207519534
# After epoch 374 the cost function is 0.26788700103759766
# After epoch 375 the cost function is 0.26293071746826174
# After epoch 376 the cost function is 0.2823524475097656
# After epoch 377 the cost function is 0.2907230377197266
# After epoch 378 the cost function is 0.33905696868896484
# After epoch 379 the cost function is 0.3645817947387695
# After epoch 380 the cost function is 0.4296641540527344
# After epoch 381 the cost function is 0.35667991638183594
# After epoch 382 the cost function is 0.31825756072998046
# After epoch 383 the cost function is 0.33258182525634766
# After epoch 384 the cost function is 0.3752028274536133
# After epoch 385 the cost function is 0.4791109848022461
# After epoch 386 the cost function is 0.26810020446777344
# After epoch 387 the cost function is 0.22271350860595704
# After epoch 388 the cost function is 0.2118305206298828
# After epoch 389 the cost function is 0.20719104766845703
# After epoch 390 the cost function is 0.20409744262695312
# After epoch 391 the cost function is 0.20203865051269532
# After epoch 392 the cost function is 0.20221240997314452
# After epoch 393 the cost function is 0.20672718048095703
# After epoch 394 the cost function is 0.21411062240600587
# After epoch 395 the cost function is 0.24522113800048828
# After epoch 396 the cost function is 0.2971901702880859
# After epoch 397 the cost function is 0.46979598999023436
# After epoch 398 the cost function is 0.5090314102172852
# After epoch 399 the cost function is 0.4327064514160156
# After epoch 400 the cost function is 0.4007611083984375
# After epoch 401 the cost function is 0.33743820190429685
# After epoch 402 the cost function is 0.2512139129638672
# After epoch 403 the cost function is 0.261203498840332
# After epoch 404 the cost function is 0.392587890625
# After epoch 405 the cost function is 0.45709251403808593
# After epoch 406 the cost function is 0.4115991973876953
# After epoch 407 the cost function is 0.25006900787353514
# After epoch 408 the cost function is 0.19638805389404296
# After epoch 409 the cost function is 0.19304393768310546
# After epoch 410 the cost function is 0.187973575592041
# After epoch 411 the cost function is 0.20156854629516602
# After epoch 412 the cost function is 0.1861092185974121
# After epoch 413 the cost function is 0.1937538719177246
# After epoch 414 the cost function is 0.1777230453491211
# After epoch 415 the cost function is 0.18332036972045898
# After epoch 416 the cost function is 0.1678897476196289
# After epoch 417 the cost function is 0.16702301025390626
# After epoch 418 the cost function is 0.1564772319793701
# After epoch 419 the cost function is 0.1535065269470215
# After epoch 420 the cost function is 0.1463651180267334
# After epoch 421 the cost function is 0.14277077674865724
# After epoch 422 the cost function is 0.13762223243713378
# After epoch 423 the cost function is 0.13440238952636718
# After epoch 424 the cost function is 0.13051723480224608
# After epoch 425 the cost function is 0.12783742904663087
# After epoch 426 the cost function is 0.12468510627746582
# After epoch 427 the cost function is 0.12239883422851562
# After epoch 428 the cost function is 0.11969314575195313
# After epoch 429 the cost function is 0.11769546508789062
# After epoch 430 the cost function is 0.1153132438659668
# After epoch 431 the cost function is 0.11358552932739258
# After epoch 432 the cost function is 0.1115016746520996
# After epoch 433 the cost function is 0.11012535095214844
# After epoch 434 the cost function is 0.10840156555175781
# After epoch 435 the cost function is 0.1075503921508789
# After epoch 436 the cost function is 0.10625775337219238
# After epoch 437 the cost function is 0.10604072570800781
# After epoch 438 the cost function is 0.10505758285522461
# After epoch 439 the cost function is 0.10529226303100586
# After epoch 440 the cost function is 0.10418245315551758
# After epoch 441 the cost function is 0.1043850326538086
# After epoch 442 the cost function is 0.1025503158569336
# After epoch 443 the cost function is 0.1021484375
# After epoch 444 the cost function is 0.09906399726867676
# After epoch 445 the cost function is 0.09767049789428711
# After epoch 446 the cost function is 0.09325329780578613
# After epoch 447 the cost function is 0.0910432243347168
# After epoch 448 the cost function is 0.0862661361694336
# After epoch 449 the cost function is 0.08383545875549317
# After epoch 450 the cost function is 0.08024082183837891
# After epoch 451 the cost function is 0.07817169189453126
# After epoch 452 the cost function is 0.0759253168106079
# After epoch 453 the cost function is 0.0743189239501953
# After epoch 454 the cost function is 0.0727132511138916
# After epoch 455 the cost function is 0.07135480880737305
# After epoch 456 the cost function is 0.07000738143920898
# After epoch 457 the cost function is 0.06877097129821777
# After epoch 458 the cost function is 0.06754841327667237
# After epoch 459 the cost function is 0.06638442993164062
# After epoch 460 the cost function is 0.0652362060546875
# After epoch 461 the cost function is 0.06412060260772705
# After epoch 462 the cost function is 0.06301569938659668
# After epoch 463 the cost function is 0.06192034721374512
# After epoch 464 the cost function is 0.060811519622802734
# After epoch 465 the cost function is 0.059662461280822754
# After epoch 466 the cost function is 0.05841064453125
# After epoch 467 the cost function is 0.05695315837860107
# After epoch 468 the cost function is 0.05517715454101563
# After epoch 469 the cost function is 0.05323916435241699
# After epoch 470 the cost function is 0.051547269821166995
# After epoch 471 the cost function is 0.05015303134918213
# After epoch 472 the cost function is 0.04895545959472656
# After epoch 473 the cost function is 0.047884159088134766
# After epoch 474 the cost function is 0.046899938583374025
# After epoch 475 the cost function is 0.0459795093536377
# After epoch 476 the cost function is 0.04510737419128418
# After epoch 477 the cost function is 0.04427302360534668
# After epoch 478 the cost function is 0.04346888065338135
# After epoch 479 the cost function is 0.0426894760131836
# After epoch 480 the cost function is 0.041930770874023436
# After epoch 481 the cost function is 0.04118980407714844
# After epoch 482 the cost function is 0.040464444160461424
# After epoch 483 the cost function is 0.039753158092498776
# After epoch 484 the cost function is 0.03905496120452881
# After epoch 485 the cost function is 0.03836925745010376
# After epoch 486 the cost function is 0.03769582033157349
# After epoch 487 the cost function is 0.03703466892242432
# After epoch 488 the cost function is 0.03638604640960694
# After epoch 489 the cost function is 0.03575031995773315
# After epoch 490 the cost function is 0.03512795925140381
# After epoch 491 the cost function is 0.03451941967010498
# After epoch 492 the cost function is 0.03392515182495117
# After epoch 493 the cost function is 0.0333455228805542
# After epoch 494 the cost function is 0.03278079986572266
# After epoch 495 the cost function is 0.03223115921020508
# After epoch 496 the cost function is 0.031696629524230954
# After epoch 497 the cost function is 0.0311771559715271
# After epoch 498 the cost function is 0.03067258358001709
# After epoch 499 the cost function is 0.03018264293670654
# After epoch 500 the cost function is 0.029707038402557374
# After epoch 501 the cost function is 0.029245383739471435
# After epoch 502 the cost function is 0.02879728078842163
# After epoch 503 the cost function is 0.028362298011779787
# After epoch 504 the cost function is 0.027939977645874022
# After epoch 505 the cost function is 0.027529873847961427
# After epoch 506 the cost function is 0.02713152885437012
# After epoch 507 the cost function is 0.026744489669799806
# After epoch 508 the cost function is 0.026368322372436522
# After epoch 509 the cost function is 0.026002607345581054
# After epoch 510 the cost function is 0.025646915435791017
# After epoch 511 the cost function is 0.02530086040496826
# After epoch 512 the cost function is 0.024964056015014648
# After epoch 513 the cost function is 0.024636130332946777
# After epoch 514 the cost function is 0.024316749572753905
# After epoch 515 the cost function is 0.024005565643310547
# After epoch 516 the cost function is 0.023702263832092285
# After epoch 517 the cost function is 0.02340653896331787
# After epoch 518 the cost function is 0.023118104934692383
# After epoch 519 the cost function is 0.022836685180664062
# After epoch 520 the cost function is 0.02256202220916748
# After epoch 521 the cost function is 0.022293858528137207
# After epoch 522 the cost function is 0.022031962871551514
# After epoch 523 the cost function is 0.021776111125946046
# After epoch 524 the cost function is 0.021526081562042235
# After epoch 525 the cost function is 0.021281676292419435
# After epoch 526 the cost function is 0.021042697429656983
# After epoch 527 the cost function is 0.020808959007263185
# After epoch 528 the cost function is 0.020580282211303712
# After epoch 529 the cost function is 0.020356500148773195
# After epoch 530 the cost function is 0.020137453079223634
# After epoch 531 the cost function is 0.019922982454299926
# After epoch 532 the cost function is 0.019712947607040406
# After epoch 533 the cost function is 0.01950720191001892
# After epoch 534 the cost function is 0.019305610656738283
# After epoch 535 the cost function is 0.019108049869537354
# After epoch 536 the cost function is 0.01891439437866211
# After epoch 537 the cost function is 0.018724524974823
# After epoch 538 the cost function is 0.01853832960128784
# After epoch 539 the cost function is 0.018355699777603148
# After epoch 540 the cost function is 0.01817652940750122
# After epoch 541 the cost function is 0.01800072431564331
# After epoch 542 the cost function is 0.017828183174133302
# After epoch 543 the cost function is 0.01765881299972534
# After epoch 544 the cost function is 0.017492527961730956
# After epoch 545 the cost function is 0.017329246997833253
# After epoch 546 the cost function is 0.017168880701065065
# After epoch 547 the cost function is 0.017011356353759766
# After epoch 548 the cost function is 0.016856589317321778
# After epoch 549 the cost function is 0.016704518795013428
# After epoch 550 the cost function is 0.016555063724517823
# After epoch 551 the cost function is 0.016408162117004396
# After epoch 552 the cost function is 0.01626374840736389
# After epoch 553 the cost function is 0.01612175703048706
# After epoch 554 the cost function is 0.01598212480545044
# After epoch 555 the cost function is 0.01584479808807373
# After epoch 556 the cost function is 0.01570971727371216
# After epoch 557 the cost function is 0.01557682991027832
# After epoch 558 the cost function is 0.015446076393127442
# After epoch 559 the cost function is 0.015317411422729492
# After epoch 560 the cost function is 0.015190781354904174
# After epoch 561 the cost function is 0.015066142082214356
# After epoch 562 the cost function is 0.014943444728851318
# After epoch 563 the cost function is 0.014822642803192138
# After epoch 564 the cost function is 0.014703694581985473
# After epoch 565 the cost function is 0.014586559534072875
# After epoch 566 the cost function is 0.014471193552017212
# After epoch 567 the cost function is 0.01435755729675293
# After epoch 568 the cost function is 0.014245615005493165
# After epoch 569 the cost function is 0.014135321378707886
# After epoch 570 the cost function is 0.014026647806167603
# After epoch 571 the cost function is 0.013919559717178344
# After epoch 572 the cost function is 0.013814018964767456
# After epoch 573 the cost function is 0.013709994554519654
# After epoch 574 the cost function is 0.013607451915740967
# After epoch 575 the cost function is 0.013506362438201905
# After epoch 576 the cost function is 0.013406692743301392
# After epoch 577 the cost function is 0.013308414220809937
# After epoch 578 the cost function is 0.013211500644683839
# After epoch 579 the cost function is 0.013115923404693603
# After epoch 580 the cost function is 0.013021652698516845
# After epoch 581 the cost function is 0.012928661108016968
# After epoch 582 the cost function is 0.012836928367614747
# After epoch 583 the cost function is 0.012746424674987792
# After epoch 584 the cost function is 0.012657127380371093
# After epoch 585 the cost function is 0.012569012641906739
# After epoch 586 the cost function is 0.012482059001922608
# After epoch 587 the cost function is 0.012396240234375
# After epoch 588 the cost function is 0.012311536073684692
# After epoch 589 the cost function is 0.012227928638458252
# After epoch 590 the cost function is 0.012145394086837768
# After epoch 591 the cost function is 0.012063908576965331
# After epoch 592 the cost function is 0.011983458995819091
# After epoch 593 the cost function is 0.011904020309448243
# After epoch 594 the cost function is 0.011825579404830932
# After epoch 595 the cost function is 0.01174811363220215
# After epoch 596 the cost function is 0.011671607494354247
# After epoch 597 the cost function is 0.011596040725708008
# After epoch 598 the cost function is 0.011521397829055787
# After epoch 599 the cost function is 0.01144766092300415
# After epoch 600 the cost function is 0.011374820470809937
# After epoch 601 the cost function is 0.01130285143852234
# After epoch 602 the cost function is 0.011231744289398193
# After epoch 603 the cost function is 0.011161479949951172
# After epoch 604 the cost function is 0.01109204649925232
# After epoch 605 the cost function is 0.0110234272480011
# After epoch 606 the cost function is 0.010955612659454345
# After epoch 607 the cost function is 0.010888583660125732
# After epoch 608 the cost function is 0.010822329521179199
# After epoch 609 the cost function is 0.0107568359375
# After epoch 610 the cost function is 0.01069209337234497
# After epoch 611 the cost function is 0.010628083944320679
# After epoch 612 the cost function is 0.010564799308776856
# After epoch 613 the cost function is 0.010502225160598755
# After epoch 614 the cost function is 0.010440349578857422
# After epoch 615 the cost function is 0.010379164218902589
# After epoch 616 the cost function is 0.010318657159805298
# After epoch 617 the cost function is 0.01025881290435791
# After epoch 618 the cost function is 0.010199625492095948
# After epoch 619 the cost function is 0.010141081809997558
# After epoch 620 the cost function is 0.010083174705505371
# After epoch 621 the cost function is 0.010025889873504638
# After epoch 622 the cost function is 0.009969221353530884
# After epoch 623 the cost function is 0.009913156032562256
# After epoch 624 the cost function is 0.009857687950134277
# After epoch 625 the cost function is 0.009802803993225098
# After epoch 626 the cost function is 0.00974849820137024
# After epoch 627 the cost function is 0.00969476044178009
# After epoch 628 the cost function is 0.009641581773757934
# After epoch 629 the cost function is 0.009588953256607056
# After epoch 630 the cost function is 0.00953686773777008
# After epoch 631 the cost function is 0.009485317468643189
# After epoch 632 the cost function is 0.009434292316436768
# After epoch 633 the cost function is 0.00938378632068634
# After epoch 634 the cost function is 0.009333789944648743
# After epoch 635 the cost function is 0.009284296035766602
# After epoch 636 the cost function is 0.009235299825668335
# After epoch 637 the cost function is 0.00918678879737854
# After epoch 638 the cost function is 0.009138761162757874
# After epoch 639 the cost function is 0.00909120798110962
# After epoch 640 the cost function is 0.009044123888015747
# After epoch 641 the cost function is 0.008997496962547303
# After epoch 642 the cost function is 0.008951326608657837
# After epoch 643 the cost function is 0.00890560269355774
# After epoch 644 the cost function is 0.008860318660736085
# After epoch 645 the cost function is 0.008815473318099976
# After epoch 646 the cost function is 0.008771052956581116
# After epoch 647 the cost function is 0.008727055788040162
# After epoch 648 the cost function is 0.00868347704410553
# After epoch 649 the cost function is 0.008640309572219848
# After epoch 650 the cost function is 0.00859754741191864
# After epoch 651 the cost function is 0.008555185794830323
# After epoch 652 the cost function is 0.008513216972351073
# After epoch 653 the cost function is 0.008471637368202209
# After epoch 654 the cost function is 0.00843044102191925
# After epoch 655 the cost function is 0.008389623761177063
# After epoch 656 the cost function is 0.008349182605743409
# After epoch 657 the cost function is 0.008309105634689331
# After epoch 658 the cost function is 0.008269394636154176
# After epoch 659 the cost function is 0.008230042457580567
# After epoch 660 the cost function is 0.008191043138504028
# After epoch 661 the cost function is 0.008152393102645874
# After epoch 662 the cost function is 0.008114088177680969
# After epoch 663 the cost function is 0.008076123595237732
# After epoch 664 the cost function is 0.00803849458694458
# After epoch 665 the cost function is 0.008001196384429931
# After epoch 666 the cost function is 0.007964226007461548
# After epoch 667 the cost function is 0.007927578687667847
# After epoch 668 the cost function is 0.007891250848770142
# After epoch 669 the cost function is 0.007855236530303955
# After epoch 670 the cost function is 0.007819531559944153
# After epoch 671 the cost function is 0.007784136533737183
# After epoch 672 the cost function is 0.007749042510986328
# After epoch 673 the cost function is 0.007714248299598694
# After epoch 674 the cost function is 0.007679749131202698
# After epoch 675 the cost function is 0.007645541429519653
# After epoch 676 the cost function is 0.0076116216182708744
# After epoch 677 the cost function is 0.007577987909317016
# After epoch 678 the cost function is 0.007544635534286499
# After epoch 679 the cost function is 0.007511560916900635
# After epoch 680 the cost function is 0.007478758096694947
# After epoch 681 the cost function is 0.007446225881576538
# After epoch 682 the cost function is 0.00741396427154541
# After epoch 683 the cost function is 0.007381964921951294
# After epoch 684 the cost function is 0.0073502278327941895
# After epoch 685 the cost function is 0.0073187494277954105
# After epoch 686 the cost function is 0.007287524342536926
# After epoch 687 the cost function is 0.00725655198097229
# After epoch 688 the cost function is 0.007225828170776367
# After epoch 689 the cost function is 0.00719535231590271
# After epoch 690 the cost function is 0.007165119051933289
# After epoch 691 the cost function is 0.007135125398635864
# After epoch 692 the cost function is 0.007105368375778198
# After epoch 693 the cost function is 0.007075848579406738
# After epoch 694 the cost function is 0.007046558260917664
# After epoch 695 the cost function is 0.007017499208450318
# After epoch 696 the cost function is 0.00698866605758667
# After epoch 697 the cost function is 0.006960058212280273
# After epoch 698 the cost function is 0.006931671500205993
# After epoch 699 the cost function is 0.006903502941131592
# After epoch 700 the cost function is 0.00687555193901062
# After epoch 701 the cost function is 0.00684781551361084
# After epoch 702 the cost function is 0.006820290088653564
# After epoch 703 the cost function is 0.006792974472045898
# After epoch 704 the cost function is 0.0067658662796020504
# After epoch 705 the cost function is 0.006738961935043335
# After epoch 706 the cost function is 0.006712261438369751
# After epoch 707 the cost function is 0.006685761213302613
# After epoch 708 the cost function is 0.006659457683563233
# After epoch 709 the cost function is 0.006633350253105163
# After epoch 710 the cost function is 0.006607437133789062
# After epoch 711 the cost function is 0.006581717133522034
# After epoch 712 the cost function is 0.006556184887886047
# After epoch 713 the cost function is 0.006530839800834656
# After epoch 714 the cost function is 0.006505681276321411
# After epoch 715 the cost function is 0.006480706334114075
# After epoch 716 the cost function is 0.006455912590026856
# After epoch 717 the cost function is 0.00643129825592041
# After epoch 718 the cost function is 0.006406862735748291
# After epoch 719 the cost function is 0.006382601261138916
# After epoch 720 the cost function is 0.00635851502418518
# After epoch 721 the cost function is 0.006334601640701294
# After epoch 722 the cost function is 0.006310857534408569
# After epoch 723 the cost function is 0.006287281513214111
# After epoch 724 the cost function is 0.00626387357711792
# After epoch 725 the cost function is 0.006240630149841308
# After epoch 726 the cost function is 0.006217550039291381
# After epoch 727 the cost function is 0.006194630861282349
# After epoch 728 the cost function is 0.006171873211860657
# After epoch 729 the cost function is 0.00614927351474762
# After epoch 730 the cost function is 0.0061268311738967894
# After epoch 731 the cost function is 0.00610454261302948
# After epoch 732 the cost function is 0.006082409024238586
# After epoch 733 the cost function is 0.0060604274272918705
# After epoch 734 the cost function is 0.006038596630096435
# After epoch 735 the cost function is 0.006016912460327148
# After epoch 736 the cost function is 0.0059953778982162476
# After epoch 737 the cost function is 0.005973989963531494
# After epoch 738 the cost function is 0.005952744483947754
# After epoch 739 the cost function is 0.005931644439697265
# After epoch 740 the cost function is 0.005910685062408447
# After epoch 741 the cost function is 0.005889865159988403
# After epoch 742 the cost function is 0.0058691871166229245
# After epoch 743 the cost function is 0.005848643779754639
# After epoch 744 the cost function is 0.005828238129615784
# After epoch 745 the cost function is 0.005807966589927673
# After epoch 746 the cost function is 0.005787830352783203
# After epoch 747 the cost function is 0.005767825245857239
# After epoch 748 the cost function is 0.00574795126914978
# After epoch 749 the cost function is 0.005728207230567932
# After epoch 750 the cost function is 0.005708590745925903
# After epoch 751 the cost function is 0.005689104795455932
# After epoch 752 the cost function is 0.005669742822647095
# After epoch 753 the cost function is 0.005650505423545837
# After epoch 754 the cost function is 0.005631392002105713
# After epoch 755 the cost function is 0.005612400770187378
# After epoch 756 the cost function is 0.005593531131744385
# After epoch 757 the cost function is 0.005574783086776733
# After epoch 758 the cost function is 0.005556153655052185
# After epoch 759 the cost function is 0.005537642240524292
# After epoch 760 the cost function is 0.005519246459007263
# After epoch 761 the cost function is 0.0055009680986404415
# After epoch 762 the cost function is 0.005482803583145141
# After epoch 763 the cost function is 0.005464754104614258
# After epoch 764 the cost function is 0.005446817874908447
# After epoch 765 the cost function is 0.005428990721702576
# After epoch 766 the cost function is 0.0054112768173217776
# After epoch 767 the cost function is 0.005393670201301575
# After epoch 768 the cost function is 0.005376173853874206
# After epoch 769 the cost function is 0.005358784198760986
# After epoch 770 the cost function is 0.005341501235961914
# After epoch 771 the cost function is 0.0053243255615234375
# After epoch 772 the cost function is 0.00530725359916687
# After epoch 773 the cost function is 0.005290286540985107
# After epoch 774 the cost function is 0.005273420214653015
# After epoch 775 the cost function is 0.005256657600402832
# After epoch 776 the cost function is 0.0052399951219558715
# After epoch 777 the cost function is 0.005223433971405029
# After epoch 778 the cost function is 0.0052069717645645145
# After epoch 779 the cost function is 0.005190607905387878
# After epoch 780 the cost function is 0.005174341201782226
# After epoch 781 the cost function is 0.005158171057701111
# After epoch 782 the cost function is 0.005142097473144531
# After epoch 783 the cost function is 0.0051261186599731445
# After epoch 784 the cost function is 0.00511023461818695
# After epoch 785 the cost function is 0.0050944435596466065
# After epoch 786 the cost function is 0.005078744888305664
# After epoch 787 the cost function is 0.005063138008117676
# After epoch 788 the cost function is 0.005047621726989746
# After epoch 789 the cost function is 0.00503219723701477
# After epoch 790 the cost function is 0.005016860961914063
# After epoch 791 the cost function is 0.005001614093780518
# After epoch 792 the cost function is 0.004986454546451568
# After epoch 793 the cost function is 0.00497138261795044
# After epoch 794 the cost function is 0.004956396520137787
# After epoch 795 the cost function is 0.004941497445106507
# After epoch 796 the cost function is 0.004926683604717255
# After epoch 797 the cost function is 0.004911953210830688
# After epoch 798 the cost function is 0.004897306561470032
# After epoch 799 the cost function is 0.004882741570472717
# After epoch 800 the cost function is 0.004868260622024536
# After epoch 801 the cost function is 0.004853861033916473
# After epoch 802 the cost function is 0.004839540719985962
# After epoch 803 the cost function is 0.004825302362442017
# After epoch 804 the cost function is 0.0048111420869827275
# After epoch 805 the cost function is 0.0047970619797706605
# After epoch 806 the cost function is 0.004783059358596802
# After epoch 807 the cost function is 0.004769135713577271
# After epoch 808 the cost function is 0.004755286872386933
# After epoch 809 the cost function is 0.00474151611328125
# After epoch 810 the cost function is 0.004727819561958313
# After epoch 811 the cost function is 0.004714198410511017
# After epoch 812 the cost function is 0.004700654149055481
# After epoch 813 the cost function is 0.004687181413173675
# After epoch 814 the cost function is 0.004673782885074616
# After epoch 815 the cost function is 0.004660456478595734
# After epoch 816 the cost function is 0.004647202789783478
# After epoch 817 the cost function is 0.004634019732475281
# After epoch 818 the cost function is 0.0046209082007408146
# After epoch 819 the cost function is 0.004607867002487182
# After epoch 820 the cost function is 0.00459489643573761
# After epoch 821 the cost function is 0.004581995010375976
# After epoch 822 the cost function is 0.004569161236286163
# After epoch 823 the cost function is 0.004556398391723632
# After epoch 824 the cost function is 0.004543700814247131
# After epoch 825 the cost function is 0.004531070590019226
# After epoch 826 the cost function is 0.004518508613109588
# After epoch 827 the cost function is 0.004506011009216309
# After epoch 828 the cost function is 0.004493580460548401
# After epoch 829 the cost function is 0.004481214880943298
# After epoch 830 the cost function is 0.004468913078308105
# After epoch 831 the cost function is 0.0044566762447357175
# After epoch 832 the cost function is 0.004444502592086792
# After epoch 833 the cost function is 0.004432392716407776
# After epoch 834 the cost function is 0.004420343935489655
# After epoch 835 the cost function is 0.004408358931541443
# After epoch 836 the cost function is 0.004396435022354126
# After epoch 837 the cost function is 0.004384572803974152
# After epoch 838 the cost function is 0.0043727710843086244
# After epoch 839 the cost function is 0.004361029863357544
# After epoch 840 the cost function is 0.0043493488430976866
# After epoch 841 the cost function is 0.004337726533412934
# After epoch 842 the cost function is 0.004326163530349731
# After epoch 843 the cost function is 0.004314658641815186
# After epoch 844 the cost function is 0.004303213059902191
# After epoch 845 the cost function is 0.004291824698448181
# After epoch 846 the cost function is 0.004280493259429931
# After epoch 847 the cost function is 0.004269219636917114
# After epoch 848 the cost function is 0.00425800085067749
# After epoch 849 the cost function is 0.0042468392848968506
# After epoch 850 the cost function is 0.00423573225736618
# After epoch 851 the cost function is 0.004224680662155152
# After epoch 852 the cost function is 0.004213685393333435
# After epoch 853 the cost function is 0.004202743172645569
# After epoch 854 the cost function is 0.004191854596138
# After epoch 855 the cost function is 0.004181019961833954
# After epoch 856 the cost function is 0.0041702395677566525
# After epoch 857 the cost function is 0.004159510731697082
# After epoch 858 the cost function is 0.004148835241794586
# After epoch 859 the cost function is 0.004138210117816925
# After epoch 860 the cost function is 0.004127638339996338
# After epoch 861 the cost function is 0.004117118120193481
# After epoch 862 the cost function is 0.004106647968292236
# After epoch 863 the cost function is 0.00409622848033905
# After epoch 864 the cost function is 0.004085859656333924
# After epoch 865 the cost function is 0.00407554030418396
# After epoch 866 the cost function is 0.004065271615982056
# After epoch 867 the cost function is 0.004055050611495972
# After epoch 868 the cost function is 0.004044879078865051
# After epoch 869 the cost function is 0.004034755825996399
# After epoch 870 the cost function is 0.004024681448936462
# After epoch 871 the cost function is 0.004014654755592346
# After epoch 872 the cost function is 0.004004673957824707
# After epoch 873 the cost function is 0.003994742631912232
# After epoch 874 the cost function is 0.003984856605529785
# After epoch 875 the cost function is 0.003975017070770264
# After epoch 876 the cost function is 0.003965224623680114
# After epoch 877 the cost function is 0.003955476880073547
# After epoch 878 the cost function is 0.003945775628089905
# After epoch 879 the cost function is 0.003936117887496949
# After epoch 880 the cost function is 0.003926507234573364
# After epoch 881 the cost function is 0.00391694039106369
# After epoch 882 the cost function is 0.003907417953014374
# After epoch 883 the cost function is 0.0038979405164718626
# After epoch 884 the cost function is 0.0038885051012039185
# After epoch 885 the cost function is 0.0038791131973266602
# After epoch 886 the cost function is 0.0038697654008865356
# After epoch 887 the cost function is 0.0038604605197906493
# After epoch 888 the cost function is 0.0038511961698532104
# After epoch 889 the cost function is 0.003841977119445801
# After epoch 890 the cost function is 0.0038327980041503906
# After epoch 891 the cost function is 0.0038236609101295472
# After epoch 892 the cost function is 0.0038145652413368227
# After epoch 893 the cost function is 0.0038055109977722166
# After epoch 894 the cost function is 0.0037964975833892824
# After epoch 895 the cost function is 0.003787524104118347
# After epoch 896 the cost function is 0.003778591752052307
# After epoch 897 the cost function is 0.0037696993350982665
# After epoch 898 the cost function is 0.0037608462572097778
# After epoch 899 the cost function is 0.0037520328164100647
# After epoch 900 the cost function is 0.0037432587146759033
# After epoch 901 the cost function is 0.0037345248460769653
# After epoch 902 the cost function is 0.0037258273363113405
# After epoch 903 the cost function is 0.003717169463634491
# After epoch 904 the cost function is 0.0037085509300231936
# After epoch 905 the cost function is 0.0036999690532684326
# After epoch 906 the cost function is 0.003691425323486328
# After epoch 907 the cost function is 0.0036829188466072083
# After epoch 908 the cost function is 0.003674450516700745
# After epoch 909 the cost function is 0.003666017949581146
# After epoch 910 the cost function is 0.0036576229333877565
# After epoch 911 the cost function is 0.0036492639780044554
# After epoch 912 the cost function is 0.0036409419775009157
# After epoch 913 the cost function is 0.0036326557397842406
# After epoch 914 the cost function is 0.003624405264854431
# After epoch 915 the cost function is 0.0036161911487579347
# After epoch 916 the cost function is 0.0036080121994018556
# After epoch 917 the cost function is 0.003599867522716522
# After epoch 918 the cost function is 0.0035917580127716063
# After epoch 919 the cost function is 0.003583683967590332
# After epoch 920 the cost function is 0.0035756444931030274
# After epoch 921 the cost function is 0.003567638397216797
# After epoch 922 the cost function is 0.0035596674680709837
# After epoch 923 the cost function is 0.0035517296195030214
# After epoch 924 the cost function is 0.003543824553489685
# After epoch 925 the cost function is 0.0035359546542167663
# After epoch 926 the cost function is 0.0035281172394752503
# After epoch 927 the cost function is 0.0035203126072883605
# After epoch 928 the cost function is 0.003512542247772217
# After epoch 929 the cost function is 0.0035048025846481324
# After epoch 930 the cost function is 0.003497096300125122
# After epoch 931 the cost function is 0.0034894216060638427
# After epoch 932 the cost function is 0.00348177969455719
# After epoch 933 the cost function is 0.003474169373512268
# After epoch 934 the cost function is 0.0034665897488594054
# After epoch 935 the cost function is 0.0034590429067611695
# After epoch 936 the cost function is 0.0034515273571014402
# After epoch 937 the cost function is 0.003444041907787323
# After epoch 938 the cost function is 0.003436587452888489
# After epoch 939 the cost function is 0.0034291645884513854
# After epoch 940 the cost function is 0.00342177152633667
# After epoch 941 the cost function is 0.0034144085645675657
# After epoch 942 the cost function is 0.0034070765972137452
# After epoch 943 the cost function is 0.003399773836135864
# After epoch 944 the cost function is 0.003392501473426819
# After epoch 945 the cost function is 0.0033852574229240417
# After epoch 946 the cost function is 0.0033780446648597716
# After epoch 947 the cost function is 0.00337086021900177
# After epoch 948 the cost function is 0.0033637043833732606
# After epoch 949 the cost function is 0.0033565786480903624
# After epoch 950 the cost function is 0.003349480628967285
# After epoch 951 the cost function is 0.003342410326004028
# After epoch 952 the cost function is 0.0033353698253631592
# After epoch 953 the cost function is 0.0033283579349517823
# After epoch 954 the cost function is 0.003321372866630554
# After epoch 955 the cost function is 0.0033144155144691468
# After epoch 956 the cost function is 0.0033074867725372313
# After epoch 957 the cost function is 0.003300585150718689
# After epoch 958 the cost function is 0.003293711841106415
# After epoch 959 the cost function is 0.0032868644595146178
# After epoch 960 the cost function is 0.0032800447940826414
# After epoch 961 the cost function is 0.003273252248764038
# After epoch 962 the cost function is 0.003266485929489136
# After epoch 963 the cost function is 0.0032597458362579345
# After epoch 964 the cost function is 0.003253032863140106
# After epoch 965 the cost function is 0.003246346116065979
# After epoch 966 the cost function is 0.003239685595035553
# After epoch 967 the cost function is 0.00323305070400238
# After epoch 968 the cost function is 0.003226441740989685
# After epoch 969 the cost function is 0.0032198584079742433
# After epoch 970 the cost function is 0.0032133013010025024
# After epoch 971 the cost function is 0.0032067692279815676
# After epoch 972 the cost function is 0.003200262188911438
# After epoch 973 the cost function is 0.003193780183792114
# After epoch 974 the cost function is 0.0031873232126235964
# After epoch 975 the cost function is 0.0031808915734291075
# After epoch 976 the cost function is 0.003174484074115753
# After epoch 977 the cost function is 0.0031681016087532045
# After epoch 978 the cost function is 0.0031617435812950133
# After epoch 979 the cost function is 0.003155409097671509
# After epoch 980 the cost function is 0.00314909964799881
# After epoch 981 the cost function is 0.0031428128480911256
# After epoch 982 the cost function is 0.0031365507841110227
# After epoch 983 the cost function is 0.003130313456058502
# After epoch 984 the cost function is 0.0031240984797477724
# After epoch 985 the cost function is 0.003117906451225281
# After epoch 986 the cost function is 0.003111739456653595
# After epoch 987 the cost function is 0.0031055939197540284
# After epoch 988 the cost function is 0.0030994725227355955
# After epoch 989 the cost function is 0.0030933743715286254
# After epoch 990 the cost function is 0.0030872976779937745
# After epoch 991 the cost function is 0.0030812454223632813
# After epoch 992 the cost function is 0.0030752146244049073
# After epoch 993 the cost function is 0.0030692058801651003
# After epoch 994 the cost function is 0.003063220977783203
# After epoch 995 the cost function is 0.00305725634098053
# After epoch 996 the cost function is 0.003051314949989319
# After epoch 997 the cost function is 0.003045395612716675
# After epoch 998 the cost function is 0.0030394983291625976
# After epoch 999 the cost function is 0.0030336225032806395

# %% [markdown]
# Let's also look at the accuracy. Start running the cell below to generate the plots.  This will take awhile to run, so while it's running, make a prediction for what you think the accuracy of the training data will be. Sketch your prediction.
#
# **What is the highest accuracy you think we can achieve for the training data?**
#
# **At that same time, what do you think the accuracy of the validation set will be?**

# %%
target = get_target(label_100)
target_valid = get_target(label_valid[:100])
acc_train_100 = []
acc_valid_100 = []
for model, epoch in zip(models_100, range(len(models_100))):
  if epoch % 10 == 0:
    print("On epoch ", epoch, " of ", len(models_100))

  pred = model(torch.tensor(image_train[:100], device=device))
  acc_train_100.append(accuracy(pred, target))


  pred = model(torch.tensor(image_valid[:100], device=device))
  acc_valid_100.append(accuracy(pred, target_valid))
print("Done calculating accuracy. Run next cell for plot")
# Out:
# On epoch  0  of  1000
# On epoch  10  of  1000
# On epoch  20  of  1000
# On epoch  30  of  1000
# On epoch  40  of  1000
# On epoch  50  of  1000
# On epoch  60  of  1000
# On epoch  70  of  1000
# On epoch  80  of  1000
# On epoch  90  of  1000
# On epoch  100  of  1000
# On epoch  110  of  1000
# On epoch  120  of  1000
# On epoch  130  of  1000
# On epoch  140  of  1000
# On epoch  150  of  1000
# On epoch  160  of  1000
# On epoch  170  of  1000
# On epoch  180  of  1000
# On epoch  190  of  1000
# On epoch  200  of  1000
# On epoch  210  of  1000
# On epoch  220  of  1000
# On epoch  230  of  1000
# On epoch  240  of  1000
# On epoch  250  of  1000
# On epoch  260  of  1000
# On epoch  270  of  1000
# On epoch  280  of  1000
# On epoch  290  of  1000
# On epoch  300  of  1000
# On epoch  310  of  1000
# On epoch  320  of  1000
# On epoch  330  of  1000
# On epoch  340  of  1000
# On epoch  350  of  1000
# On epoch  360  of  1000
# On epoch  370  of  1000
# On epoch  380  of  1000
# On epoch  390  of  1000
# On epoch  400  of  1000
# On epoch  410  of  1000
# On epoch  420  of  1000
# On epoch  430  of  1000
# On epoch  440  of  1000
# On epoch  450  of  1000
# On epoch  460  of  1000
# On epoch  470  of  1000
# On epoch  480  of  1000
# On epoch  490  of  1000
# On epoch  500  of  1000
# On epoch  510  of  1000
# On epoch  520  of  1000
# On epoch  530  of  1000
# On epoch  540  of  1000
# On epoch  550  of  1000
# On epoch  560  of  1000
# On epoch  570  of  1000
# On epoch  580  of  1000
# On epoch  590  of  1000
# On epoch  600  of  1000
# On epoch  610  of  1000
# On epoch  620  of  1000
# On epoch  630  of  1000
# On epoch  640  of  1000
# On epoch  650  of  1000
# On epoch  660  of  1000
# On epoch  670  of  1000
# On epoch  680  of  1000
# On epoch  690  of  1000
# On epoch  700  of  1000
# On epoch  710  of  1000
# On epoch  720  of  1000
# On epoch  730  of  1000
# On epoch  740  of  1000
# On epoch  750  of  1000
# On epoch  760  of  1000
# On epoch  770  of  1000
# On epoch  780  of  1000
# On epoch  790  of  1000
# On epoch  800  of  1000
# On epoch  810  of  1000
# On epoch  820  of  1000
# On epoch  830  of  1000
# On epoch  840  of  1000
# On epoch  850  of  1000
# On epoch  860  of  1000
# On epoch  870  of  1000
# On epoch  880  of  1000
# On epoch  890  of  1000
# On epoch  900  of  1000
# On epoch  910  of  1000
# On epoch  920  of  1000
# On epoch  930  of  1000
# On epoch  940  of  1000
# On epoch  950  of  1000
# On epoch  960  of  1000
# On epoch  970  of  1000
# On epoch  980  of  1000
# On epoch  990  of  1000
# Done calculating accuracy. Run next cell for plot

# %%
log_model = lambda x, a, b, c, d: a/(1+np.exp(-b*(x-c))) + d

trunc_epoch = epochs_100[0:]
trunc_train = costs_100[0:]
trunc_valid = costs_valid_100[0:]

params, cov = curve_fit(log_model, trunc_epoch, acc_train_100, p0=[.9, 1, 40, .12])
model_train = log_model(np.array(trunc_epoch), *params)
print(f"The carrying capacity of the cost curve for the training data is {(params[0]+params[3])*100:.2f}%.")

# plot the cost function as a function of epoch
fig = plt.figure(figsize=(8,6))
plt.title("Accuracy vs. training epoch")
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(which='both', axis='both')
#plt.plot(epochs_100, acc_train_100, 'r-', label="Training set")
plt.plot(epochs_100, acc_valid_100, 'b-', label="Validation set")
#plt.plot(epochs_100, model_train, 'r--', label="Logistic fit")
#plt.plot(epochs_100, model_valid, 'b--', label="Validation set")
plt.legend()
plt.show()

fig = plt.figure(figsize=(8,6))
plt.title("Accuracy vs. training epoch")
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(which='both', axis='both')
plt.plot(epochs_100, acc_train_100, 'r-', label="Training set")
#plt.plot(epochs_100, acc_valid_100, 'b-', label="Validation set")
plt.plot(epochs_100, model_train, 'r--', label="Logistic fit")
#plt.plot(epochs_100, model_valid, 'b--', label="Validation set")
plt.legend()
plt.show()
# Out:
# The carrying capacity of the cost curve for the training data is 100.55%.

# %% [markdown]
# **Compare your prediction to what you saw in the above plot.**
#
# **What is the maximum accuracy of the training set with 100 example? With 50,000 examples?**
#
# **Why can our model memorize the smaller training set, but not the larger training set? How could we modify our model so it could learn the full training set?**
#
# **Why do you think the accuracy on the validation set is sometimes increasing? What accuracy is it trending towards?**

# %% [markdown]
# # Bad data, bad model
#
# We just trained a model that achieved 99% accuracy! That is right there with the world's best models for this problem, right? There's just one problem. It performs worse then guessing on any image it hasn't seen before. Not the most useful model, is it? This is an example of **over-training** or **over-fitting**. We hyper-specalize our model to the point of uselessness. We saw this even before we taught our model to memorize 100 images. In the first model we trained in this notebook the cost function of the validation set began creeping up over time even as the cost function of the training set continued to fall. That's a clear sign that we began to over-fit our model.
#
# # Universality of Neural Networks
# In any machine learning model, the data used to train it is the *most* important component. [The Universal Approximation Theorem](https://towardsdatascience.com/neural-networks-and-the-universal-approximation-theorem-8a389a33d30a) guarantees that a neural network (with enough complexity) can be used to approximate *any* function, regardless of the number of inputs or outputs. Assuming of course, we have enough examples of the function to show the neural net.
#
# The fact that you need data to train any useful model is, I would argue, one of the [dominant forces in the economy](https://www.economist.com/special-report/2020-02-22) (particularly in the tech sector). Any company that provides a free service on the internet (social media, Google, etc.) is probably in the business of collecting and using user data. This is often the driving force (or at least *a* driving force) behind decisions around availability of data through APIs. In the past year, [Twitter](https://www.theverge.com/2023/2/2/23582615/twitter-removing-free-api-developer-apps-price-announcement) and [Reddit](https://en.wikipedia.org/wiki/2023_Reddit_API_controversy) both made large changes to their API pricing structures. Reddit's CEO has [talked explicitly](https://www.nytimes.com/2023/04/18/technology/reddit-ai-openai-google.html) about how the change is motivated by a desire to profit off of the data (post and comments on reddit) that is being used to train large language models like the one that underlies ChatGPT.

# %% [markdown]
# # Homework
#
# Pick some situation where you encounter (or thing you encounter) some machine learning based model or algorithm. Suppose you were to design that algorithm:
#
# 1. What is the algorithm doing?
# 1. What is the cost function for the algorithm?
# 1. What data would you need to train this model? What are the inputs and outputs of the model?

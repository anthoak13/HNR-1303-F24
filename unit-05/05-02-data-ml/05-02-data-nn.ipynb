# %% [markdown]
# # Breaking a simple neural network
#
# In this notebook we will take the neural net we constructed last class and try to break it. How? By messing with the data we use to train it.
#
# My goal for this notebook is for you to understand the importance of data in training a neural network. If our data is incomplete or incorrect in some manner, then our model will be garbage (even if our cost function might look alright)
#
# **Before running any code**: One person in your group should go to `Runtime->Change runtime type` and select `T4 GPU`. The other group member should keep this option on `CPU`. The person who is using a GPU will train the model using the GPU rather than the CPU. This is often faster for large models. The question is: is our model large enough for that to make a difference?
#
# Run the cell below to import all of the python packages we will require in this notebook. You should see the device is CUDA and the GPU is availible if you changed the runtype otherwise is should say the device is CPU.

# %%
from pathlib import Path # internal python library for managing file paths
import requests # used to doqload files using web requests
import pickle
import gzip # used to unzip files
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

import torch
import torch.nn.functional as F
from torch import nn

import copy
from google.colab import files
import random

gpu_avail = torch.cuda.is_available()
print(f"Is the GPU available? {gpu_avail}")
device = torch.device("cuda") if gpu_avail else torch.device("cpu")
print("Device", device)
# Out:
# Is the GPU available? False
# Device cpu

# %% [markdown]
# # Getting the MINST dataset
#
# Run the cell below to download and unpack the MINST dataset (this is the same as last notebook).

# %%
data_path = Path("data")
path = data_path/"mnist" # this defines the file path as data/mnist
path.mkdir(parents=True, exist_ok=True) # this creates the folders "data" and "data/mnist"

data_url = "https://github.com/pytorch/tutorials/raw/main/_static/"
data_filename = "mnist.pkl.gz"

if not (data_path / data_filename).exists():
  content = requests.get(data_url + data_filename).content
  (data_path/data_filename).open("wb").write(content)

with gzip.open((data_path / data_filename).as_posix(), "rb") as unpacked_data:
  ((image_train, label_train), (image_valid, label_valid), _) = pickle.load(unpacked_data, encoding="latin-1")

# %% [markdown]
# ---
# # (Re-)Building a neural network

# %% [markdown]
# Run the code cells in this section to re-build the differnt parts of the neural network. These cells will define the cost function, the activation function, and the structure of the neural net (number of hidden layers, etc.)

# %%
# Define the cost function that takes in the model prediction (input) and the expected output by the model (target)
def cost_func(input, target):
   cost = torch.nn.MSELoss(reduction='sum')
   return cost(input, target)

# Define a function that takes in a digit (0-9) and creates the corresponding model target
def get_target(digits):
  target = F.one_hot(torch.tensor(digits, device = device), 10)
  return target

# Define the activation function
activation_func = F.sigmoid

# Define the structure of the neural net
class NN_Model(nn.Module):
  def __init__(self):
    super().__init__()
    self.hidden1 = nn.Linear(784,16) # Our input layer has 784 neurons and our first hidden layer has 16 elements
    self.hidden2 = nn.Linear(16,16) # Our second hidden layer has 16 inputs and 16 outputs
    self.output = nn.Linear(16,10) # Our output layer has 16 inputs and 10 outputs

  def forward(self, xb):
    # xb is the value of all the neurons at the current layer.
    # At the start it is a tensor with 784 elements

    # Do the matrix multiplication and then take the sigmoid of each element in the first hidden layer.
    xb = activation_func(self.hidden1(xb))
    # xb is now a tensor with 16 elements

    # Do the matrix multiplication and then take the sigmoid of each element in the second hidden layer.
    xb = activation_func(self.hidden2(xb))
    # xb is now a tensor with 16 elements

    # Do the matrix multiplication and then take the sigmoid of each element in the output layer.
    xb = activation_func(self.output(xb))
    # xb is now a tensor with 10 elements

    return xb

# %% [markdown]
# ---
# # Training the model

# %% [markdown]
# Run the cell below to define the training function. This is a slightly more sophisticated version of the training function we have used in the past. It takes in both the training data and the validation data. It also uses the abstract `Dataset` class and the helper class `DataLoader` from PyTorch to simplify the managment of the data and creating batches to train on.
#
# **Optional for those intrested in the details**: This information is not necessary for understanding anything in our class, but is here for those who are intrested in digging into the details of how python handles data structures. The `Dataset` class wraps any object that implements the [`__len__()`](https://docs.python.org/3/reference/datamodel.html#object.__len__) and [`__getitem__()`](https://docs.python.org/3/reference/datamodel.html#object.__getitem__) functions in Python. These are both examples of so-called ["magic functions"](https://rszalski.github.io/magicmethods/) in Python. They are what underly a lot of the power of Python, which I would argue is the ability to basically ignore the specific type of an object. Instead we can treat an object logically. Is it an array like object? Then `a[0]` should do something reasonable. Personally, I've never really liked the name "magic functions". What they really are is an [Interface](https://en.wikipedia.org/wiki/Interface_(object-oriented_programming) which defines a set of *behaviors*. Any class can then agree to follow and implement the interface. All of these classes can be used interchangibly (in certain contexts). The two functions we need implemented are part of [the group of magic functions](https://docs.python.org/3/reference/datamodel.html#emulating-container-types) that allow for us to iterate through a container. `__len__(self)` is what is called whenever you run `len(obj)`. `__getitem__(self, key)` is called whenever you run something like `self[key]`. Both are fundemental to the design of a data structure and are part of the interface that allows you to mostly treat all data structures the same way in Python. Isn't object oriented programming fun?

# %%
# We will define a function for training out model:
# epochs is the number of times we pass over the complete training set.
# batch_size is how many training examples to combine before updating the model parameters
# learning_rate controls how large of a step we take each time we update the model parameters
# data_train is the list of images we are training on (the entirety of this dataset corresponds to a single epoch)
# label_train is the list of labels corresponding to the images in data_train
# model is the model we are training
# We can optionally pass two additional parameters data_valid and label_valid.

# The function will return a list containing the average cost function after each epoch
def train_model(epochs, batch_size, learning_rate, data_train, label_train, model, data_valid = None, label_valid = None):

  # Create lists to return
  cost_valid = []
  cost_train = []
  models = []

  # Create the optimizer to perform the gradient descent
  opt = torch.optim.SGD(model.parameters(), lr=learning_rate)

  # Wrap the training data in a dataset
  train_ds = torch.utils.data.TensorDataset(torch.tensor(data_train, device = device), get_target(label_train))
  train_dl = torch.utils.data.DataLoader(train_ds, batch_size=batch_size)

  # Send the model to the GPU if available
  model.to(device)

  # We will repeat the training process multiple times, printing the current average of the cost function after each epoch
  for epoch in range (epochs):
    runningLoss = 0.0
    model.train()
    # Each iteration of this loop will evaluate the model
    # on a subset of the data containing batch_size images
    for xb, yb in train_dl:
      xb = xb.to(device)
      yb = yb.to(device)
      
      opt.zero_grad()      
      pred = model(xb)
      cost = cost_func(pred, yb.float())

      # Update the model parameters (i.e. train the model)
      # for this batch of data
      cost.backward()
      opt.step()
      
      runningLoss += cost.item()
      

    # End of batch_size loop

    # calculate the average cost function
    cost = runningLoss / len(train_dl.dataset)

    xb = torch.tensor(data_valid, device=device)
    yb = get_target(label_valid)
    pred = model(xb)

    # calculate the average cost function
    cost_v = cost_func(pred, yb) / len(pred)

    print(f"After epoch {epoch} the cost function is {cost}")
    cost_valid.append(cost_v.item())
    cost_train.append(cost)
    models.append(copy.deepcopy(model))

  return cost_valid, cost_train, models

# Return the predicted digit from the output of the model
def get_digit(pred):
  return torch.argmax(pred, dim=0)

def accuracy(pred, xy):
  num_right = 0
  for i in range(pred.shape[0]):
    if get_digit(pred[i]) == get_digit(xy[i]):
      num_right += 1

  return num_right / pred.shape[0]

# %% [markdown]
# ## Get a working model
#
# Run the following code to train the model using some default hyperparameters:

# %%
# Hyperparameters for training
learning_rate = 0.05
batch_size = 100
num_epochs = 100

# This will default to creating a model with random weights and biases.
torch.manual_seed(0) # This will fix it so we all get the same data
if torch.cuda.is_available():
  torch.cuda.manual_seed(0)
  torch.cuda.manual_seed_all(0)

model = NN_Model()
model.to(device)

# Train the data. Save the average cost function and the model after each epoch
costs_valid, costs, models = train_model(num_epochs, batch_size, learning_rate, image_train, label_train, model, data_valid = image_valid, label_valid=label_valid)

#torch.save(model, 'testModel.pth')
#files.download('testModel.pth')
epochs = [i for i in range(len(costs))]

# plot the cost function as a function of epoch
fig = plt.figure(figsize=(8,6))
plt.title("Cost function vs. training epoch")
plt.xlabel('Epoch')
plt.ylabel('Cost function (arb)')
plt.grid(which='both', axis='both')
plt.plot(epochs, costs, 'r-', label="Training set")
plt.plot(epochs, costs_valid, 'b-', label="Validation set")
plt.legend()
plt.show()
# Out:
# After epoch 0 the cost function is 0.19530515372753143
# After epoch 1 the cost function is 0.131694033741951
# After epoch 2 the cost function is 0.12024848908185959
# After epoch 3 the cost function is 0.10495374351739883
# After epoch 4 the cost function is 0.10684888809919357
# After epoch 5 the cost function is 0.10160128027200699
# After epoch 6 the cost function is 0.10563848912715912
# After epoch 7 the cost function is 0.1035088449716568
# After epoch 8 the cost function is 0.08596884459257126
# After epoch 9 the cost function is 0.08718351274728775
# After epoch 10 the cost function is 0.09362450242042542
# After epoch 11 the cost function is 0.08756448328495026
# After epoch 12 the cost function is 0.07867836207151413
# After epoch 13 the cost function is 0.07687289267778397
# After epoch 14 the cost function is 0.07596025615930557
# After epoch 15 the cost function is 0.07388724386692047
# After epoch 16 the cost function is 0.07241076976060867
# After epoch 17 the cost function is 0.07310161739587784
# After epoch 18 the cost function is 0.07284577190876007
# After epoch 19 the cost function is 0.0689186155796051
# After epoch 20 the cost function is 0.06940879672765732
# After epoch 21 the cost function is 0.06485214084386826
# After epoch 22 the cost function is 0.06568067520856857
# After epoch 23 the cost function is 0.06452007591724396
# After epoch 24 the cost function is 0.06989973783493042
# After epoch 25 the cost function is 0.06486489623785019
# After epoch 26 the cost function is 0.06201152503490448
# After epoch 27 the cost function is 0.06418207287788391
# After epoch 28 the cost function is 0.06012517586350441
# After epoch 29 the cost function is 0.0650007426738739
# After epoch 30 the cost function is 0.06312716007232666
# After epoch 31 the cost function is 0.06087327003479004
# After epoch 32 the cost function is 0.06583888828754425
# After epoch 33 the cost function is 0.05968647450208664
# After epoch 34 the cost function is 0.06373358517885208
# After epoch 35 the cost function is 0.06533753126859665
# After epoch 36 the cost function is 0.05923161655664444
# After epoch 37 the cost function is 0.06387132406234741
# After epoch 38 the cost function is 0.057589076459407806
# After epoch 39 the cost function is 0.06029749661684036
# After epoch 40 the cost function is 0.05884352698922157
# After epoch 41 the cost function is 0.05670803785324097
# After epoch 42 the cost function is 0.05498380959033966
# After epoch 43 the cost function is 0.05959903448820114
# After epoch 44 the cost function is 0.055060975253582
# After epoch 45 the cost function is 0.05677567049860954
# After epoch 46 the cost function is 0.05515158548951149
# After epoch 47 the cost function is 0.05673784762620926
# After epoch 48 the cost function is 0.05453675612807274
# After epoch 49 the cost function is 0.055606622248888016
# After epoch 50 the cost function is 0.05578949302434921
# After epoch 51 the cost function is 0.05582910776138306
# After epoch 52 the cost function is 0.054955728352069855
# After epoch 53 the cost function is 0.0527750626206398
# After epoch 54 the cost function is 0.05644466355443001
# After epoch 55 the cost function is 0.05438194423913956
# After epoch 56 the cost function is 0.055774468928575516
# After epoch 57 the cost function is 0.05417116358876228
# After epoch 58 the cost function is 0.05612615868449211
# After epoch 59 the cost function is 0.05324564501643181
# After epoch 60 the cost function is 0.05732973664999008
# After epoch 61 the cost function is 0.05468900501728058
# After epoch 62 the cost function is 0.0548623651266098
# After epoch 63 the cost function is 0.05246790498495102
# After epoch 64 the cost function is 0.054213568568229675
# After epoch 65 the cost function is 0.05394088476896286
# After epoch 66 the cost function is 0.054654259234666824
# After epoch 67 the cost function is 0.05219234898686409
# After epoch 68 the cost function is 0.0534297376871109
# After epoch 69 the cost function is 0.049433086067438126
# After epoch 70 the cost function is 0.05164272338151932
# After epoch 71 the cost function is 0.05690869316458702
# After epoch 72 the cost function is 0.051237188279628754
# After epoch 73 the cost function is 0.05625885725021362
# After epoch 74 the cost function is 0.04991420358419418
# After epoch 75 the cost function is 0.049305565655231476
# After epoch 76 the cost function is 0.050200220197439194
# After epoch 77 the cost function is 0.05240877345204353
# After epoch 78 the cost function is 0.049760688096284866
# After epoch 79 the cost function is 0.051622435450553894
# After epoch 80 the cost function is 0.05044618248939514
# After epoch 81 the cost function is 0.05588100478053093
# After epoch 82 the cost function is 0.05178872495889664
# After epoch 83 the cost function is 0.057144246995449066
# After epoch 84 the cost function is 0.049453966319561005
# After epoch 85 the cost function is 0.048228710889816284
# After epoch 86 the cost function is 0.04849100112915039
# After epoch 87 the cost function is 0.04774027317762375
# After epoch 88 the cost function is 0.04751111939549446
# After epoch 89 the cost function is 0.053270820528268814
# After epoch 90 the cost function is 0.049853548407554626
# After epoch 91 the cost function is 0.05280015990138054
# After epoch 92 the cost function is 0.05181487277150154
# After epoch 93 the cost function is 0.04727740213274956
# After epoch 94 the cost function is 0.0475371889770031
# After epoch 95 the cost function is 0.05003311485052109
# After epoch 96 the cost function is 0.05130331963300705
# After epoch 97 the cost function is 0.048207104206085205
# After epoch 98 the cost function is 0.0477636456489563
# After epoch 99 the cost function is 0.049032632261514664

# %% [markdown]
# # When is a model done learning?
#
# **Based on the cost curves you generated above, how does the long-term behavior of the cost function differ between the validation set and the training set?**
#
# **Around what epoch does the validation curve level off?**
#
# **What do you think is happening here?**
#
#
# Run the code below to fit the long term behavior of the cost function for our two data sets.

# %%
linear_model = lambda x,a,b: x*a + b

trunc_epoch = epochs[20:]
trunc_train = costs[20:]
trunc_valid = costs_valid[20:]

params, cov = curve_fit(linear_model, trunc_epoch, trunc_train)
model_train = linear_model(np.array(trunc_epoch), *params)
print(f"The slope of the cost curve for the training data is {params[0]:.2e}.")

params, cov = curve_fit(linear_model, trunc_epoch, trunc_valid)
model_valid = linear_model(np.array(trunc_epoch), *params)
print(f"The slope of the cost curve for the validation data is {params[0]:.2e}.")

# plot the cost function as a function of epoch
fig = plt.figure(figsize=(8,6))
plt.title("Cost function vs. training epoch")
plt.xlabel('Epoch')
plt.ylabel('Cost function (arb)')
plt.grid(which='both', axis='both')
plt.plot(trunc_epoch, costs[20:], 'r-', label="Training set")
plt.plot(trunc_epoch, model_train, 'r--', label="Linear fit")
plt.plot(epochs[20:], costs_valid[20:], 'b-', label="Validation set")
plt.plot(trunc_epoch, model_valid, 'b--', label="Linear fit")
plt.legend()
plt.show()
# Out:
# The slope of the cost curve for the training data is -2.14e-04.
# The slope of the cost curve for the validation data is 4.89e-05.

# %% [markdown]
# **What does it mean for the validity of our model that the slope for the training set is negative and the slope for the validation set is positive?**

# %% [markdown]
# # Training with bad data
#
# Machine learning models are only as good as the data they are given. Suppose we where to shuffle of the labels in our training set. That is, each image in our training set is assigned to a random number as a label.
#
# **What do you think the cost curves will look like for the training and validation sets?**
#
#
# After writing your prediction, run the following code to find out.

# %%
# Hyperparameters for training
learning_rate = 0.05
batch_size = 100
num_epochs = 100

# This will default to creating a model with random weights and biases.
torch.manual_seed(0) # This will fix it so we all get the same starting model
model = NN_Model()
model.to(device)

label_sh = copy.deepcopy(label_train) # Make a copy of our labels
random.shuffle(label_sh) # Shuffle our labels at random

# Train the data. Save the average cost function and the model after each epoch
costs_valid_sh, costs_sh, models_sh = train_model(num_epochs, batch_size, learning_rate, image_train, label_sh, model, data_valid = image_valid, label_valid=label_valid)
epochs_sh = [i for i in range(len(costs_sh))]
# Out:
# After epoch 0 the cost function is 0.900730550289154
# After epoch 1 the cost function is 0.9006468057632446
# After epoch 2 the cost function is 0.9005928635597229
# After epoch 3 the cost function is 0.9005525708198547
# After epoch 4 the cost function is 0.9005204439163208
# After epoch 5 the cost function is 0.9004935026168823
# After epoch 6 the cost function is 0.9004703760147095
# After epoch 7 the cost function is 0.9004495143890381
# After epoch 8 the cost function is 0.9004303812980652
# After epoch 9 the cost function is 0.9004120826721191
# After epoch 10 the cost function is 0.9003939628601074
# After epoch 11 the cost function is 0.9003755450248718
# After epoch 12 the cost function is 0.9003559947013855
# After epoch 13 the cost function is 0.900334894657135
# After epoch 14 the cost function is 0.9003111124038696
# After epoch 15 the cost function is 0.9002835750579834
# After epoch 16 the cost function is 0.9002517461776733
# After epoch 17 the cost function is 0.9002153277397156
# After epoch 18 the cost function is 0.9001756310462952
# After epoch 19 the cost function is 0.9001339077949524
# After epoch 20 the cost function is 0.9000909328460693
# After epoch 21 the cost function is 0.9000466465950012
# After epoch 22 the cost function is 0.9000008702278137
# After epoch 23 the cost function is 0.8999534249305725
# After epoch 24 the cost function is 0.8999043703079224
# After epoch 25 the cost function is 0.8998542428016663
# After epoch 26 the cost function is 0.8998026847839355
# After epoch 27 the cost function is 0.8997496962547302
# After epoch 28 the cost function is 0.8996945023536682
# After epoch 29 the cost function is 0.8996365666389465
# After epoch 30 the cost function is 0.8995750546455383
# After epoch 31 the cost function is 0.899510383605957
# After epoch 32 the cost function is 0.8994432091712952
# After epoch 33 the cost function is 0.8993745446205139
# After epoch 34 the cost function is 0.8993048667907715
# After epoch 35 the cost function is 0.8992344737052917
# After epoch 36 the cost function is 0.8991633653640747
# After epoch 37 the cost function is 0.8990914225578308
# After epoch 38 the cost function is 0.8990175127983093
# After epoch 39 the cost function is 0.8989416360855103
# After epoch 40 the cost function is 0.8988629579544067
# After epoch 41 the cost function is 0.8987816572189331
# After epoch 42 the cost function is 0.8986974954605103
# After epoch 43 the cost function is 0.8986110687255859
# After epoch 44 the cost function is 0.8985229730606079
# After epoch 45 the cost function is 0.8984336853027344
# After epoch 46 the cost function is 0.8983439207077026
# After epoch 47 the cost function is 0.8982539176940918
# After epoch 48 the cost function is 0.8981638550758362
# After epoch 49 the cost function is 0.8980737328529358
# After epoch 50 the cost function is 0.8979841470718384
# After epoch 51 the cost function is 0.8978951573371887
# After epoch 52 the cost function is 0.8978071808815002
# After epoch 53 the cost function is 0.8977206349372864
# After epoch 54 the cost function is 0.8976354598999023
# After epoch 55 the cost function is 0.8975515365600586
# After epoch 56 the cost function is 0.8974685072898865
# After epoch 57 the cost function is 0.8973854780197144
# After epoch 58 the cost function is 0.8973016142845154
# After epoch 59 the cost function is 0.8972159624099731
# After epoch 60 the cost function is 0.8971270322799683
# After epoch 61 the cost function is 0.8970337510108948
# After epoch 62 the cost function is 0.8969351649284363
# After epoch 63 the cost function is 0.8968300223350525
# After epoch 64 the cost function is 0.8967179656028748
# After epoch 65 the cost function is 0.8965984582901001
# After epoch 66 the cost function is 0.8964722156524658
# After epoch 67 the cost function is 0.8963404893875122
# After epoch 68 the cost function is 0.896204948425293
# After epoch 69 the cost function is 0.8960680365562439
# After epoch 70 the cost function is 0.8959323167800903
# After epoch 71 the cost function is 0.8958008885383606
# After epoch 72 the cost function is 0.8956759572029114
# After epoch 73 the cost function is 0.8955604434013367
# After epoch 74 the cost function is 0.8954570889472961
# After epoch 75 the cost function is 0.8953691124916077
# After epoch 76 the cost function is 0.8952981233596802
# After epoch 77 the cost function is 0.8952451348304749
# After epoch 78 the cost function is 0.8952116966247559
# After epoch 79 the cost function is 0.8951975703239441
# After epoch 80 the cost function is 0.8951975703239441
# After epoch 81 the cost function is 0.8952029943466187
# After epoch 82 the cost function is 0.8952075839042664
# After epoch 83 the cost function is 0.8952080607414246
# After epoch 84 the cost function is 0.8952163457870483
# After epoch 85 the cost function is 0.8952664732933044
# After epoch 86 the cost function is 0.8953860402107239
# After epoch 87 the cost function is 0.8955832719802856
# After epoch 88 the cost function is 0.8958114981651306
# After epoch 89 the cost function is 0.8960177898406982
# After epoch 90 the cost function is 0.8962309956550598
# After epoch 91 the cost function is 0.8964820504188538
# After epoch 92 the cost function is 0.8968574404716492
# After epoch 93 the cost function is 0.8969200253486633
# After epoch 94 the cost function is 0.8973442912101746
# After epoch 95 the cost function is 0.897701621055603
# After epoch 96 the cost function is 0.8981529474258423
# After epoch 97 the cost function is 0.8984520435333252
# After epoch 98 the cost function is 0.8989555239677429
# After epoch 99 the cost function is 0.8994640111923218

# %%
# plot the cost function as a function of epoch
fig = plt.figure(figsize=(8,6))
plt.title("Cost function vs. training epoch")
plt.xlabel('Epoch')
plt.ylabel('Cost function (arb)')
plt.grid(which='both', axis='both')
plt.plot(epochs_sh, costs_sh, 'r-', label="Training set")
plt.plot(epochs_sh, costs_valid_sh, 'b-', label="Validation set")
plt.legend()
plt.show()

# %% [markdown]
# **What is the long term behavior for both cost curves?**
#
# **How do the cost curves differ from when we are training with good data?**
#
#
# Let's look for a second at the accuracy as a function of epoch. It's a little easier to interpate. **If our model was just guessing, what would the expected accuracy of the model be?**
#
# After making your prediction, run the two code cells below to calcualte and plot accuracy vs epoch (it'll take a bit, there is a lot of data to churn through, if you want to edit the plot just run the second cell).

# %%
target = get_target(label_sh)
target_valid = get_target(label_valid)
acc_train = []
acc_valid = []
for model, epoch in zip(models_sh, range(len(models_sh))):
  if epoch % 10 == 0:
    print("On epoch ", epoch, " of ", len(models_sh))

  pred = model(torch.tensor(image_train, device=device))
  acc_train.append(accuracy(pred, target))


  pred = model(torch.tensor(image_valid, device=device))
  acc_valid.append(accuracy(pred, target_valid))
# Out:
# On epoch  0  of  100
# On epoch  10  of  100
# On epoch  20  of  100
# On epoch  30  of  100
# On epoch  40  of  100
# On epoch  50  of  100
# On epoch  60  of  100
# On epoch  70  of  100
# On epoch  80  of  100
# On epoch  90  of  100

# %%
log_model = lambda x, a, b, c, d: a/(1+np.exp(-b*(x-c))) + d

trunc_epoch = epochs_sh[0:]
trunc_train = costs_sh[0:]
trunc_valid = costs_valid_sh[0:]

params, cov = curve_fit(log_model, trunc_epoch, acc_train, p0=[.03, 1, 45, .12])
model_train = log_model(np.array(trunc_epoch), *params)
print(f"The carrying capacity of the cost curve for the training data is {(params[0]+params[3])*100:.2f}%.")


# plot the cost function as a function of epoch
fig = plt.figure(figsize=(8,6))
plt.title("Accuracy vs. training epoch")
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(which='both', axis='both')
plt.plot(epochs_sh, acc_train, 'r-', label="Training set")
plt.plot(epochs_sh, acc_valid, 'b-', label="Validation set")
plt.plot(epochs_sh, model_train, 'r--', label="Logistic fit")
plt.legend()
plt.show()
# Out:
# The carrying capacity of the cost curve for the training data is 14.16%.

# %% [markdown]
# **What do you notice about the accuracy? Is one dataset better than random? Is one dataset worse than random?**
#
# **Why do you think the accuracy for the trainins set is leveling off? It is fit quite well by a logisitic function.**
#
# **What do you think would happen if we were to only train on $100$ examples instead of $50,000$ (with the wrong labels)?**

# %% [markdown]
# The code below will train a series of models on only 100 events with the labels shuffled.

# %%
# Hyperparameters for training
learning_rate = 0.05
batch_size = 100
num_epochs = 1000

# This will default to creating a model with random weights and biases.
torch.manual_seed(0) # This will fix it so we all get the same data
model = NN_Model()
model.to(device)

label_100 = label_sh[:100]
data_100 = image_train[:100]

# Train the data. Save the average cost function and the model after each epoch
costs_valid_100, costs_100, models_100 = train_model(num_epochs, batch_size, learning_rate, data_100, label_100, model, data_valid = image_valid, label_valid=label_valid)
epochs_100 = [i for i in range(len(costs_100))]

# plot the cost function as a function of epoch
fig = plt.figure(figsize=(8,6))
plt.title("Cost function vs. training epoch")
plt.xlabel('Epoch')
plt.ylabel('Cost function (arb)')
plt.grid(which='both', axis='both')
plt.plot(epochs_100, costs_100, 'r-', label="Training set")
plt.plot(epochs_100, costs_valid_100, 'b-', label="Validation set")
plt.legend()
plt.show()
# Out:
# After epoch 0 the cost function is 0.9816204309463501
# After epoch 1 the cost function is 0.9790477752685547
# After epoch 2 the cost function is 0.9758740067481995
# After epoch 3 the cost function is 0.9719253778457642
# After epoch 4 the cost function is 0.9669978618621826
# After epoch 5 the cost function is 0.960909903049469
# After epoch 6 the cost function is 0.953657865524292
# After epoch 7 the cost function is 0.94569993019104
# After epoch 8 the cost function is 0.9380539059638977
# After epoch 9 the cost function is 0.9315271973609924
# After epoch 10 the cost function is 0.9258596301078796
# After epoch 11 the cost function is 0.920459508895874
# After epoch 12 the cost function is 0.9152024984359741
# After epoch 13 the cost function is 0.9103146195411682
# After epoch 14 the cost function is 0.9061205983161926
# After epoch 15 the cost function is 0.902828574180603
# After epoch 16 the cost function is 0.9004232287406921
# After epoch 17 the cost function is 0.8987275958061218
# After epoch 18 the cost function is 0.8975309729576111
# After epoch 19 the cost function is 0.8966648578643799
# After epoch 20 the cost function is 0.8960151672363281
# After epoch 21 the cost function is 0.8955110311508179
# After epoch 22 the cost function is 0.8951088190078735
# After epoch 23 the cost function is 0.8947807550430298
# After epoch 24 the cost function is 0.8945091366767883
# After epoch 25 the cost function is 0.8942814469337463
# After epoch 26 the cost function is 0.8940889239311218
# After epoch 27 the cost function is 0.8939246535301208
# After epoch 28 the cost function is 0.8937835693359375
# After epoch 29 the cost function is 0.8936616778373718
# After epoch 30 the cost function is 0.893555760383606
# After epoch 31 the cost function is 0.8934628963470459
# After epoch 32 the cost function is 0.8933812975883484
# After epoch 33 the cost function is 0.8933088779449463
# After epoch 34 the cost function is 0.8932443261146545
# After epoch 35 the cost function is 0.8931862711906433
# After epoch 36 the cost function is 0.8931336998939514
# After epoch 37 the cost function is 0.893085777759552
# After epoch 38 the cost function is 0.8930416703224182
# After epoch 39 the cost function is 0.8930008411407471
# After epoch 40 the cost function is 0.8929628133773804
# After epoch 41 the cost function is 0.8929266929626465
# After epoch 42 the cost function is 0.8928926587104797
# After epoch 43 the cost function is 0.892859935760498
# After epoch 44 the cost function is 0.8928284645080566
# After epoch 45 the cost function is 0.8927977681159973
# After epoch 46 the cost function is 0.8927679657936096
# After epoch 47 the cost function is 0.8927386403083801
# After epoch 48 the cost function is 0.8927096724510193
# After epoch 49 the cost function is 0.8926808834075928
# After epoch 50 the cost function is 0.892652153968811
# After epoch 51 the cost function is 0.8926236033439636
# After epoch 52 the cost function is 0.8925949335098267
# After epoch 53 the cost function is 0.8925661444664001
# After epoch 54 the cost function is 0.8925370573997498
# After epoch 55 the cost function is 0.892507791519165
# After epoch 56 the cost function is 0.8924781680107117
# After epoch 57 the cost function is 0.8924481272697449
# After epoch 58 the cost function is 0.8924177289009094
# After epoch 59 the cost function is 0.892386794090271
# After epoch 60 the cost function is 0.8923554420471191
# After epoch 61 the cost function is 0.8923235535621643
# After epoch 62 the cost function is 0.8922908902168274
# After epoch 63 the cost function is 0.8922577500343323
# After epoch 64 the cost function is 0.8922238349914551
# After epoch 65 the cost function is 0.8921892046928406
# After epoch 66 the cost function is 0.892153799533844
# After epoch 67 the cost function is 0.8921176195144653
# After epoch 68 the cost function is 0.892080545425415
# After epoch 69 the cost function is 0.8920425176620483
# After epoch 70 the cost function is 0.8920037150382996
# After epoch 71 the cost function is 0.8919638991355896
# After epoch 72 the cost function is 0.8919228315353394
# After epoch 73 the cost function is 0.8918807506561279
# After epoch 74 the cost function is 0.8918375968933105
# After epoch 75 the cost function is 0.8917931914329529
# After epoch 76 the cost function is 0.8917475342750549
# After epoch 77 the cost function is 0.8917004466056824
# After epoch 78 the cost function is 0.8916521668434143
# After epoch 79 the cost function is 0.8916022777557373
# After epoch 80 the cost function is 0.8915507793426514
# After epoch 81 the cost function is 0.8914976716041565
# After epoch 82 the cost function is 0.8914429545402527
# After epoch 83 the cost function is 0.8913863301277161
# After epoch 84 the cost function is 0.891327977180481
# After epoch 85 the cost function is 0.8912674784660339
# After epoch 86 the cost function is 0.8912048935890198
# After epoch 87 the cost function is 0.8911402225494385
# After epoch 88 the cost function is 0.8910732269287109
# After epoch 89 the cost function is 0.8910037875175476
# After epoch 90 the cost function is 0.8909317255020142
# After epoch 91 the cost function is 0.8908571600914001
# After epoch 92 the cost function is 0.8907795548439026
# After epoch 93 the cost function is 0.890699028968811
# After epoch 94 the cost function is 0.8906154036521912
# After epoch 95 the cost function is 0.8905283212661743
# After epoch 96 the cost function is 0.89043790102005
# After epoch 97 the cost function is 0.8903436064720154
# After epoch 98 the cost function is 0.8902456164360046
# After epoch 99 the cost function is 0.8901433348655701
# After epoch 100 the cost function is 0.8900367617607117
# After epoch 101 the cost function is 0.8899255394935608
# After epoch 102 the cost function is 0.8898094296455383
# After epoch 103 the cost function is 0.8896881937980652
# After epoch 104 the cost function is 0.8895614147186279
# After epoch 105 the cost function is 0.8894289135932922
# After epoch 106 the cost function is 0.8892902135848999
# After epoch 107 the cost function is 0.8891449570655823
# After epoch 108 the cost function is 0.8889928460121155
# After epoch 109 the cost function is 0.8888334035873413
# After epoch 110 the cost function is 0.8886659145355225
# After epoch 111 the cost function is 0.8884903788566589
# After epoch 112 the cost function is 0.8883059620857239
# After epoch 113 the cost function is 0.8881120085716248
# After epoch 114 the cost function is 0.8879083395004272
# After epoch 115 the cost function is 0.8876937031745911
# After epoch 116 the cost function is 0.8874678015708923
# After epoch 117 the cost function is 0.8872299194335938
# After epoch 118 the cost function is 0.8869789242744446
# After epoch 119 the cost function is 0.8867141604423523
# After epoch 120 the cost function is 0.88643479347229
# After epoch 121 the cost function is 0.8861396312713623
# After epoch 122 the cost function is 0.8858277201652527
# After epoch 123 the cost function is 0.8854976892471313
# After epoch 124 the cost function is 0.8851484656333923
# After epoch 125 the cost function is 0.884778618812561
# After epoch 126 the cost function is 0.8843868374824524
# After epoch 127 the cost function is 0.8839712738990784
# After epoch 128 the cost function is 0.8835304379463196
# After epoch 129 the cost function is 0.8830624222755432
# After epoch 130 the cost function is 0.8825653195381165
# After epoch 131 the cost function is 0.8820370435714722
# After epoch 132 the cost function is 0.8814752101898193
# After epoch 133 the cost function is 0.8808776140213013
# After epoch 134 the cost function is 0.8802414536476135
# After epoch 135 the cost function is 0.8795638084411621
# After epoch 136 the cost function is 0.8788419961929321
# After epoch 137 the cost function is 0.8780725002288818
# After epoch 138 the cost function is 0.8772518634796143
# After epoch 139 the cost function is 0.8763765096664429
# After epoch 140 the cost function is 0.8754423260688782
# After epoch 141 the cost function is 0.8744451999664307
# After epoch 142 the cost function is 0.8733804225921631
# After epoch 143 the cost function is 0.8722432851791382
# After epoch 144 the cost function is 0.8710285425186157
# After epoch 145 the cost function is 0.8697308897972107
# After epoch 146 the cost function is 0.8683444261550903
# After epoch 147 the cost function is 0.866862952709198
# After epoch 148 the cost function is 0.8652800917625427
# After epoch 149 the cost function is 0.8635894656181335
# After epoch 150 the cost function is 0.8617842197418213
# After epoch 151 the cost function is 0.8598576188087463
# After epoch 152 the cost function is 0.8578031659126282
# After epoch 153 the cost function is 0.8556153774261475
# After epoch 154 the cost function is 0.8532891273498535
# After epoch 155 the cost function is 0.850820779800415
# After epoch 156 the cost function is 0.8482092022895813
# After epoch 157 the cost function is 0.8454553484916687
# After epoch 158 the cost function is 0.8425625562667847
# After epoch 159 the cost function is 0.8395375609397888
# After epoch 160 the cost function is 0.8363893032073975
# After epoch 161 the cost function is 0.8331291675567627
# After epoch 162 the cost function is 0.8297702074050903
# After epoch 163 the cost function is 0.8263263702392578
# After epoch 164 the cost function is 0.8228132128715515
# After epoch 165 the cost function is 0.8192460536956787
# After epoch 166 the cost function is 0.8156416416168213
# After epoch 167 the cost function is 0.8120179772377014
# After epoch 168 the cost function is 0.8083959817886353
# After epoch 169 the cost function is 0.8048551082611084
# After epoch 170 the cost function is 0.8026995658874512
# After epoch 171 the cost function is 0.8345939517021179
# After epoch 172 the cost function is 0.9396817684173584
# After epoch 173 the cost function is 0.9126181602478027
# After epoch 174 the cost function is 0.9056860208511353
# After epoch 175 the cost function is 0.8957089781761169
# After epoch 176 the cost function is 0.876406192779541
# After epoch 177 the cost function is 0.8360942602157593
# After epoch 178 the cost function is 0.8226862549781799
# After epoch 179 the cost function is 0.8703594207763672
# After epoch 180 the cost function is 0.8158295154571533
# After epoch 181 the cost function is 0.8564945459365845
# After epoch 182 the cost function is 0.9210390448570251
# After epoch 183 the cost function is 0.9105060696601868
# After epoch 184 the cost function is 0.9065864682197571
# After epoch 185 the cost function is 0.9016665816307068
# After epoch 186 the cost function is 0.8948249816894531
# After epoch 187 the cost function is 0.8837550282478333
# After epoch 188 the cost function is 0.8639973402023315
# After epoch 189 the cost function is 0.8365457057952881
# After epoch 190 the cost function is 0.8133114576339722
# After epoch 191 the cost function is 0.8047832250595093
# After epoch 192 the cost function is 0.797045111656189
# After epoch 193 the cost function is 0.7919468879699707
# After epoch 194 the cost function is 0.8023934960365295
# After epoch 195 the cost function is 0.9215911626815796
# After epoch 196 the cost function is 0.9319969415664673
# After epoch 197 the cost function is 0.9171440601348877
# After epoch 198 the cost function is 0.9153993129730225
# After epoch 199 the cost function is 0.9141325354576111
# After epoch 200 the cost function is 0.9130330085754395
# After epoch 201 the cost function is 0.9120117425918579
# After epoch 202 the cost function is 0.9110291004180908
# After epoch 203 the cost function is 0.9100530743598938
# After epoch 204 the cost function is 0.9090452790260315
# After epoch 205 the cost function is 0.9079565405845642
# After epoch 206 the cost function is 0.9067317247390747
# After epoch 207 the cost function is 0.905323326587677
# After epoch 208 the cost function is 0.9037124514579773
# After epoch 209 the cost function is 0.9019185900688171
# After epoch 210 the cost function is 0.8999709486961365
# After epoch 211 the cost function is 0.8978515863418579
# After epoch 212 the cost function is 0.8954409956932068
# After epoch 213 the cost function is 0.8924611806869507
# After epoch 214 the cost function is 0.8883475661277771
# After epoch 215 the cost function is 0.8819599747657776
# After epoch 216 the cost function is 0.8712255954742432
# After epoch 217 the cost function is 0.8539379835128784
# After epoch 218 the cost function is 0.8307064771652222
# After epoch 219 the cost function is 0.8118872046470642
# After epoch 220 the cost function is 0.8045750260353088
# After epoch 221 the cost function is 0.7986485362052917
# After epoch 222 the cost function is 0.7937742471694946
# After epoch 223 the cost function is 0.7893882989883423
# After epoch 224 the cost function is 0.7855420112609863
# After epoch 225 the cost function is 0.7849911451339722
# After epoch 226 the cost function is 0.8106104135513306
# After epoch 227 the cost function is 0.86396324634552
# After epoch 228 the cost function is 0.9134312272071838
# After epoch 229 the cost function is 0.8977535963058472
# After epoch 230 the cost function is 0.8913947343826294
# After epoch 231 the cost function is 0.8821715712547302
# After epoch 232 the cost function is 0.8664408922195435
# After epoch 233 the cost function is 0.8453112244606018
# After epoch 234 the cost function is 0.8260486125946045
# After epoch 235 the cost function is 0.8035047054290771
# After epoch 236 the cost function is 0.7934790849685669
# After epoch 237 the cost function is 0.7981992959976196
# After epoch 238 the cost function is 0.8081631660461426
# After epoch 239 the cost function is 0.8661619424819946
# After epoch 240 the cost function is 0.8281010389328003
# After epoch 241 the cost function is 0.7829058170318604
# After epoch 242 the cost function is 0.7897529602050781
# After epoch 243 the cost function is 0.8423606753349304
# After epoch 244 the cost function is 0.7840418815612793
# After epoch 245 the cost function is 0.7917736172676086
# After epoch 246 the cost function is 0.8538485765457153
# After epoch 247 the cost function is 0.8006210327148438
# After epoch 248 the cost function is 0.7774785757064819
# After epoch 249 the cost function is 0.8161654472351074
# After epoch 250 the cost function is 0.7686823010444641
# After epoch 251 the cost function is 0.7844864726066589
# After epoch 252 the cost function is 0.8083787560462952
# After epoch 253 the cost function is 0.8895464539527893
# After epoch 254 the cost function is 0.85848069190979
# After epoch 255 the cost function is 0.8263474106788635
# After epoch 256 the cost function is 0.7814845442771912
# After epoch 257 the cost function is 0.775132954120636
# After epoch 258 the cost function is 0.8088453412055969
# After epoch 259 the cost function is 0.7634578943252563
# After epoch 260 the cost function is 0.7670080065727234
# After epoch 261 the cost function is 0.7811259627342224
# After epoch 262 the cost function is 0.8483691215515137
# After epoch 263 the cost function is 0.787102222442627
# After epoch 264 the cost function is 0.7601139545440674
# After epoch 265 the cost function is 0.7826864123344421
# After epoch 266 the cost function is 0.7775852680206299
# After epoch 267 the cost function is 0.8435221910476685
# After epoch 268 the cost function is 0.7773194909095764
# After epoch 269 the cost function is 0.7546085119247437
# After epoch 270 the cost function is 0.7698656320571899
# After epoch 271 the cost function is 0.770735502243042
# After epoch 272 the cost function is 0.8363590836524963
# After epoch 273 the cost function is 0.7617443799972534
# After epoch 274 the cost function is 0.7465092539787292
# After epoch 275 the cost function is 0.7554736137390137
# After epoch 276 the cost function is 0.7621610760688782
# After epoch 277 the cost function is 0.8258666396141052
# After epoch 278 the cost function is 0.7475972771644592
# After epoch 279 the cost function is 0.7359087467193604
# After epoch 280 the cost function is 0.7352101802825928
# After epoch 281 the cost function is 0.7376899719238281
# After epoch 282 the cost function is 0.7565187811851501
# After epoch 283 the cost function is 0.7780082821846008
# After epoch 284 the cost function is 0.8746440410614014
# After epoch 285 the cost function is 0.8321295976638794
# After epoch 286 the cost function is 0.776090681552887
# After epoch 287 the cost function is 0.7387044429779053
# After epoch 288 the cost function is 0.7431682348251343
# After epoch 289 the cost function is 0.7412344217300415
# After epoch 290 the cost function is 0.7610083818435669
# After epoch 291 the cost function is 0.7549131512641907
# After epoch 292 the cost function is 0.8056582808494568
# After epoch 293 the cost function is 0.7302592396736145
# After epoch 294 the cost function is 0.7186481952667236
# After epoch 295 the cost function is 0.7162767648696899
# After epoch 296 the cost function is 0.714464545249939
# After epoch 297 the cost function is 0.7133404016494751
# After epoch 298 the cost function is 0.7137884497642517
# After epoch 299 the cost function is 0.716796875
# After epoch 300 the cost function is 0.7310975790023804
# After epoch 301 the cost function is 0.7583697438240051
# After epoch 302 the cost function is 0.8403468132019043
# After epoch 303 the cost function is 0.775239109992981
# After epoch 304 the cost function is 0.7039148807525635
# After epoch 305 the cost function is 0.6986591815948486
# After epoch 306 the cost function is 0.6948201656341553
# After epoch 307 the cost function is 0.6914665699005127
# After epoch 308 the cost function is 0.6882608532905579
# After epoch 309 the cost function is 0.6851373314857483
# After epoch 310 the cost function is 0.682345986366272
# After epoch 311 the cost function is 0.6810070872306824
# After epoch 312 the cost function is 0.6868967413902283
# After epoch 313 the cost function is 0.710489809513092
# After epoch 314 the cost function is 0.7829949259757996
# After epoch 315 the cost function is 0.8236638903617859
# After epoch 316 the cost function is 0.7265216112136841
# After epoch 317 the cost function is 0.6778765916824341
# After epoch 318 the cost function is 0.697654664516449
# After epoch 319 the cost function is 0.7480143904685974
# After epoch 320 the cost function is 0.7462347149848938
# After epoch 321 the cost function is 0.6565207839012146
# After epoch 322 the cost function is 0.6496200561523438
# After epoch 323 the cost function is 0.6445665955543518
# After epoch 324 the cost function is 0.642591655254364
# After epoch 325 the cost function is 0.6543012857437134
# After epoch 326 the cost function is 0.6896474957466125
# After epoch 327 the cost function is 0.765556812286377
# After epoch 328 the cost function is 0.7409668564796448
# After epoch 329 the cost function is 0.6849520802497864
# After epoch 330 the cost function is 0.681772768497467
# After epoch 331 the cost function is 0.6490882635116577
# After epoch 332 the cost function is 0.7196348309516907
# After epoch 333 the cost function is 0.7366529703140259
# After epoch 334 the cost function is 0.6867048740386963
# After epoch 335 the cost function is 0.615094780921936
# After epoch 336 the cost function is 0.604235827922821
# After epoch 337 the cost function is 0.598558247089386
# After epoch 338 the cost function is 0.5970771908760071
# After epoch 339 the cost function is 0.6126449704170227
# After epoch 340 the cost function is 0.6274617910385132
# After epoch 341 the cost function is 0.7018458843231201
# After epoch 342 the cost function is 0.6607377529144287
# After epoch 343 the cost function is 0.5836221575737
# After epoch 344 the cost function is 0.5846554040908813
# After epoch 345 the cost function is 0.6130046248435974
# After epoch 346 the cost function is 0.6237838268280029
# After epoch 347 the cost function is 0.6653808355331421
# After epoch 348 the cost function is 0.5841658711433411
# After epoch 349 the cost function is 0.5813849568367004
# After epoch 350 the cost function is 0.6309173107147217
# After epoch 351 the cost function is 0.5563150644302368
# After epoch 352 the cost function is 0.5717127323150635
# After epoch 353 the cost function is 0.5979648232460022
# After epoch 354 the cost function is 0.6180548667907715
# After epoch 355 the cost function is 0.5564461946487427
# After epoch 356 the cost function is 0.5306293964385986
# After epoch 357 the cost function is 0.5189619660377502
# After epoch 358 the cost function is 0.514535129070282
# After epoch 359 the cost function is 0.5230891704559326
# After epoch 360 the cost function is 0.5752599239349365
# After epoch 361 the cost function is 0.682834804058075
# After epoch 362 the cost function is 0.6785799264907837
# After epoch 363 the cost function is 0.7507668137550354
# After epoch 364 the cost function is 0.8676006197929382
# After epoch 365 the cost function is 0.757070779800415
# After epoch 366 the cost function is 0.6933509707450867
# After epoch 367 the cost function is 0.6723695397377014
# After epoch 368 the cost function is 0.6210619211196899
# After epoch 369 the cost function is 0.7420682311058044
# After epoch 370 the cost function is 0.6630403995513916
# After epoch 371 the cost function is 0.5498971343040466
# After epoch 372 the cost function is 0.5975474119186401
# After epoch 373 the cost function is 0.6665669083595276
# After epoch 374 the cost function is 0.7684282064437866
# After epoch 375 the cost function is 0.6854939460754395
# After epoch 376 the cost function is 0.681989312171936
# After epoch 377 the cost function is 0.604588508605957
# After epoch 378 the cost function is 0.5424606204032898
# After epoch 379 the cost function is 0.5002554059028625
# After epoch 380 the cost function is 0.5631898641586304
# After epoch 381 the cost function is 0.7100069522857666
# After epoch 382 the cost function is 0.5617030262947083
# After epoch 383 the cost function is 0.5272895693778992
# After epoch 384 the cost function is 0.5087869763374329
# After epoch 385 the cost function is 0.49073898792266846
# After epoch 386 the cost function is 0.46993812918663025
# After epoch 387 the cost function is 0.4510726034641266
# After epoch 388 the cost function is 0.43908974528312683
# After epoch 389 the cost function is 0.43131396174430847
# After epoch 390 the cost function is 0.4253678023815155
# After epoch 391 the cost function is 0.42198988795280457
# After epoch 392 the cost function is 0.4272545874118805
# After epoch 393 the cost function is 0.4718340039253235
# After epoch 394 the cost function is 0.6071128249168396
# After epoch 395 the cost function is 0.6110367178916931
# After epoch 396 the cost function is 0.5179535150527954
# After epoch 397 the cost function is 0.48091888427734375
# After epoch 398 the cost function is 0.45311859250068665
# After epoch 399 the cost function is 0.49891239404678345
# After epoch 400 the cost function is 0.44580239057540894
# After epoch 401 the cost function is 0.5377802848815918
# After epoch 402 the cost function is 0.44563499093055725
# After epoch 403 the cost function is 0.5586466789245605
# After epoch 404 the cost function is 0.6251356601715088
# After epoch 405 the cost function is 0.5589740872383118
# After epoch 406 the cost function is 0.46730127930641174
# After epoch 407 the cost function is 0.42823466658592224
# After epoch 408 the cost function is 0.41255390644073486
# After epoch 409 the cost function is 0.46053969860076904
# After epoch 410 the cost function is 0.3813355267047882
# After epoch 411 the cost function is 0.38557377457618713
# After epoch 412 the cost function is 0.3712054491043091
# After epoch 413 the cost function is 0.38265475630760193
# After epoch 414 the cost function is 0.41227492690086365
# After epoch 415 the cost function is 0.5234162211418152
# After epoch 416 the cost function is 0.80478835105896
# After epoch 417 the cost function is 0.7419218420982361
# After epoch 418 the cost function is 0.7305393815040588
# After epoch 419 the cost function is 0.5823454260826111
# After epoch 420 the cost function is 0.5461987257003784
# After epoch 421 the cost function is 0.5926845669746399
# After epoch 422 the cost function is 0.776023805141449
# After epoch 423 the cost function is 0.8208572864532471
# After epoch 424 the cost function is 0.7947074174880981
# After epoch 425 the cost function is 0.7304765582084656
# After epoch 426 the cost function is 0.6577919721603394
# After epoch 427 the cost function is 0.5137026309967041
# After epoch 428 the cost function is 0.40531399846076965
# After epoch 429 the cost function is 0.3587898015975952
# After epoch 430 the cost function is 0.34928277134895325
# After epoch 431 the cost function is 0.3583969175815582
# After epoch 432 the cost function is 0.4280034303665161
# After epoch 433 the cost function is 0.5171899795532227
# After epoch 434 the cost function is 0.4256623387336731
# After epoch 435 the cost function is 0.3569728434085846
# After epoch 436 the cost function is 0.33125534653663635
# After epoch 437 the cost function is 0.3276074230670929
# After epoch 438 the cost function is 0.3301756680011749
# After epoch 439 the cost function is 0.35156479477882385
# After epoch 440 the cost function is 0.36420494318008423
# After epoch 441 the cost function is 0.4351944625377655
# After epoch 442 the cost function is 0.4979109466075897
# After epoch 443 the cost function is 0.34543660283088684
# After epoch 444 the cost function is 0.29809847474098206
# After epoch 445 the cost function is 0.2851651906967163
# After epoch 446 the cost function is 0.280863493680954
# After epoch 447 the cost function is 0.28253912925720215
# After epoch 448 the cost function is 0.2862068712711334
# After epoch 449 the cost function is 0.30538663268089294
# After epoch 450 the cost function is 0.2996526062488556
# After epoch 451 the cost function is 0.32328319549560547
# After epoch 452 the cost function is 0.29798752069473267
# After epoch 453 the cost function is 0.3200763761997223
# After epoch 454 the cost function is 0.34759148955345154
# After epoch 455 the cost function is 0.42501887679100037
# After epoch 456 the cost function is 0.5171923637390137
# After epoch 457 the cost function is 0.39152535796165466
# After epoch 458 the cost function is 0.3268183767795563
# After epoch 459 the cost function is 0.4141000807285309
# After epoch 460 the cost function is 0.6028323769569397
# After epoch 461 the cost function is 0.5555250644683838
# After epoch 462 the cost function is 0.5567440986633301
# After epoch 463 the cost function is 0.45035800337791443
# After epoch 464 the cost function is 0.3661228120326996
# After epoch 465 the cost function is 0.36743050813674927
# After epoch 466 the cost function is 0.4450106918811798
# After epoch 467 the cost function is 0.4478694200515747
# After epoch 468 the cost function is 0.336544007062912
# After epoch 469 the cost function is 0.2952796518802643
# After epoch 470 the cost function is 0.2753809988498688
# After epoch 471 the cost function is 0.24961334466934204
# After epoch 472 the cost function is 0.23125356435775757
# After epoch 473 the cost function is 0.22164680063724518
# After epoch 474 the cost function is 0.21614831686019897
# After epoch 475 the cost function is 0.21149921417236328
# After epoch 476 the cost function is 0.20857420563697815
# After epoch 477 the cost function is 0.20631857216358185
# After epoch 478 the cost function is 0.20732539892196655
# After epoch 479 the cost function is 0.21011269092559814
# After epoch 480 the cost function is 0.2232411950826645
# After epoch 481 the cost function is 0.24858132004737854
# After epoch 482 the cost function is 0.2967461049556732
# After epoch 483 the cost function is 0.27968382835388184
# After epoch 484 the cost function is 0.333343505859375
# After epoch 485 the cost function is 0.4465188980102539
# After epoch 486 the cost function is 0.27604222297668457
# After epoch 487 the cost function is 0.20512893795967102
# After epoch 488 the cost function is 0.19507497549057007
# After epoch 489 the cost function is 0.18981237709522247
# After epoch 490 the cost function is 0.18665485084056854
# After epoch 491 the cost function is 0.1855275183916092
# After epoch 492 the cost function is 0.18680115044116974
# After epoch 493 the cost function is 0.1929083615541458
# After epoch 494 the cost function is 0.20325660705566406
# After epoch 495 the cost function is 0.22304023802280426
# After epoch 496 the cost function is 0.22659578919410706
# After epoch 497 the cost function is 0.21563959121704102
# After epoch 498 the cost function is 0.18104462325572968
# After epoch 499 the cost function is 0.16141510009765625
# After epoch 500 the cost function is 0.14312699437141418
# After epoch 501 the cost function is 0.134019672870636
# After epoch 502 the cost function is 0.12950201332569122
# After epoch 503 the cost function is 0.12568604946136475
# After epoch 504 the cost function is 0.12317314743995667
# After epoch 505 the cost function is 0.12056959420442581
# After epoch 506 the cost function is 0.11974883824586868
# After epoch 507 the cost function is 0.11843565851449966
# After epoch 508 the cost function is 0.12085847556591034
# After epoch 509 the cost function is 0.12156394869089127
# After epoch 510 the cost function is 0.13132867217063904
# After epoch 511 the cost function is 0.13789328932762146
# After epoch 512 the cost function is 0.1772007942199707
# After epoch 513 the cost function is 0.26878222823143005
# After epoch 514 the cost function is 0.4263554811477661
# After epoch 515 the cost function is 0.22520503401756287
# After epoch 516 the cost function is 0.20662349462509155
# After epoch 517 the cost function is 0.23313751816749573
# After epoch 518 the cost function is 0.2123192995786667
# After epoch 519 the cost function is 0.22659620642662048
# After epoch 520 the cost function is 0.32321372628211975
# After epoch 521 the cost function is 0.302486777305603
# After epoch 522 the cost function is 0.38969993591308594
# After epoch 523 the cost function is 0.2290152758359909
# After epoch 524 the cost function is 0.15267853438854218
# After epoch 525 the cost function is 0.0999702662229538
# After epoch 526 the cost function is 0.0840374156832695
# After epoch 527 the cost function is 0.07992243021726608
# After epoch 528 the cost function is 0.0768018439412117
# After epoch 529 the cost function is 0.07416655868291855
# After epoch 530 the cost function is 0.071825310587883
# After epoch 531 the cost function is 0.0697038322687149
# After epoch 532 the cost function is 0.06775124371051788
# After epoch 533 the cost function is 0.06593180447816849
# After epoch 534 the cost function is 0.06422190368175507
# After epoch 535 the cost function is 0.06260238587856293
# After epoch 536 the cost function is 0.06106041744351387
# After epoch 537 the cost function is 0.05958525836467743
# After epoch 538 the cost function is 0.05816953629255295
# After epoch 539 the cost function is 0.05680736154317856
# After epoch 540 the cost function is 0.05549485236406326
# After epoch 541 the cost function is 0.05422911047935486
# After epoch 542 the cost function is 0.05300832912325859
# After epoch 543 the cost function is 0.051830995827913284
# After epoch 544 the cost function is 0.05069582164287567
# After epoch 545 the cost function is 0.049601346254348755
# After epoch 546 the cost function is 0.048545971512794495
# After epoch 547 the cost function is 0.0475279726088047
# After epoch 548 the cost function is 0.046545568853616714
# After epoch 549 the cost function is 0.04559702053666115
# After epoch 550 the cost function is 0.04468066245317459
# After epoch 551 the cost function is 0.04379492625594139
# After epoch 552 the cost function is 0.04293837025761604
# After epoch 553 the cost function is 0.042109642177820206
# After epoch 554 the cost function is 0.0413074865937233
# After epoch 555 the cost function is 0.040530748665332794
# After epoch 556 the cost function is 0.03977833688259125
# After epoch 557 the cost function is 0.03904923051595688
# After epoch 558 the cost function is 0.03834247216582298
# After epoch 559 the cost function is 0.03765714913606644
# After epoch 560 the cost function is 0.03699241206049919
# After epoch 561 the cost function is 0.036347441375255585
# After epoch 562 the cost function is 0.035721465945243835
# After epoch 563 the cost function is 0.035113755613565445
# After epoch 564 the cost function is 0.03452358394861221
# After epoch 565 the cost function is 0.033950306475162506
# After epoch 566 the cost function is 0.0333932600915432
# After epoch 567 the cost function is 0.032851845026016235
# After epoch 568 the cost function is 0.032325468957424164
# After epoch 569 the cost function is 0.03181357681751251
# After epoch 570 the cost function is 0.031315628439188004
# After epoch 571 the cost function is 0.0308311078697443
# After epoch 572 the cost function is 0.030359528958797455
# After epoch 573 the cost function is 0.02990042231976986
# After epoch 574 the cost function is 0.029453327879309654
# After epoch 575 the cost function is 0.029017824679613113
# After epoch 576 the cost function is 0.02859349735081196
# After epoch 577 the cost function is 0.028179951012134552
# After epoch 578 the cost function is 0.02777680940926075
# After epoch 579 the cost function is 0.027383700013160706
# After epoch 580 the cost function is 0.02700028568506241
# After epoch 581 the cost function is 0.026626234874129295
# After epoch 582 the cost function is 0.026261216029524803
# After epoch 583 the cost function is 0.025904936715960503
# After epoch 584 the cost function is 0.025557100772857666
# After epoch 585 the cost function is 0.025217415764927864
# After epoch 586 the cost function is 0.0248856283724308
# After epoch 587 the cost function is 0.024561472237110138
# After epoch 588 the cost function is 0.024244707077741623
# After epoch 589 the cost function is 0.02393507957458496
# After epoch 590 the cost function is 0.023632371798157692
# After epoch 591 the cost function is 0.023336373269557953
# After epoch 592 the cost function is 0.023046858608722687
# After epoch 593 the cost function is 0.022763634100556374
# After epoch 594 the cost function is 0.022486500442028046
# After epoch 595 the cost function is 0.022215280681848526
# After epoch 596 the cost function is 0.021949786692857742
# After epoch 597 the cost function is 0.02168985828757286
# After epoch 598 the cost function is 0.021435312926769257
# After epoch 599 the cost function is 0.021186012774705887
# After epoch 600 the cost function is 0.02094178833067417
# After epoch 601 the cost function is 0.020702507346868515
# After epoch 602 the cost function is 0.02046802081167698
# After epoch 603 the cost function is 0.02023819275200367
# After epoch 604 the cost function is 0.02001289278268814
# After epoch 605 the cost function is 0.01979200541973114
# After epoch 606 the cost function is 0.019575398415327072
# After epoch 607 the cost function is 0.01936296373605728
# After epoch 608 the cost function is 0.019154584035277367
# After epoch 609 the cost function is 0.01895015686750412
# After epoch 610 the cost function is 0.018749570474028587
# After epoch 611 the cost function is 0.018552731722593307
# After epoch 612 the cost function is 0.01835954748094082
# After epoch 613 the cost function is 0.018169915303587914
# After epoch 614 the cost function is 0.017983749508857727
# After epoch 615 the cost function is 0.017800964415073395
# After epoch 616 the cost function is 0.0176214799284935
# After epoch 617 the cost function is 0.017445210367441177
# After epoch 618 the cost function is 0.01727207750082016
# After epoch 619 the cost function is 0.01710200496017933
# After epoch 620 the cost function is 0.016934921965003014
# After epoch 621 the cost function is 0.016770757734775543
# After epoch 622 the cost function is 0.016609445214271545
# After epoch 623 the cost function is 0.0164509117603302
# After epoch 624 the cost function is 0.016295097768306732
# After epoch 625 the cost function is 0.016141939908266068
# After epoch 626 the cost function is 0.01599137671291828
# After epoch 627 the cost function is 0.01584334671497345
# After epoch 628 the cost function is 0.015697795897722244
# After epoch 629 the cost function is 0.015554670244455338
# After epoch 630 the cost function is 0.015413911081850529
# After epoch 631 the cost function is 0.01527546439319849
# After epoch 632 the cost function is 0.01513928547501564
# After epoch 633 the cost function is 0.015005317516624928
# After epoch 634 the cost function is 0.014873516745865345
# After epoch 635 the cost function is 0.014743833802640438
# After epoch 636 the cost function is 0.014616222120821476
# After epoch 637 the cost function is 0.014490637928247452
# After epoch 638 the cost function is 0.01436703559011221
# After epoch 639 the cost function is 0.014245373196899891
# After epoch 640 the cost function is 0.014125609770417213
# After epoch 641 the cost function is 0.01400770153850317
# After epoch 642 the cost function is 0.013891615904867649
# After epoch 643 the cost function is 0.01377730630338192
# After epoch 644 the cost function is 0.013664741069078445
# After epoch 645 the cost function is 0.013553880155086517
# After epoch 646 the cost function is 0.0134446881711483
# After epoch 647 the cost function is 0.013337131589651108
# After epoch 648 the cost function is 0.013231176882982254
# After epoch 649 the cost function is 0.013126790523529053
# After epoch 650 the cost function is 0.01302393525838852
# After epoch 651 the cost function is 0.012922587804496288
# After epoch 652 the cost function is 0.0128227099776268
# After epoch 653 the cost function is 0.012724275700747967
# After epoch 654 the cost function is 0.0126272551715374
# After epoch 655 the cost function is 0.012531619518995285
# After epoch 656 the cost function is 0.012437340803444386
# After epoch 657 the cost function is 0.012344391085207462
# After epoch 658 the cost function is 0.012252744287252426
# After epoch 659 the cost function is 0.012162376195192337
# After epoch 660 the cost function is 0.012073257006704807
# After epoch 661 the cost function is 0.011985366232693195
# After epoch 662 the cost function is 0.011898679658770561
# After epoch 663 the cost function is 0.011813174933195114
# After epoch 664 the cost function is 0.011728824116289616
# After epoch 665 the cost function is 0.011645607650279999
# After epoch 666 the cost function is 0.011563505977392197
# After epoch 667 the cost function is 0.011482493951916695
# After epoch 668 the cost function is 0.011402551084756851
# After epoch 669 the cost function is 0.011323660612106323
# After epoch 670 the cost function is 0.011245801113545895
# After epoch 671 the cost function is 0.0111689493060112
# After epoch 672 the cost function is 0.011093092150986195
# After epoch 673 the cost function is 0.011018208228051662
# After epoch 674 the cost function is 0.01094428077340126
# After epoch 675 the cost function is 0.010871287435293198
# After epoch 676 the cost function is 0.010799219831824303
# After epoch 677 the cost function is 0.010728052817285061
# After epoch 678 the cost function is 0.010657774284482002
# After epoch 679 the cost function is 0.010588365606963634
# After epoch 680 the cost function is 0.010519815608859062
# After epoch 681 the cost function is 0.010452105663716793
# After epoch 682 the cost function is 0.010385219007730484
# After epoch 683 the cost function is 0.010319146327674389
# After epoch 684 the cost function is 0.01025386806577444
# After epoch 685 the cost function is 0.010189373046159744
# After epoch 686 the cost function is 0.01012564916163683
# After epoch 687 the cost function is 0.010062678717076778
# After epoch 688 the cost function is 0.01000045146793127
# After epoch 689 the cost function is 0.009938955307006836
# After epoch 690 the cost function is 0.00987817533314228
# After epoch 691 the cost function is 0.009818102233111858
# After epoch 692 the cost function is 0.009758718311786652
# After epoch 693 the cost function is 0.009700020775198936
# After epoch 694 the cost function is 0.00964199285954237
# After epoch 695 the cost function is 0.009584622457623482
# After epoch 696 the cost function is 0.0095279011875391
# After epoch 697 the cost function is 0.009471816942095757
# After epoch 698 the cost function is 0.009416359476745129
# After epoch 699 the cost function is 0.009361518546938896
# After epoch 700 the cost function is 0.009307284839451313
# After epoch 701 the cost function is 0.009253647178411484
# After epoch 702 the cost function is 0.009200599044561386
# After epoch 703 the cost function is 0.0091481264680624
# After epoch 704 the cost function is 0.00909622386097908
# After epoch 705 the cost function is 0.009044880047440529
# After epoch 706 the cost function is 0.00899408757686615
# After epoch 707 the cost function is 0.008943837136030197
# After epoch 708 the cost function is 0.008894119411706924
# After epoch 709 the cost function is 0.008844929747283459
# After epoch 710 the cost function is 0.00879625417292118
# After epoch 711 the cost function is 0.008748090825974941
# After epoch 712 the cost function is 0.00870042759925127
# After epoch 713 the cost function is 0.008653257973492146
# After epoch 714 the cost function is 0.00860657449811697
# After epoch 715 the cost function is 0.008560370653867722
# After epoch 716 the cost function is 0.008514637127518654
# After epoch 717 the cost function is 0.008469370193779469
# After epoch 718 the cost function is 0.008424561470746994
# After epoch 719 the cost function is 0.008380201645195484
# After epoch 720 the cost function is 0.008336285129189491
# After epoch 721 the cost function is 0.008292810060083866
# After epoch 722 the cost function is 0.00824976246803999
# After epoch 723 the cost function is 0.008207142353057861
# After epoch 724 the cost function is 0.008164940401911736
# After epoch 725 the cost function is 0.008123153820633888
# After epoch 726 the cost function is 0.008081769570708275
# After epoch 727 the cost function is 0.008040789514780045
# After epoch 728 the cost function is 0.008000204339623451
# After epoch 729 the cost function is 0.007960008457303047
# After epoch 730 the cost function is 0.007920198142528534
# After epoch 731 the cost function is 0.007880765944719315
# After epoch 732 the cost function is 0.007841707207262516
# After epoch 733 the cost function is 0.007803016807883978
# After epoch 734 the cost function is 0.007764691021293402
# After epoch 735 the cost function is 0.007726720534265041
# After epoch 736 the cost function is 0.007689105346798897
# After epoch 737 the cost function is 0.007651838473975658
# After epoch 738 the cost function is 0.0076149143278598785
# After epoch 739 the cost function is 0.007578331045806408
# After epoch 740 the cost function is 0.007542080711573362
# After epoch 741 the cost function is 0.007506163790822029
# After epoch 742 the cost function is 0.0074705686420202255
# After epoch 743 the cost function is 0.007435296196490526
# After epoch 744 the cost function is 0.007400341797620058
# After epoch 745 the cost function is 0.007365697994828224
# After epoch 746 the cost function is 0.007331365253776312
# After epoch 747 the cost function is 0.007297335658222437
# After epoch 748 the cost function is 0.007263605482876301
# After epoch 749 the cost function is 0.00723017193377018
# After epoch 750 the cost function is 0.007197035476565361
# After epoch 751 the cost function is 0.007164184935390949
# After epoch 752 the cost function is 0.00713161937892437
# After epoch 753 the cost function is 0.007099337410181761
# After epoch 754 the cost function is 0.0070673334412276745
# After epoch 755 the cost function is 0.0070356037467718124
# After epoch 756 the cost function is 0.007004144601523876
# After epoch 757 the cost function is 0.006972953677177429
# After epoch 758 the cost function is 0.00694202771410346
# After epoch 759 the cost function is 0.006911362987011671
# After epoch 760 the cost function is 0.00688095623627305
# After epoch 761 the cost function is 0.006850803270936012
# After epoch 762 the cost function is 0.006820902228355408
# After epoch 763 the cost function is 0.006791249383240938
# After epoch 764 the cost function is 0.0067618428729474545
# After epoch 765 the cost function is 0.006732678506523371
# After epoch 766 the cost function is 0.006703751627355814
# After epoch 767 the cost function is 0.006675064563751221
# After epoch 768 the cost function is 0.006646609865128994
# After epoch 769 the cost function is 0.006618386134505272
# After epoch 770 the cost function is 0.006590390577912331
# After epoch 771 the cost function is 0.006562619004398584
# After epoch 772 the cost function is 0.006535072345286608
# After epoch 773 the cost function is 0.006507746409624815
# After epoch 774 the cost function is 0.006480637937784195
# After epoch 775 the cost function is 0.006453743204474449
# After epoch 776 the cost function is 0.006427060812711716
# After epoch 777 the cost function is 0.006400587968528271
# After epoch 778 the cost function is 0.00637432374060154
# After epoch 779 the cost function is 0.006348265800625086
# After epoch 780 the cost function is 0.006322409026324749
# After epoch 781 the cost function is 0.006296755280345678
# After epoch 782 the cost function is 0.0062712980434298515
# After epoch 783 the cost function is 0.006246036849915981
# After epoch 784 the cost function is 0.0062209684401750565
# After epoch 785 the cost function is 0.006196091882884502
# After epoch 786 the cost function is 0.006171405781060457
# After epoch 787 the cost function is 0.006146905943751335
# After epoch 788 the cost function is 0.0061225928366184235
# After epoch 789 the cost function is 0.006098461803048849
# After epoch 790 the cost function is 0.006074512377381325
# After epoch 791 the cost function is 0.006050742231309414
# After epoch 792 the cost function is 0.00602714903652668
# After epoch 793 the cost function is 0.0060037304647266865
# After epoch 794 the cost function is 0.005980485584586859
# After epoch 795 the cost function is 0.005957411602139473
# After epoch 796 the cost function is 0.005934508051723242
# After epoch 797 the cost function is 0.005911771673709154
# After epoch 798 the cost function is 0.005889201536774635
# After epoch 799 the cost function is 0.005866795778274536
# After epoch 800 the cost function is 0.00584455206990242
# After epoch 801 the cost function is 0.005822467617690563
# After epoch 802 the cost function is 0.0058005438186228275
# After epoch 803 the cost function is 0.0057787769474089146
# After epoch 804 the cost function is 0.005757165141403675
# After epoch 805 the cost function is 0.005735707934945822
# After epoch 806 the cost function is 0.0057144020684063435
# After epoch 807 the cost function is 0.0056932480074465275
# After epoch 808 the cost function is 0.005672243889421225
# After epoch 809 the cost function is 0.005651385989040136
# After epoch 810 the cost function is 0.005630673374980688
# After epoch 811 the cost function is 0.005610107909888029
# After epoch 812 the cost function is 0.005589683074504137
# After epoch 813 the cost function is 0.0055694011971354485
# After epoch 814 the cost function is 0.005549259018152952
# After epoch 815 the cost function is 0.005529256537556648
# After epoch 816 the cost function is 0.005509389564394951
# After epoch 817 the cost function is 0.005489660426974297
# After epoch 818 the cost function is 0.0054700649343431
# After epoch 819 the cost function is 0.005450602155178785
# After epoch 820 the cost function is 0.0054312716238200665
# After epoch 821 the cost function is 0.005412073340266943
# After epoch 822 the cost function is 0.005393003113567829
# After epoch 823 the cost function is 0.005374059546738863
# After epoch 824 the cost function is 0.005355244968086481
# After epoch 825 the cost function is 0.005336554255336523
# After epoch 826 the cost function is 0.005317988805472851
# After epoch 827 the cost function is 0.005299545358866453
# After epoch 828 the cost function is 0.0052812243811786175
# After epoch 829 the cost function is 0.005263024475425482
# After epoch 830 the cost function is 0.00524494331330061
# After epoch 831 the cost function is 0.0052269818261265755
# After epoch 832 the cost function is 0.005209135822951794
# After epoch 833 the cost function is 0.005191407166421413
# After epoch 834 the cost function is 0.005173792131245136
# After epoch 835 the cost function is 0.005156293045729399
# After epoch 836 the cost function is 0.005138906184583902
# After epoch 837 the cost function is 0.005121629219502211
# After epoch 838 the cost function is 0.005104463547468185
# After epoch 839 the cost function is 0.005087409168481827
# After epoch 840 the cost function is 0.005070460960268974
# After epoch 841 the cost function is 0.0050536226481199265
# After epoch 842 the cost function is 0.005036889109760523
# After epoch 843 the cost function is 0.0050202626734972
# After epoch 844 the cost function is 0.0050037396140396595
# After epoch 845 the cost function is 0.004987319931387901
# After epoch 846 the cost function is 0.004971003159880638
# After epoch 847 the cost function is 0.004954788833856583
# After epoch 848 the cost function is 0.004938675090670586
# After epoch 849 the cost function is 0.004922660533338785
# After epoch 850 the cost function is 0.004906746093183756
# After epoch 851 the cost function is 0.004890928044915199
# After epoch 852 the cost function is 0.004875208251178265
# After epoch 853 the cost function is 0.004859584383666515
# After epoch 854 the cost function is 0.004844056908041239
# After epoch 855 the cost function is 0.004828623030334711
# After epoch 856 the cost function is 0.0048132832162082195
# After epoch 857 the cost function is 0.004798036068677902
# After epoch 858 the cost function is 0.004782881122082472
# After epoch 859 the cost function is 0.004767817445099354
# After epoch 860 the cost function is 0.004752843640744686
# After epoch 861 the cost function is 0.0047379606403410435
# After epoch 862 the cost function is 0.004723165649920702
# After epoch 863 the cost function is 0.004708458669483662
# After epoch 864 the cost function is 0.004693838767707348
# After epoch 865 the cost function is 0.004679305944591761
# After epoch 866 the cost function is 0.004664857871830463
# After epoch 867 the cost function is 0.004650495480746031
# After epoch 868 the cost function is 0.004636217840015888
# After epoch 869 the cost function is 0.004622023086994886
# After epoch 870 the cost function is 0.004607911221683025
# After epoch 871 the cost function is 0.004593882709741592
# After epoch 872 the cost function is 0.004579933360219002
# After epoch 873 the cost function is 0.004566066432744265
# After epoch 874 the cost function is 0.004552279133349657
# After epoch 875 the cost function is 0.004538571462035179
# After epoch 876 the cost function is 0.004524940624833107
# After epoch 877 the cost function is 0.004511390347033739
# After epoch 878 the cost function is 0.00449791457504034
# After epoch 879 the cost function is 0.004484518431127071
# After epoch 880 the cost function is 0.004471196793019772
# After epoch 881 the cost function is 0.004457950592041016
# After epoch 882 the cost function is 0.0044447798281908035
# After epoch 883 the cost function is 0.004431683104485273
# After epoch 884 the cost function is 0.004418659023940563
# After epoch 885 the cost function is 0.004405709449201822
# After epoch 886 the cost function is 0.0043928311206400394
# After epoch 887 the cost function is 0.004380025435239077
# After epoch 888 the cost function is 0.00436728959903121
# After epoch 889 the cost function is 0.004354625474661589
# After epoch 890 the cost function is 0.004342030733823776
# After epoch 891 the cost function is 0.004329505376517773
# After epoch 892 the cost function is 0.004317049868404865
# After epoch 893 the cost function is 0.00430466141551733
# After epoch 894 the cost function is 0.004292341414839029
# After epoch 895 the cost function is 0.004280088469386101
# After epoch 896 the cost function is 0.0042679025791585445
# After epoch 897 the cost function is 0.004255782347172499
# After epoch 898 the cost function is 0.0042437282390892506
# After epoch 899 the cost function is 0.004231737926602364
# After epoch 900 the cost function is 0.004219813738018274
# After epoch 901 the cost function is 0.004207952413707972
# After epoch 902 the cost function is 0.004196155816316605
# After epoch 903 the cost function is 0.004184422083199024
# After epoch 904 the cost function is 0.004172750283032656
# After epoch 905 the cost function is 0.004161140415817499
# After epoch 906 the cost function is 0.004149592947214842
# After epoch 907 the cost function is 0.004138106480240822
# After epoch 908 the cost function is 0.0041266800835728645
# After epoch 909 the cost function is 0.004115313291549683
# After epoch 910 the cost function is 0.004104007966816425
# After epoch 911 the cost function is 0.0040927608497440815
# After epoch 912 the cost function is 0.0040815724059939384
# After epoch 913 the cost function is 0.004070442169904709
# After epoch 914 the cost function is 0.004059370141476393
# After epoch 915 the cost function is 0.004048355855047703
# After epoch 916 the cost function is 0.004037398379296064
# After epoch 917 the cost function is 0.004026496782898903
# After epoch 918 the cost function is 0.004015651531517506
# After epoch 919 the cost function is 0.004004862625151873
# After epoch 920 the cost function is 0.003994128201156855
# After epoch 921 the cost function is 0.003983448725193739
# After epoch 922 the cost function is 0.0039728255942463875
# After epoch 923 the cost function is 0.0039622546173632145
# After epoch 924 the cost function is 0.003951737191528082
# After epoch 925 the cost function is 0.003941273782402277
# After epoch 926 the cost function is 0.003930862993001938
# After epoch 927 the cost function is 0.003920504357665777
# After epoch 928 the cost function is 0.003910197410732508
# After epoch 929 the cost function is 0.0038999433163553476
# After epoch 930 the cost function is 0.003889739513397217
# After epoch 931 the cost function is 0.003879586700350046
# After epoch 932 the cost function is 0.003869485342875123
# After epoch 933 the cost function is 0.003859433811157942
# After epoch 934 the cost function is 0.003849431872367859
# After epoch 935 the cost function is 0.0038394788280129433
# After epoch 936 the cost function is 0.003829575376585126
# After epoch 937 the cost function is 0.003819720121100545
# After epoch 938 the cost function is 0.003809913992881775
# After epoch 939 the cost function is 0.003800154896453023
# After epoch 940 the cost function is 0.0037904444616287947
# After epoch 941 the cost function is 0.0037807815242558718
# After epoch 942 the cost function is 0.0037711658515036106
# After epoch 943 the cost function is 0.0037615958135575056
# After epoch 944 the cost function is 0.003752071876078844
# After epoch 945 the cost function is 0.0037425945047289133
# After epoch 946 the cost function is 0.0037331627681851387
# After epoch 947 the cost function is 0.0037237766664475203
# After epoch 948 the cost function is 0.0037144345697015524
# After epoch 949 the cost function is 0.0037051376421004534
# After epoch 950 the cost function is 0.003695886116474867
# After epoch 951 the cost function is 0.003686677897349
# After epoch 952 the cost function is 0.0036775129847228527
# After epoch 953 the cost function is 0.0036683923099189997
# After epoch 954 the cost function is 0.003659314475953579
# After epoch 955 the cost function is 0.003650279715657234
# After epoch 956 the cost function is 0.00364128639921546
# After epoch 957 the cost function is 0.0036323361564427614
# After epoch 958 the cost function is 0.0036234280560165644
# After epoch 959 the cost function is 0.003614561865106225
# After epoch 960 the cost function is 0.0036057373508810997
# After epoch 961 the cost function is 0.003596952883526683
# After epoch 962 the cost function is 0.0035882098600268364
# After epoch 963 the cost function is 0.0035795068833976984
# After epoch 964 the cost function is 0.0035708441864699125
# After epoch 965 the cost function is 0.0035622217692434788
# After epoch 966 the cost function is 0.003553639631718397
# After epoch 967 the cost function is 0.003545096144080162
# After epoch 968 the cost function is 0.0035365924704819918
# After epoch 969 the cost function is 0.003528126748278737
# After epoch 970 the cost function is 0.003519700840115547
# After epoch 971 the cost function is 0.0035113126505166292
# After epoch 972 the cost function is 0.0035029626451432705
# After epoch 973 the cost function is 0.0034946512896567583
# After epoch 974 the cost function is 0.0034863760229200125
# After epoch 975 the cost function is 0.003478139638900757
# After epoch 976 the cost function is 0.0034699400421231985
# After epoch 977 the cost function is 0.0034617760684341192
# After epoch 978 the cost function is 0.003453650278970599
# After epoch 979 the cost function is 0.003445560345426202
# After epoch 980 the cost function is 0.003437506500631571
# After epoch 981 the cost function is 0.003429488278925419
# After epoch 982 the cost function is 0.003421506844460964
# After epoch 983 the cost function is 0.0034135591704398394
# After epoch 984 the cost function is 0.003405648283660412
# After epoch 985 the cost function is 0.0033977723214775324
# After epoch 986 the cost function is 0.0033899301197379827
# After epoch 987 the cost function is 0.003382123773917556
# After epoch 988 the cost function is 0.003374350257217884
# After epoch 989 the cost function is 0.003366611199453473
# After epoch 990 the cost function is 0.00335890706628561
# After epoch 991 the cost function is 0.003351234830915928
# After epoch 992 the cost function is 0.00334359728731215
# After epoch 993 the cost function is 0.0033359932713210583
# After epoch 994 the cost function is 0.003328421153128147
# After epoch 995 the cost function is 0.0033208830282092094
# After epoch 996 the cost function is 0.0033133765682578087
# After epoch 997 the cost function is 0.003305902471765876
# After epoch 998 the cost function is 0.0032984602730721235
# After epoch 999 the cost function is 0.00329105113632977

# %% [markdown]
# Let's take a look at the accuracy as well. Once again this will take while to run. While it's running, make a prediction for what you think the accuracy of the training data will be.
#
# **What is the highest accuracy you think we can achieve for the training data?**
#
# **At that same time, what do you think the accuracy of the validation set will be?**

# %%
target = get_target(label_100)
target_valid = get_target(label_valid[:100])
acc_train_100 = []
acc_valid_100 = []
for model, epoch in zip(models_100, range(len(models_100))):
  if epoch % 10 == 0:
    print("On epoch ", epoch, " of ", len(models_100))

  pred = model(torch.tensor(image_train[:100], device=device))
  acc_train_100.append(accuracy(pred, target))


  pred = model(torch.tensor(image_valid[:100], device=device))
  acc_valid_100.append(accuracy(pred, target_valid))
print("Done calculating accuracy. Run next cell for plot")
# Out:
# On epoch  0  of  1000
# On epoch  10  of  1000
# On epoch  20  of  1000
# On epoch  30  of  1000
# On epoch  40  of  1000
# On epoch  50  of  1000
# On epoch  60  of  1000
# On epoch  70  of  1000
# On epoch  80  of  1000
# On epoch  90  of  1000
# On epoch  100  of  1000
# On epoch  110  of  1000
# On epoch  120  of  1000
# On epoch  130  of  1000
# On epoch  140  of  1000
# On epoch  150  of  1000
# On epoch  160  of  1000
# On epoch  170  of  1000
# On epoch  180  of  1000
# On epoch  190  of  1000
# On epoch  200  of  1000
# On epoch  210  of  1000
# On epoch  220  of  1000
# On epoch  230  of  1000
# On epoch  240  of  1000
# On epoch  250  of  1000
# On epoch  260  of  1000
# On epoch  270  of  1000
# On epoch  280  of  1000
# On epoch  290  of  1000
# On epoch  300  of  1000
# On epoch  310  of  1000
# On epoch  320  of  1000
# On epoch  330  of  1000
# On epoch  340  of  1000
# On epoch  350  of  1000
# On epoch  360  of  1000
# On epoch  370  of  1000
# On epoch  380  of  1000
# On epoch  390  of  1000
# On epoch  400  of  1000
# On epoch  410  of  1000
# On epoch  420  of  1000
# On epoch  430  of  1000
# On epoch  440  of  1000
# On epoch  450  of  1000
# On epoch  460  of  1000
# On epoch  470  of  1000
# On epoch  480  of  1000
# On epoch  490  of  1000
# On epoch  500  of  1000
# On epoch  510  of  1000
# On epoch  520  of  1000
# On epoch  530  of  1000
# On epoch  540  of  1000
# On epoch  550  of  1000
# On epoch  560  of  1000
# On epoch  570  of  1000
# On epoch  580  of  1000
# On epoch  590  of  1000
# On epoch  600  of  1000
# On epoch  610  of  1000
# On epoch  620  of  1000
# On epoch  630  of  1000
# On epoch  640  of  1000
# On epoch  650  of  1000
# On epoch  660  of  1000
# On epoch  670  of  1000
# On epoch  680  of  1000
# On epoch  690  of  1000
# On epoch  700  of  1000
# On epoch  710  of  1000
# On epoch  720  of  1000
# On epoch  730  of  1000
# On epoch  740  of  1000
# On epoch  750  of  1000
# On epoch  760  of  1000
# On epoch  770  of  1000
# On epoch  780  of  1000
# On epoch  790  of  1000
# On epoch  800  of  1000
# On epoch  810  of  1000
# On epoch  820  of  1000
# On epoch  830  of  1000
# On epoch  840  of  1000
# On epoch  850  of  1000
# On epoch  860  of  1000
# On epoch  870  of  1000
# On epoch  880  of  1000
# On epoch  890  of  1000
# On epoch  900  of  1000
# On epoch  910  of  1000
# On epoch  920  of  1000
# On epoch  930  of  1000
# On epoch  940  of  1000
# On epoch  950  of  1000
# On epoch  960  of  1000
# On epoch  970  of  1000
# On epoch  980  of  1000
# On epoch  990  of  1000
# Done calculating accuracy. Run next cell for plot

# %%
log_model = lambda x, a, b, c, d: a/(1+np.exp(-b*(x-c))) + d

trunc_epoch = epochs_100[0:]
trunc_train = costs_100[0:]
trunc_valid = costs_valid_100[0:]

params, cov = curve_fit(log_model, trunc_epoch, acc_train_100, p0=[.9, 1, 40, .12])
model_train = log_model(np.array(trunc_epoch), *params)
print(f"The carrying capacity of the cost curve for the training data is {(params[0]+params[3])*100:.2f}%.")

# plot the cost function as a function of epoch
fig = plt.figure(figsize=(8,6))
plt.title("Accuracy vs. training epoch")
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(which='both', axis='both')
#plt.plot(epochs_100, acc_train_100, 'r-', label="Training set")
plt.plot(epochs_100, acc_valid_100, 'b-', label="Validation set")
#plt.plot(epochs_100, model_train, 'r--', label="Logistic fit")
#plt.plot(epochs_100, model_valid, 'b--', label="Validation set")
plt.legend()
plt.show()

fig = plt.figure(figsize=(8,6))
plt.title("Accuracy vs. training epoch")
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(which='both', axis='both')
plt.plot(epochs_100, acc_train_100, 'r-', label="Training set")
#plt.plot(epochs_100, acc_valid_100, 'b-', label="Validation set")
plt.plot(epochs_100, model_train, 'r--', label="Logistic fit")
#plt.plot(epochs_100, model_valid, 'b--', label="Validation set")
plt.legend()
plt.show()
# Out:
# The carrying capacity of the cost curve for the training data is 101.14%.

# %% [markdown]
# **Compare your prediction to what you saw in the above plot.**
#
# **What is the maximum accuracy of the training set with 100 example? With 50,000 examples?**
#
# **Why can our model memorize the smaller training set, but not the larger training set? How could we modify our model so it could learn the full training set?**
#
# **Why do you think the accuracy on the validation set is sometimes increasing? What accuracy is it trending towards?**

# %% [markdown]
# # Bad data, bad model
#
# We just trained a model that achieved 99% accuracy! That right there with the worlds best models, right? There's just one problem. It performs worse then guessing on any image it hasn't seen before. Not the most useful model, is it? This is an exmaple of **over-training** or **over-fitting**. We hyper-specalize our model to the point of uselessness. We say this even before we taught our model to memorize 100 images. In our model at the start of this notebook the cost function of the validation set began creeping up over time even as the cost function of the training set continued to fall. That's a clear sign that we began to over-fit our model.
#
# # Universality of Neural Networks
# In any machine learning model, the data used to train it is the *most* important component. [The Universal Approximation Theorem](https://towardsdatascience.com/neural-networks-and-the-universal-approximation-theorem-8a389a33d30a) guarantees that a neural network (with enough complexity) can be used to approximate *any* function, regardless of the number of inputs or outputs. Assuming of course, we have enough examples of the function to show the neural net.
#
# The fact that you need data to train any useful model is, I would argue, one of the [dominent forces in the economy](https://www.economist.com/special-report/2020-02-22) (particularly in the tech sector). Any company that provides a free service on the internet (social media, Google, etc.) is probably in the buisness of collecting and using user data. This is often the driving force (or at least *a* driving force) behind decisions around availability of data through APIs. In the past year, [Twitter](https://www.theverge.com/2023/2/2/23582615/twitter-removing-free-api-developer-apps-price-announcement) and [Reddit](https://en.wikipedia.org/wiki/2023_Reddit_API_controversy) both made large changes to their API pricing structures. Reddit's CEO has [talked explicity](https://www.nytimes.com/2023/04/18/technology/reddit-ai-openai-google.html) about how the change is motivated by a desire to profit off of the data (post and comments on reddit) that is being used to train large language models like the one that underlies ChatGPT.

# %% [markdown]
# # Homework
#
# Pick some situation where you encounter (or thing you encounter) some machine learning based model or algorithm. Suppose you were to design that algorithm:
#
# 1. What is the algorithm doing?
# 1. What is the cost function for the algorithm?
# 1. What data would you need to train this model? What are the inputs and outputs of the model?

# %% [markdown]
# # Unit 5 Assessment - Machine Leanring
#
# ## Instructions
#
# In this assessment, you will answer questions about machine learning and interprate the results of machine learning models.
#
# Scores are determined by:
#
# - Successfully starting the C Level = 50 pts
# - Perfectly completing the C Level = 75 pts
# - Perfectly completing the B and C Levels = 85 pts
# - Perfectly completing the A, B, and C Levels = 100 pts
#
# You may use your Colab notebooks, and any links to web sites I provide. (You may not use any other person or web site or book or resource, in general. This includes any discussion with classmates or other people on the subject matter.) **You should only make a single copy of this assessment**, and then edit just that copy. We will discuss this bit and class and may make some changes.
#
# You may ask me for help **once**; however, you may ask for clarification as often as needed.
#
# Add additional cells for both code and markdown as needed. **Write answers to questions in narrative form in markdown.** You may print values you need in your code, and then use these values in a written response. All answers should be in the form of markdown or graphs. **Show all your work.** Calculations should be done in code cells instead of on a calculator.
#
# All graphs should have correct titles and axis labels (with units).
#
# The assesment should be worked on only in-class.
#
#
# ## Grade
#
# Level | Grade | Comment
# --- | --- | ---
# C (75 pts) | |
# B (10 pts) | |
# A (15 pts) | |
# Total |

# %% [markdown]
# # Level C
#
# ## Exercise 0
#
# 1. Save a copy of this notebook to Google Drive. Have you already shared your Google Colabortory folder with "hpuphysicsdepartment@gmail.com"? If not, then be sure to share your folder.
#
# 2. Add a text cell above and type your name as a level one heading in markdown. (A level one heading starts with # on its own line.)
#
# 3. Run the `import` statements below to add packages.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Exercise 1
#
# When we say we are "training a model", what does that mean? In other words, what mathematical process is happening when we are training a model?
#
# When we are training a model we are fitting the weights and biases. This is like an empirical model. The method we use to fit these model parameters is stochastic gradient descent which is like a dynamic model.

# %% [markdown]
# ## Exercise 2
#
# In the context of machine learning, what is a cost function? What does it tell us about the model's performance?
#
# The cost function defines how "well" our model is doing. The lower the cost function, the closer the output of the model is to the desired output.

# %% [markdown]
# ## Exercise 3
#
# In the context of machine learning, what is an activation function? Why is it used in machine learning?
#
# The activation function "squishes" the values in the neurons to be between 0 or 1 (if it is the sigmoid function). It is needed to our models have some non-linearity in them. Otherwise we would only be able to fit linear functions, and most functions are non-linear!

# %% [markdown]
# ## Exercise 4
#
# Define "training set" and "validation set". Describe the purpose of using both a training and a validation set when training and evaluating a model.
#
# The training set is what is used to updated the model parameters when training a model. For a model to be useful, it should also perform well on data it was not exposed to while training. That is where the validation set comes in. It allows us to evaluate how well the model is doing on *new* data, which is what we actually care about.

# %% [markdown]
# # Level B
#
# ## Exercise 1
#
# A common cost function is the mean squared error loss (or cost). This is the cost function we have used in class and seen in Sanderson's videos. Suppose we have a neural network with four output neurons. For some input data, the model outputs $\left[\frac{1}{3}, 0, \frac{2}{3}, 1\right]$. The target (or expected) output is $[0, 0, 0, 1]$. Calculate the value of the mean squared error cost function for this case.

# %% [markdown]
# The value of the cost function is 0.139. You could also do $(0-1/3)^2 + (0-0)^2 + (0-2/3)^2 + (1-1)^2$

# %%
target = np.array([0,0,0,1])
predictions = np.array([1/3,0,2/3,1])

mse = np.mean((target - predictions) ** 2)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 0.1388888888888889

# %% [markdown]
# ## Exercise 2
#
# What is the value of the MSE cost function if the model is performing perfectly?
#
# It would be 0.

# %% [markdown]
# ## Exercise 3
#
# What is the expected long term (after many epochs of training) behavior of the cost function evaluated on both the training and validation data sets?
#
# The cost function should continuously decrease for the training data. The cost function for the validation set should level off at some point.

# %% [markdown]
# ## Exercise 4
#
# How does the use of the gradient descent (or stochastic gradient descent) method allow us to train a model?
#
# It is like a dynamic model. It allows us to calculate the rate of change for each model parameter that will maximally decrease the value of the cost function. We can then "walk" in that direction by updating each parameter using the rate of change and a step size (learning rate).

# %% [markdown]
# # Level A
#
# **The true level A will involve training a model, and analysing its behavior like we did for the digit recognition problem.** This example, just has you analyzing an cost curve rather than generating one yourself.

# %% [markdown]
# ## Exercise 1
#
# Make a sketch for the cost function as a function of epoch for a model that is being overtrained. Your sketch should include the cost curves for both the validation and training sets.

# %% [markdown]
# ## Exercise 2
#
# Consider the following graph of a machine learning model being trained. At what epoch should we stop training the model? Why?
#
# <img src="https://github.com/anthoak13/HNR-1303-F23/blob/main/unit-05/05-10-practice/CostFunction.png?raw=true" width="500" align="center">
#
# Somewhere around 40. Why?

# %% [markdown]
# ## Exercise 3
#
# Consider the connection between the gradient descent method used to train neural networks and the dynamic models we studied in the previous unit. Gradient descent follows the same pattern we have seen in the past:
#
# $$\text{future value} = \text{current value} + \text{rate of change} * \text{step size}$$
#
# a) In the gradient descent method, what is the rate of change? the rate of change of the cost function w.r.t thee model parameter.
#
# b) What do we call the step size in gradient descent? The learning rate.
#
# C) Suppose you train a model with three different step sizes and you get the following three different cost curves. The three curves are shown below in two plots (because the scale makes it hard to see step size C in the first plot). Rank the three step sizes from smallest to largest. Explain your reasoning.
#
# <img src="https://github.com/anthoak13/HNR-1303-F23/blob/main/unit-05/05-10-practice/CostFunctionAll.png?raw=true" width="500" align="center">
# <img src="https://github.com/anthoak13/HNR-1303-F23/blob/main/unit-05/05-10-practice/CostFunctionZoom.png?raw=true" width="500" align="center">

# %% [markdown]
# If we are taking a larger step-size then we should be converging to a minimum more quickly. So C should have the largest step size, then A, and finally B.

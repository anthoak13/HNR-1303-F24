# %% [markdown]
# # Introduction to Machine Learning (and Neural Networks)
#
# Grant Sanderson in a series on his YouTube channel 3blue1brown explores the mathematics underlying nueral networks. In my opinion he does an exellent job of motivating the ideas behind these tools without getting too bogged down in the mathematical details.
#
# The two videos can be played by running the two cells below. The videos are about 18 minutes each. It is not necessary to watch the bits after the credits where Sanderson is interviewing Lisha Li.
#
# For class, I would like you to watch two videos, linked below, and answer questions based on the video. Most of the questions focus on how what he discusses in the video is simply a re-skin of the mathematics we discussed in the unit on empircal models.  I suggest reviewing (and maybe printing) the questions before watching the video. Then, as you watch the video, occasionally pause the video and make notes on the various questions. Otherwise, you may forget the details before the end of the video.
#
# In class, each group will present their answer to, and lead a disucssion on, one of the questions.

# %% [markdown]
# # [What is a Neural Network](https://www.youtube.com/watch?v=aircAruvnKk)

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('aircAruvnKk', width=800, height=400)

# %% [markdown]
# ## Question 1
#
# In the context of a nueral network, what is a neuron? What defines the connection between two neturons in a network?

# %% [markdown]
# ## Question 2
#
# In the example discussed in the video, there are four layers in the neural network. What is the purpose of the first and last layer of neurons? What is the purpose of the two middle, or "hidden" layers?

# %% [markdown]
# ## Question 3
#
# We have seen the sigmoid function a few times in this class under a different name. What else is that function called and in what context have we seen it before? What is its purpose in the context of neural networks?

# %% [markdown]
# ## Question 4
#
# In the context of machine learning, "learning" refers to what modeling technique we have already studied in this class?

# %% [markdown]
# # [Gradient Descent (or how a neural network learns)](https://www.youtube.com/watch?v=IHZwWFHWa-w)

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('IHZwWFHWa-w', width=800, height=400)

# %% [markdown]
# ## Question 1
#
# What is needed to train a netural network? In what ways does this differ from how we have constructed models in the past? In what ways is it similar?

# %% [markdown]
# ## Question 2
#
# We have seen the exact same "cost" function that Sanderson introduces before. What was the context for the "cost" function, and how have we used it in the past?

# %% [markdown]
# ## Question 3
#
# Sanderson discusses a method for finding the minimum of a function. What determines if we find a global or local minimum? How does this tie into what we learning when fitting empirical models in unit 3?

# %% [markdown]
# ## Question 4
#
# After watching these two videos, what would you rank as some of the biggest benifits of using a neural network rather than one of the traditional modeling techniques we have discussed previously? What would you rank as some of the biggest potential drawbacks?

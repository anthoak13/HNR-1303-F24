# %% [markdown]
# # Rubric for Group Report on Modified SIR Model
# **Total: 20 Points (5 categories)**
#
# ---
#
# ### **1. Reporting, Structure, and Quality (25%)**
# This section evaluates the overall clarity, organization, and quality of the group’s report, including how well they integrate the code, writing, and analysis.
#
# - **A (Excellent)**: The report is exceptionally well-organized, with a clear structure that integrates code, writing, and analysis seamlessly. Writing is concise, logical, and free of errors. Figures and plots are well-labeled, clearly contributing to the analysis. Code is well-explained and smoothly integrated into the narrative. The flow between sections is logical, enhancing the reader’s understanding.
# - **B (Good)**: The report is well-organized with minor issues in structure or clarity. Integration of code and analysis is present but could be more cohesive. Writing contains a few minor grammatical or structural errors, but they do not significantly detract from understanding. Figures and plots are present, mostly well-labeled, but some may lack explanation.
# - **C (Satisfactory)**: The report lacks clear structure or contains multiple grammatical or organizational issues. Integration of code and analysis is weak or inconsistent. Figures and plots are poorly labeled or do not clearly connect to the analysis. The report is somewhat difficult to follow.
# - **D (Poor)**: The report is disorganized and difficult to follow. Writing contains significant errors, and there is little to no integration of code, writing, and analysis. Figures or plots are either missing or poorly labeled, making it hard to interpret the results.
#
# ---
#
# ### **2. Model Formulation (25%)**
# This section evaluates the correctness and clarity of the modifications to the SIR model, including reinfection, partial immunity, and mortality.
#
# - **A (Excellent)**: The model is fully and correctly implemented, with all required modifications (reinfection and partial immunity or mortality) clearly incorporated. Parameters are well-defined, and the interactions are logically explained. The model accurately reflects the system’s dynamics, and the group demonstrates a strong understanding of the modifications and their implications.
# - **B (Good)**: The reinfection modification is correctly implemented, but one of the other modifications (partial immunity or mortality) may be incomplete or lack detail. The model mostly works as expected, and the description is clear, but some parts lack depth.
# - **C (Satisfactory)**: The model is partially implemented, with significant issues in one or more modifications. The description is vague or incomplete, and some key components of the model are missing or incorrect.
# - **D (Poor)**: The model is either incorrectly implemented or not modified meaningfully. There is little to no explanation of the changes made to the original SIR model, and key components are missing or incorrect.
#
# ---
#
# ### **3. Model Implementation in Python (15%)**
# This section evaluates the correctness, clarity, and efficiency of the Python code used to simulate the modified model.
#
# - **A (Excellent)**: The Python code fully and correctly implements the modified model. The code is well-written, organized, and efficient, with no errors or bugs. It is well-documented, making it easy to follow.
# - **B (Good)**: The code is mostly correct, with only minor errors or inefficiencies. It runs as expected, but there may be some minor issues with documentation, organization, or clarity.
# - **C (Satisfactory)**: The code runs but contains significant errors, or it lacks clarity. Documentation is minimal or disorganized, and some parts of the model may not function as intended.
# - **D (Poor)**: The code is incomplete, contains major errors, or does not run. It is difficult to follow due to a lack of organization or documentation.
#
# ---
#
# ### **4. Research Question Development (15%)**
# This section assesses the development of a thoughtful and relevant research question based on the modified model, and the identification of appropriate metrics.
#
# - **A (Excellent)**: The research question is well-developed, thoughtful, and directly related to the modifications made to the model. The group identifies appropriate and measurable metrics (e.g., peak infection, total infections, long-term trends) to answer the question. The question is clearly stated and relevant to the model’s scope.
# - **B (Good)**: The research question is relevant but could be more specific or detailed. The group identifies metrics, but they may not fully address the research question or lack clear justification. There is a general understanding of how the question relates to the model.
# - **C (Satisfactory)**: The research question is vague or underdeveloped. Metrics are either poorly chosen or not clearly explained in relation to the research question, and the connection to the model is unclear.
# - **D (Poor)**: The research question is missing, irrelevant, or inappropriate. No meaningful metrics are provided to assess the model.
#
# ---
#
# ### **5. Data Generation and Analysis (20%)**
# This section evaluates how well the group generates and analyzes data from the model to answer their research question.
#
# - **A (Excellent)**: The group effectively generates data from simulations, exploring multiple scenarios. Their analysis is well-executed and directly addresses the research question, demonstrating a strong understanding of the model’s behavior under different conditions. They clearly interpret the data and explain the implications.
# - **B (Good)**: The group generates data and provides a good analysis, but the exploration of different scenarios may be limited or lack depth. Their interpretation is generally clear but may miss some important insights.
# - **C (Satisfactory)**: Data generation or analysis is incomplete or lacks depth. The results may not fully address the research question, and the interpretation may be unclear or overly simplistic.
# - **D (Poor)**: Little to no data generation or analysis is present. The simulations are incomplete, and the results do not contribute meaningfully to answering the research question.
#
# ---
#
# ### **Total: 20 Points (5 categories)**
#
# ---

# %% [markdown]
# This rubric was written and edited with assistance from generative AI (no link to the conversation this time).
